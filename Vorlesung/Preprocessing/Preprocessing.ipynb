# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

import re
from collections import defaultdict
from collections import Counter

# https://de.wikipedia.org/wiki/Schamanismus

# %%
# Downloads. Run only once

# nltk.download('stopwords')  # Stopwords
# nltk.download('punkt')  # Tokenizers
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\monox\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\monox\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
stops = list(stopwords.words('german'))  # english
print(stops[:5], len(stops))
# Out:
# ['aber', 'alle', 'allem', 'allen', 'aller'] 232

# %%
# Or "alice.txt"
with open("Schamanismus.txt", "r", encoding="utf-8") as inf:
    text = inf.read()

# %%
print("Unique characters", len(set(text)))
print(" ".join(set(text)))

print("\n" * 2)

char_count = Counter(text)
print("Most common chars:", char_count.most_common(20))  # Zipf?
# Out:
# Unique characters 102
# k L q O 	 g 5 = ) a ‘ H 1
#  l P ù v ’ ; → b R , W 6 j N Y E ä ü 0 r B i d ß Z A : t p y ‚ ( w 7 D ó ´ z u h M e c I m é . 3 * á è S ` ?   [ / 2 Ä 4 x Ü „ U s “ " - í T G … ö ﻿ F š o 9 C K n J f – V ] ñ 8
#
#
#
# Most common chars: [('e', 8453), (' ', 8370), ('n', 5251), ('i', 4565), ('s', 3696), ('r', 3636), ('t', 2969), ('a', 2949), ('h', 2468), ('d', 2234), ('l', 2082), ('u', 2075), ('c', 1736), ('o', 1454), ('m', 1408), ('g', 1226), ('b', 758), ('k', 665), ('f', 605), ('w', 519)]

# %%
# Cleaning
s = 2000
print(text[s:s+100])
text_cleaned = re.sub(r"[^a-zA-Z0-9äöüÄÖÜß\.,!\?-]", " ", text)

print(text_cleaned[s:s+100])
print("\n\nUnique characters", len(set(text_cleaned)))
# Out:
#  „westlich idealistischen Konstrukt Schamanismus“ jeglichen Erklärungswert ab.[A 2]
#
# Einig ist man s
#   westlich idealistischen Konstrukt Schamanismus  jeglichen Erklärungswert ab. A 2   Einig ist man s
#
#
# Unique characters 71

# %%
# Segmentation
sentences = sent_tokenize(text_cleaned, language="german")

print(len(sentences), "sentences.")
print(sentences[3:5])
# Out:
# 299 sentences.
# ['Nach L szl  Vajda 3  und Jane Monnig Atkinson A 1  sollte aufgrund der Vielzahl unterschiedlicher Konzepte treffender von Schamanismen im Plural gesprochen werden.', 'Sibirische Schamanen und verschiedene Geisterbeschwörer anderer Ethnien   die ebenfalls häufig verallgemeinernd als Schamanen bezeichnet werden   hatten oder haben in vielen traditionellen Weltanschauungen angeblich Einfluss auf die Mächte des Jenseits.']

# %%
# Tokenization
tokenized_sentences = []
for sent in sentences:
    tokens = word_tokenize(sent, language="german")
    tokenized_sentences.append(tokens)
    
print(tokenized_sentences[0])
# Out:
# ['Schamanismus', 'bezeichnet', 'im', 'engeren', 'Sinne', 'die', 'traditionellen', 'ethnischen', 'Religionen', 'des', 'Kulturareales', 'Sibirien', 'Nenzen', ',', 'Jakuten', ',', 'Altaier', ',', 'Burjaten', ',', 'Ewenken', ',', 'auch', 'europäische', 'Samen', 'und', 'andere', ',', 'bei', 'denen', 'das', 'Vorhandensein', 'von', 'Schamanen', 'von', 'europäischen', 'Forschern', 'der', 'Expansionszeit', 'als', 'wesentliches', 'gemeinsames', 'Kennzeichen', 'erachtet', 'wurde', '.']

# %%
# Filter stopwords
stops = set(stops)
filtered_sentences = []
for sent in tokenized_sentences:
    filtered_sent = [token for token in sent if token not in stops]
    filtered_sentences.append(filtered_sent)

# %%
print(filtered_sentences[0])
# Out:
# ['Schamanismus', 'bezeichnet', 'engeren', 'Sinne', 'traditionellen', 'ethnischen', 'Religionen', 'Kulturareales', 'Sibirien', 'Nenzen', ',', 'Jakuten', ',', 'Altaier', ',', 'Burjaten', ',', 'Ewenken', ',', 'europäische', 'Samen', ',', 'denen', 'Vorhandensein', 'Schamanen', 'europäischen', 'Forschern', 'Expansionszeit', 'wesentliches', 'gemeinsames', 'Kennzeichen', 'erachtet', 'wurde', '.']

# %%
# Lower all tokens
lowered_sentences = list(map(lambda sent: list(map(str.lower, sent)), filtered_sentences))

# %%
print(lowered_sentences[0])
# Out:
# ['schamanismus', 'bezeichnet', 'engeren', 'sinne', 'traditionellen', 'ethnischen', 'religionen', 'kulturareales', 'sibirien', 'nenzen', ',', 'jakuten', ',', 'altaier', ',', 'burjaten', ',', 'ewenken', ',', 'europäische', 'samen', ',', 'denen', 'vorhandensein', 'schamanen', 'europäischen', 'forschern', 'expansionszeit', 'wesentliches', 'gemeinsames', 'kennzeichen', 'erachtet', 'wurde', '.']

# %%
# Help from spacy


import spacy
# python -m spacy download de_core_news_sm

# %%
nlp = spacy.load("de_core_news_sm")

# %%
doc = nlp(text)

# %%
for sent in doc.sents:
    print(sent)
    break
# Out:
# Schamanismus bezeichnet im engeren Sinne die traditionellen ethnischen Religionen des Kulturareales Sibirien (Nenzen, Jakuten, Altaier, Burjaten, Ewenken, auch europäische Samen und andere), bei denen das Vorhandensein von Schamanen von europäischen Forschern der Expansionszeit als wesentliches gemeinsames Kennzeichen erachtet wurde.[1]

# %%
c = 0
for sent in doc.sents:
    for token in sent:
        print(f"{token} ({token.lemma_}) <{token.pos_}>")
# Out:
# Schamanismus (Schamanismus) <NOUN>
# bezeichnet (bezeichnen) <VERB>
# im (in) <ADP>
# engeren (eng) <ADJ>
# Sinne (Sinn) <NOUN>
# die (der) <DET>
# traditionellen (traditionell) <ADJ>
# ethnischen (ethnisch) <ADJ>
# Religionen (Religion) <NOUN>
# des (der) <DET>
# Kulturareales (Kulturareale) <PROPN>
# Sibirien (Sibirien) <PROPN>
# ( (--) <PUNCT>
# Nenzen (Nenzen) <NOUN>
# , (--) <PUNCT>
# Jakuten (Jakut) <NOUN>
# , (--) <PUNCT>
# Altaier (Altaier) <NOUN>
# , (--) <PUNCT>
# Burjaten (Burjat) <NOUN>
# , (--) <PUNCT>
# Ewenken (Ewenk) <NOUN>
# , (--) <PUNCT>
# auch (auch) <ADV>
# europäische (europäisch) <ADJ>
# Samen (Samen) <NOUN>
# und (und) <CCONJ>
# andere (anderer) <PRON>
# ) (--) <PUNCT>
# , (--) <PUNCT>
# bei (bei) <ADP>
# denen (der) <PRON>
# das (der) <DET>
# Vorhandensein (Vorhandensein) <NOUN>
# von (von) <ADP>
# Schamanen (Schaman) <NOUN>
# von (von) <ADP>
# europäischen (europäisch) <ADJ>
# Forschern (Forscher) <NOUN>
# der (der) <DET>
# Expansionszeit (Expansionszeit) <NOUN>
# als (als) <ADP>
# wesentliches (wesentlich) <ADJ>
# gemeinsames (gemeinsam) <ADJ>
# Kennzeichen (Kennzeichen) <NOUN>
# erachtet (erachten) <VERB>
# wurde.[1 (wurde.[1) <PROPN>
# ] (]) <PROPN>
# Zur (zu) <ADP>
# besseren (gut) <ADJ>
# Abgrenzung (Abgrenzung) <NOUN>
# werden (werden) <AUX>
# diese (dieser) <DET>
# Religionen (Religion) <NOUN>
# häufig (häufig) <ADV>
# „ (--) <PUNCT>
# klassischer (klassisch) <ADJ>
# Schamanismus (Schamanismus) <NOUN>
# “ (--) <PUNCT>
# oder (oder) <CCONJ>
# auch (auch) <ADV>
# „ (--) <PUNCT>
# sibirischer (sibirisch) <ADJ>
# Animismus (Animismus) <NOUN>
# “ (--) <PUNCT>
# genannt.[2 (genannt.[2) <ADJ>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# Im (in) <ADP>
# weiteren (weit) <ADJ>
# Sinne (Sinn) <NOUN>
# meint (meinen) <VERB>
# Schamanismus (Schamanismus) <PROPN>
# alle (aller) <DET>
# wissenschaftlichen (wissenschaftlich) <ADJ>
# Konzepte (Konzept) <NOUN>
# , (--) <PUNCT>
# die (der) <PRON>
# aufgrund (aufgrund) <ADP>
# von (von) <ADP>
# ähnlichen (ähnlich) <ADJ>
# Praktiken (Praktik) <NOUN>
# spiritueller (spirituell) <ADJ>
# Spezialisten (Spezialist) <NOUN>
# in (in) <ADP>
# verschiedenen (verschieden) <ADJ>
# traditionellen (traditionell) <ADJ>
# Gesellschaften (Gesellschaft) <NOUN>
# die (der) <DET>
# kulturübergreifende (kulturübergreifend) <ADJ>
# Existenz (Existenz) <NOUN>
# des (der) <DET>
# Schamanismus (Schamanismus) <NOUN>
# postulieren (postulieren) <VERB>
# . (--) <PUNCT>
# Nach (nach) <ADP>
# László (László) <PROPN>
# Vajda[3 (Vajda[3) <PROPN>
# ] (]) <PROPN>
# und (und) <CCONJ>
# Jane (Jane) <PROPN>
# Monnig (Monnig) <PROPN>
# Atkinson (Atkinson) <PROPN>
# [ ([) <PROPN>
# A (--) <PROPN>
# 1 (1) <NUM>
# ] (]) <PROPN>
# sollte (sollen) <AUX>
# aufgrund (aufgrund) <ADP>
# der (der) <DET>
# Vielzahl (Vielzahl) <NOUN>
# unterschiedlicher (unterschiedlich) <ADJ>
# Konzepte (Konzept) <NOUN>
# treffender (treffend) <ADV>
# von (von) <ADP>
# Schamanismen (Schamanisme) <NOUN>
# im (in) <ADP>
# Plural (Plural) <NOUN>
# gesprochen (sprechen) <VERB>
# werden (werden) <AUX>
# . (--) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# Sibirische (sibirisch) <ADJ>
# Schamanen (Schaman) <NOUN>
# und (und) <CCONJ>
# verschiedene (verschieden) <ADJ>
# Geisterbeschwörer (Geisterbeschwörer) <NOUN>
# anderer (anderer) <ADJ>
# Ethnien (Ethnie) <NOUN>
# – (--) <PUNCT>
# die (der) <PRON>
# ebenfalls (ebenfalls) <ADV>
# häufig (häufig) <ADV>
# verallgemeinernd (verallgemeinernd) <ADV>
# als (als) <ADP>
# Schamanen (Schaman) <NOUN>
# bezeichnet (bezeichnen) <VERB>
# werden (werden) <AUX>
# – (--) <PUNCT>
# hatten (haben) <VERB>
# oder (oder) <CCONJ>
# haben (haben) <AUX>
# in (in) <ADP>
# vielen (vieler) <DET>
# traditionellen (traditionell) <ADJ>
# Weltanschauungen (Weltanschauung) <NOUN>
# angeblich (angeblich) <ADV>
# Einfluss (Einfluss) <ADV>
# auf (auf) <ADP>
# die (der) <DET>
# Mächte (Mächte) <NOUN>
# des (der) <DET>
# Jenseits (Jenseit) <NOUN>
# . (--) <PUNCT>
# Sie (sie) <PRON>
# setzten (setzen) <VERB>
# ihre (ihr) <DET>
# Fähigkeiten (Fähigkeit) <NOUN>
# vorwiegend (vorwiegend) <ADV>
# zum (zu) <ADP>
# Wohle (wohle) <NOUN>
# der (der) <DET>
# Gemeinschaft (Gemeinschaft) <NOUN>
# ein (ein) <ADV>
# , (--) <PUNCT>
# um (um) <SCONJ>
# in (in) <ADP>
# unlösbar (unlösbar) <ADV>
# erscheinenden (erscheinend) <ADJ>
# Krisensituationen (Krisensituation) <NOUN>
# die (der) <DET>
# „ (--) <PUNCT>
# kosmische (kosmisch) <ADJ>
# Harmonie (Harmonie) <NOUN>
# “ (--) <PUNCT>
# zwischen (zwischen) <ADP>
# Diesseits (Diesseits) <NOUN>
# und (und) <CCONJ>
# Jenseits (Jenseits) <NOUN>
# wiederherzustellen (wiederherstellen) <VERB>
# . (--) <PUNCT>
# In (in) <ADP>
# diesem (dieser) <DET>
# weiten (weit) <ADJ>
# Sinne (Sinn) <NOUN>
# bezeichnet (bezeichnen) <VERB>
# Schamanismus (Schamanismus) <NOUN>
# eine (ein) <DET>
# Reihe (Reihe) <NOUN>
# unscharf (unscharf) <ADV>
# bestimmter (bestimmt) <ADJ>
# Phänomene (Phänomen) <NOUN>
# „ (--) <PUNCT>
# zwischen (zwischen) <ADP>
# Religion (Religion) <NOUN>
# und (und) <CCONJ>
# Heilritual“.[4][5][6][7][8][9][Anmerkung (Heilritual“.[4][5][6][7][8][9][Anmerkung) <NOUN>
# 1 (1) <NUM>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# Eine (ein) <DET>
# nähere (näh) <ADJ>
# allgemeingültige (allgemeingültig) <ADJ>
# Bestimmung (Bestimmung) <NOUN>
# ist (sein) <AUX>
# nicht (nicht) <PART>
# möglich (möglich) <ADV>
# , (--) <PUNCT>
# da (da) <SCONJ>
# die (der) <DET>
# Definition (Definition) <NOUN>
# verschiedene (verschieden) <ADJ>
# Betrachtungsweisen (Betrachtungsweise) <NOUN>
# aus (aus) <ADP>
# Sicht (Sicht) <NOUN>
# der (der) <DET>
# Ethnologie (Ethnologie) <NOUN>
# , (--) <PUNCT>
# Kulturanthropologie (Kulturanthropologie) <NOUN>
# , (--) <PUNCT>
# Religionswissenschaften (Religionswissenschaft) <NOUN>
# , (--) <PUNCT>
# Archäologie (Archäologie) <NOUN>
# , (--) <PUNCT>
# Soziologie (Soziologie) <NOUN>
# und (und) <CCONJ>
# Psychologie (Psychologie) <NOUN>
# enthält.[10][11 (enthält.[10][11) <PROPN>
# ] (]) <PROPN>
# Dies (dieser) <PRON>
# hat (haben) <AUX>
# unter (unter) <ADP>
# anderem (anderer) <PRON>
# zur (zu) <ADP>
# Folge (Folge) <NOUN>
# , (--) <PUNCT>
# dass (dass) <SCONJ>
# Angaben (Angabe) <NOUN>
# zur (zu) <ADP>
# räumlichen (räumlich) <ADJ>
# und (und) <CCONJ>
# zeitlichen (zeitlich) <ADJ>
# Verbreitung (Verbreitung) <NOUN>
# der (der) <DET>
# „ (--) <PUNCT>
# Schamanismen (Schamanisme) <NOUN>
# “ (--) <PUNCT>
# erheblich (erheblich) <ADV>
# voneinander (voneinander) <ADV>
# abweichen (abweichen) <VERB>
# und (und) <CCONJ>
# in (in) <ADP>
# vielen (vieler) <DET>
# Fällen (Fall) <NOUN>
# umstritten (umstritten) <ADV>
# sind.[12][13][14 (sind.[12][13][14) <PROPN>
# ] (]) <NOUN>
# Der (der) <DET>
# amerikanische (amerikanisch) <ADJ>
# Ethnologe (Ethnologe) <NOUN>
# Clifford (Clifford) <PROPN>
# Geertz (Geertz) <PROPN>
# sprach (sprechen) <VERB>
# daher (daher) <ADV>
# bereits (bereits) <ADV>
# in (in) <ADP>
# den (der) <DET>
# 1960er (1960er) <ADJ>
# Jahren (Jahr) <NOUN>
# dem (der) <DET>
# „ (--) <PUNCT>
# westlich (westlich) <ADV>
# idealistischen (idealistisch) <ADJ>
# Konstrukt (Konstrukt) <NOUN>
# Schamanismus (Schamanismus) <NOUN>
# “ (--) <PUNCT>
# jeglichen (jeglicher) <DET>
# Erklärungswert (Erklärungswert) <NOUN>
# ab.[A (Ab.[A) <X>
# 2 (2) <NUM>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# Einig (einig) <ADV>
# ist (sein) <AUX>
# man (man) <PRON>
# sich (sich) <PRON>
# lediglich (lediglich) <ADV>
# bei (bei) <ADP>
# der (der) <DET>
# „ (--) <PUNCT>
# engen (eng) <ADJ>
# Definition (Definition) <NOUN>
# “ (--) <PUNCT>
# des (der) <DET>
# klassisch (klassisch) <ADV>
# sibirischen (sibirisch) <ADJ>
# Schamanismus (Schamanismus) <NOUN>
# – (--) <PUNCT>
# dem (der) <DET>
# Ausgangspunkt (Ausgangspunkt) <NOUN>
# der (der) <DET>
# ersten (erster) <ADJ>
# „ (--) <PUNCT>
# Schamanismen (Schamanisme) <NOUN>
# “ (--) <PUNCT>
# . (--) <PUNCT>
# Dazu (dazu) <ADV>
# gehört (gehören) <VERB>
# vor (vor) <ADP>
# allem (alle) <PRON>
# die (der) <DET>
# genaue (genau) <ADJ>
# Beschreibung (Beschreibung) <NOUN>
# der (der) <DET>
# dort (dort) <ADV>
# praktizierten (praktiziert) <ADJ>
# rituellen (rituell) <ADJ>
# Ekstase (Ekstase) <NOUN>
# , (--) <PUNCT>
# eine (ein) <DET>
# weitgehend (weitgehend) <ADV>
# übereinstimmende (übereinstimmend) <ADJ>
# ethnische (ethnisch) <ADJ>
# Religion (Religion) <NOUN>
# sowie (sowie) <CCONJ>
# eine (ein) <DET>
# ähnliche (ähnlich) <ADJ>
# Kosmologie (Kosmologie) <NOUN>
# und (und) <CCONJ>
# Lebensweise.[15][11][16 (Lebensweise.[15][11][16) <NOUN>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# Nach (nach) <ADP>
# weiter (weiter) <ADV>
# gefassten (gefasst) <ADJ>
# Definitionen (Definition) <NOUN>
# wird (werden) <AUX>
# Schamanismus (Schamanismus) <NOUN>
# bis (bis) <ADP>
# in (in) <ADP>
# die (der) <DET>
# 1980er (1980er) <NUM>
# Jahre (Jahr) <NOUN>
# als (als) <ADP>
# frühe (früh) <ADJ>
# , (--) <PUNCT>
# kulturübergreifende (kulturübergreifend) <ADJ>
# Entwicklungsstufe (Entwicklungsstufe) <NOUN>
# jeglicher (jeglicher) <ADJ>
# Religion (Religion) <NOUN>
# betrachtet.[15 (betrachtet.[15) <PROPN>
# ] (]) <X>
# Vor (vor) <ADP>
# allem (alle) <PRON>
# das (der) <DET>
# Konzept (Konzept) <NOUN>
# des (der) <DET>
# Core-Schamanismus (Core-Schamanismus) <NOUN>
# von (von) <ADP>
# Michael (Michael) <PROPN>
# Harner (Harner) <PROPN>
# ist (sein) <AUX>
# hier (hier) <ADV>
# zu (zu) <PART>
# nennen (nennen) <VERB>
# . (--) <PUNCT>
# Diese (dieser) <DET>
# Auslegung (Auslegung) <NOUN>
# gilt (gelten) <VERB>
# jedoch (jedoch) <ADV>
# mittlerweile (mittlerweile) <ADV>
# als (als) <ADP>
# nicht (nicht) <PART>
# konsensfähig.[14 (konsensfähig.[14) <NOUN>
# ] (]) <NOUN>
# Seit (seit) <ADP>
# den (der) <DET>
# 1990er (1990er) <NUM>
# Jahren (Jahr) <NOUN>
# steht (stehen) <VERB>
# häufig (häufig) <ADV>
# der (der) <DET>
# Aspekt (Aspekt) <NOUN>
# des (der) <DET>
# „ (--) <PUNCT>
# Heilens (Heilen) <NOUN>
# “ (--) <PUNCT>
# im (in) <ADP>
# Mittelpunkt (Mittelpunkt) <NOUN>
# des (der) <DET>
# Interesses (Interesse) <NOUN>
# ( (--) <PUNCT>
# und (und) <CCONJ>
# der (der) <DET>
# jeweiligen (jeweilig) <ADJ>
# Definition).[10 (Definition).[10) <PROPN>
# ] (]) <NOUN>
#
#
#  (
#
# ) <SPACE>
# Demgegenüber (demgegenüber) <ADV>
# geht (gehen) <VERB>
# der (der) <DET>
# Indologe (Indologe) <NOUN>
# Michael (Michael) <PROPN>
# Witzel (Witzel) <PROPN>
# davon (davon) <ADV>
# aus (aus) <ADP>
# , (--) <PUNCT>
# dass (dass) <SCONJ>
# es (es) <PRON>
# angesichts (angesichts) <ADP>
# der (der) <DET>
# Ähnlichkeit (Ähnlichkeit) <NOUN>
# australischer (australisch) <ADJ>
# , (--) <PUNCT>
# andamanischer (andamanisch) <ADJ>
# , (--) <PUNCT>
# indischer (indisch) <ADJ>
# und (und) <CCONJ>
# afrikanischer (afrikanisch) <ADJ>
# Initiationsrituale (Initiationsrituale) <NOUN>
# mit (mit) <ADP>
# den (der) <DET>
# entsprechenden (entsprechend) <ADJ>
# sibirischen (sibirisch) <ADJ>
# Ritualen (Ritual) <NOUN>
# , (--) <PUNCT>
# die (der) <PRON>
# die (der) <DET>
# Phänomene (Phänomen) <NOUN>
# der (der) <DET>
# aufsteigenden (aufsteigend) <ADJ>
# Hitze (Hitze) <NOUN>
# , (--) <PUNCT>
# Trancen (Trance) <NOUN>
# ( (--) <PUNCT>
# Dreamers (Dreamer) <NOUN>
# ) (--) <PUNCT>
# , (--) <PUNCT>
# Ekstase (Ekstase) <NOUN>
# und (und) <CCONJ>
# Kollaps (Kollaps) <NOUN>
# , (--) <PUNCT>
# symbolischen (symbolisch) <ADJ>
# Tod (Tod) <NOUN>
# und (und) <CCONJ>
# Wiedergeburt (Wiedergeburt) <NOUN>
# , (--) <PUNCT>
# Verwendung (Verwendung) <NOUN>
# psychoaktiver (psychoaktiv) <ADJ>
# Drogen (Droge) <NOUN>
# , (--) <PUNCT>
# Tabubewahrung (Tabubewahrung) <NOUN>
# , (--) <PUNCT>
# Zauberei (Zauberei) <NOUN>
# und (und) <CCONJ>
# Heilung (Heilung) <NOUN>
# umfassen (umfassen) <VERB>
# , (--) <PUNCT>
# einen (ein) <DET>
# älteren (alt) <ADJ>
# Prototyp (Prototyp) <NOUN>
# des (der) <DET>
# Schamanismus (Schamanismus) <NOUN>
# gegeben (geben) <VERB>
# habe (haben) <AUX>
# . (--) <PUNCT>
# Dieser (dieser) <PRON>
# habe (haben) <AUX>
# sich (sich) <PRON>
# mit (mit) <ADP>
# der (der) <DET>
# Out-of-Africa-Wanderung (Out-of-Africa-Wanderung) <NOUN>
# des (der) <DET>
# modernen (modern) <ADJ>
# Menschen (Mensch) <NOUN>
# entlang (entlang) <ADP>
# der (der) <DET>
# Küsten (Küste) <NOUN>
# des (der) <DET>
# Indischen (Indischen) <ADJ>
# Ozeans (Ozean) <PROPN>
# und (und) <CCONJ>
# früh (früh) <ADV>
# auch (auch) <ADV>
# nach (nach) <ADP>
# Eurasien (Eurasien) <PROPN>
# und (und) <CCONJ>
# Nordamerika (Nordamerika) <PROPN>
# verbreitet (verbreiten) <VERB>
# . (--) <PUNCT>
# Dafür (dafür) <ADV>
# sprächen (spräch) <VERB>
# spätpaläolithische (spätpaläolithisch) <ADJ>
# Bärenkulte (Bärenkulte) <NOUN>
# und (und) <CCONJ>
# Felszeichnungen (Felszeichnungen) <NOUN>
# wie (wie) <ADP>
# in (in) <ADP>
# Les (Les) <PROPN>
# trois (Trois) <PROPN>
# frères (frères) <PROPN>
# ( (--) <PUNCT>
# Abb. (abb.) <NOUN>
# siehe (sehen) <VERB>
# unten (unten) <ADV>
# ) (--) <PUNCT>
# . (--) <PUNCT>
# Der (der) <DET>
# sibirische (sibirisch) <ADJ>
# Schamanismus (Schamanismus) <NOUN>
# stelle (stellen) <VERB>
# eine (ein) <DET>
# jüngere (jung) <ADJ>
# Evolutionsstufe (Evolutionsstufe) <NOUN>
# dieses (dieser) <DET>
# Prototyps (Prototyp) <NOUN>
# dar (dar) <ADV>
# ( (--) <PUNCT>
# mit (mit) <ADP>
# Fellkleidung (Fellkleidung) <NOUN>
# , (--) <PUNCT>
# Trommel (Trommel) <NOUN>
# usw. (usw.) <ADV>
# ) (--) <PUNCT>
# ; (--) <PUNCT>
# er (er) <PRON>
# habe (haben) <AUX>
# über (über) <ADP>
# weitere (weit) <ADJ>
# Wanderungswellen (Wanderungswelle) <NOUN>
# die (der) <DET>
# nordamerikanischen (nordamerikanisch) <ADJ>
# Jägerkulturen (Jägerkulture) <NOUN>
# sekundär (sekundär) <ADV>
# beeinflusst (beeinflusst) <VERB>
# . (--) <PUNCT>
# An (an) <ADP>
# die (der) <DET>
# Stelle (Stelle) <NOUN>
# des (der) <DET>
# Opfers (Opfer) <NOUN>
# wilder (wild) <ADJ>
# Tiere (Tier) <NOUN>
# , (--) <PUNCT>
# die (der) <PRON>
# der (der) <DET>
# Schamane (Schamane) <NOUN>
# vorher (vorher) <ADV>
# um (um) <ADP>
# Erlaubnis (Erlaubnis) <NOUN>
# für (für) <ADP>
# die (der) <DET>
# Tötung (Tötung) <NOUN>
# fragt (fragen) <VERB>
# oder (oder) <CCONJ>
# bei (bei) <ADP>
# denen (der) <PRON>
# er (er) <PRON>
# sich (sich) <PRON>
# für (für) <ADP>
# die (der) <DET>
# Tat (Tat) <NOUN>
# entschuldigt (entschuldigen) <VERB>
# ( (--) <PUNCT>
# so (so) <ADV>
# bei (bei) <ADP>
# den (der) <DET>
# Bärenkulten (Bärenkulten) <NOUN>
# der (der) <DET>
# Schamanen (Schaman) <NOUN>
# der (der) <DET>
# Ainu (Ainu) <NOUN>
# , (--) <PUNCT>
# Aleuten (Aleut) <NOUN>
# und (und) <CCONJ>
# der (der) <DET>
# transbaikalischen (transbaikalisch) <ADJ>
# Völker (Volk) <NOUN>
# ) (--) <PUNCT>
# , (--) <PUNCT>
# seien (sein) <AUX>
# später (spät) <ADV>
# domestizierte (domestiziert) <ADJ>
# Tiere (Tier) <NOUN>
# wie (wie) <ADP>
# das (der) <DET>
# Rentier (Rentier) <NOUN>
# ( (--) <PUNCT>
# in (in) <ADP>
# Sibirien (Sibirien) <PROPN>
# ) (--) <PUNCT>
# oder (oder) <CCONJ>
# Hunde (Hund) <NOUN>
# ( (--) <PUNCT>
# wie (wie) <ADP>
# in (in) <ADP>
# Russland (Russland) <NOUN>
# oder (oder) <CCONJ>
# Indien (Indien) <PROPN>
# ) (--) <PUNCT>
# getreten.[17 (getreten.[17) <PROPN>
# ] (]) <X>
# Insofern (insofern) <ADV>
# folgt (folgen) <VERB>
# Witzel (Witzel) <NOUN>
# der (der) <DET>
# weiten (weit) <ADJ>
# phänomenologischen (phänomenologisch) <ADJ>
# Schamanismus-Definition (Schamanismus-Definition) <NOUN>
# von (von) <ADP>
# Walter (Walter) <PROPN>
# und (und) <CCONJ>
# Fridman.[18 (Fridman.[18) <PROPN>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# Da (da) <SCONJ>
# bereits (bereits) <ADV>
# der (der) <DET>
# klassische (klassisch) <ADJ>
# Schamanismus (Schamanismus) <NOUN>
# Sibiriens (Sibirien) <PROPN>
# etliche (etlicher) <DET>
# Varianten (Variant) <NOUN>
# aufweist (aufweisen) <VERB>
# , (--) <PUNCT>
# werden (werden) <AUX>
# weiter (weiter) <ADV>
# reichende (reichend) <ADJ>
# geographische (geographisch) <ADJ>
# oder (oder) <CCONJ>
# historische (historisch) <ADJ>
# Auslegungen (Auslegung) <NOUN>
# , (--) <PUNCT>
# die (der) <PRON>
# solche (solcher) <DET>
# Phänomene (Phänomen) <NOUN>
# aus (aus) <ADP>
# ihrem (ihr) <DET>
# kulturellen (kulturell) <ADJ>
# Kontext (Kontext) <NOUN>
# gelöst (lösen) <VERB>
# betrachten (betrachten) <VERB>
# und (und) <CCONJ>
# verallgemeinern (verallgemeinern) <VERB>
# , (--) <PUNCT>
# von (von) <ADP>
# vielen (vieler) <DET>
# Autoren (Autor) <NOUN>
# als (als) <ADP>
# spekulativ (spekulativ) <ADV>
# kritisiert.[19][13 (kritisiert.[19][13) <PROPN>
# ] (]) <PROPN>
# In (in) <ADP>
# der (der) <DET>
# zeitgenössischen (zeitgenössisch) <ADJ>
# Literatur (Literatur) <NOUN>
# – (--) <PUNCT>
# populärwissenschaftlichen (populärwissenschaftlich) <VERB>
# ( (--) <PUNCT>
# insbesondere (insbesondere) <ADV>
# esoterischen (esoterisch) <ADJ>
# ) (--) <PUNCT>
# Büchern (Buch) <NOUN>
# , (--) <PUNCT>
# aber (aber) <CCONJ>
# auch (auch) <ADV>
# wissenschaftlichen (wissenschaftlich) <ADJ>
# Schriften (Schrift) <NOUN>
# – (--) <PUNCT>
# wird (werden) <AUX>
# in (in) <ADP>
# diesem (dieser) <DET>
# Zusammenhang (Zusammenhang) <NOUN>
# oftmals (oftmals) <ADV>
# nicht (nicht) <PART>
# deutlich (deutlich) <ADV>
# gemacht (machen) <VERB>
# , (--) <PUNCT>
# auf (auf) <ADP>
# welche (welcher) <DET>
# Ethnien (Ethnien) <NOUN>
# sich (sich) <PRON>
# Darstellungen (Darstellung) <NOUN>
# zu (zu) <ADP>
# bestimmten (bestimmt) <ADJ>
# schamanischen (schamanisch) <ADJ>
# Praktiken (Praktik) <NOUN>
# konkret (konkret) <ADV>
# beziehen (beziehen) <VERB>
# , (--) <PUNCT>
# so (so) <ADV>
# dass (dass) <SCONJ>
# regionale (regional) <ADJ>
# ( (--) <PUNCT>
# oft (oft) <ADV>
# sibirische (sibirisch) <ADJ>
# ) (--) <PUNCT>
# Phänomene (Phänomen) <NOUN>
# auch (auch) <ADV>
# in (in) <ADP>
# anderen (anderer) <ADJ>
# Kulturen (Kultur) <NOUN>
# verortet (verorten) <VERB>
# werden (werden) <AUX>
# , (--) <PUNCT>
# in (in) <ADP>
# deren (der) <DET>
# Traditionen (Tradition) <NOUN>
# sie (sie) <PRON>
# tatsächlich (tatsächlich) <ADV>
# jedoch (jedoch) <ADV>
# fremd (fremd) <ADV>
# sind (sein) <AUX>
# . (--) <PUNCT>
# Beispiele (Beispiel) <NOUN>
# dafür (dafür) <ADV>
# sind (sein) <AUX>
# der (der) <DET>
# Weltenbaum (Weltenbaum) <NOUN>
# und (und) <CCONJ>
# die (der) <DET>
# gesamte (gesamt) <ADJ>
# schamanische (schamanisch) <ADJ>
# Kosmologie (Kosmologie) <NOUN>
# : (--) <PUNCT>
# in (in) <ADP>
# Eurasien (Eurasien) <PROPN>
# verankerte (verankert) <ADJ>
# mythologische (mythologisch) <ADJ>
# Konzepte (Konzept) <NOUN>
# , (--) <PUNCT>
# die (der) <PRON>
# hier (hier) <ADV>
# mit (mit) <ADP>
# ähnlichen (ähnlich) <ADJ>
# Archetypen (Archetype) <NOUN>
# anderer (anderer) <ADJ>
# Weltgegenden (Weltgegende) <NOUN>
# gleichgesetzt (gleichsetzen) <VERB>
# werden (werden) <AUX>
# und (und) <CCONJ>
# so (so) <ADV>
# das (der) <DET>
# irreführende (irreführend) <ADJ>
# Bild (Bild) <NOUN>
# eines (ein) <DET>
# einheitlichen (einheitlich) <ADJ>
# Schamanismus (Schamanismus) <NOUN>
# erzeugen.[13 (erzeugen.[13) <PROPN>
# ] (]) <PROPN>
# Witzel (Witzel) <PROPN>
# sieht (sehen) <VERB>
# jedoch (jedoch) <ADV>
# in (in) <ADP>
# der (der) <DET>
# eurasischen (eurasisch) <ADJ>
# ( (--) <PUNCT>
# germanischen (germanisch) <VERB>
# , (--) <PUNCT>
# indischen (indisch) <ADJ>
# , (--) <PUNCT>
# japanischen (japanisch) <VERB>
# usw. (usw.) <ADV>
# ) (--) <PUNCT>
# Vorstellung (Vorstellung) <NOUN>
# vom (von) <ADP>
# Baum (Baum) <NOUN>
# des (der) <DET>
# Lebens (Leben) <NOUN>
# , (--) <PUNCT>
# der (der) <PRON>
# erstiegen (erstiegen) <VERB>
# werden (werden) <AUX>
# muss (Muss) <ADV>
# , (--) <PUNCT>
# beziehungsweise (beziehungsweise) <CCONJ>
# im (in) <ADP>
# Weltenbaum (Weltenbaum) <NOUN>
# nur (nur) <ADV>
# eine (ein) <DET>
# Analogie (Analogie) <NOUN>
# zur (zu) <ADP>
# älteren (alt) <ADJ>
# Vorstellung (Vorstellung) <NOUN>
# des (der) <DET>
# Schamanenflugs (Schamanenflug) <NOUN>
# , (--) <PUNCT>
# die (der) <PRON>
# nichts (nichts) <PRON>
# mit (mit) <ADP>
# anderen (anderer) <ADJ>
# Baummythen (Baummythen) <NOUN>
# zu (zu) <PART>
# tun (tun) <VERB>
# habe.[20 (habe.[20) <PROPN>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# Insbesondere (insbesondere) <ADV>
# die (der) <DET>
# äußerst (äußerst) <ADV>
# erfolgreichen (erfolgreich) <ADJ>
# Bücher (Buch) <NOUN>
# von (von) <ADP>
# Mircea (Mircea) <PROPN>
# Eliade (Eliade) <PROPN>
# , (--) <PUNCT>
# Carlos (Carlos) <PROPN>
# Castaneda (Castaneda) <PROPN>
# und (und) <CCONJ>
# Harner (Harner) <NOUN>
# haben (haben) <AUX>
# den (der) <DET>
# „ (--) <PUNCT>
# modernen (modern) <ADJ>
# Mythos (Mythos) <NOUN>
# Schamanismus (Schamanismus) <NOUN>
# “ (--) <PUNCT>
# erzeugt (erzeugen) <VERB>
# , (--) <PUNCT>
# der (der) <PRON>
# suggeriert (suggerieren) <VERB>
# , (--) <PUNCT>
# dass (dass) <SCONJ>
# es (es) <PRON>
# sich (sich) <PRON>
# dabei (dabei) <ADV>
# um (um) <ADP>
# ein (ein) <DET>
# universelles (universell) <ADJ>
# und (und) <CCONJ>
# homolog (Homolog) <NOUN>
# entstandenes (entstanden) <ADJ>
# religiös-spirituelles (religiös-spirituell) <ADJ>
# Phänomen (Phänomen) <NOUN>
# handeln (handeln) <VERB>
# würde (werden) <AUX>
# . (--) <PUNCT>
# Im (in) <ADP>
# Hinblick (Hinblick) <NOUN>
# auf (auf) <ADP>
# das (der) <DET>
# große (groß) <ADJ>
# Interesse (Interesse) <NOUN>
# in (in) <ADP>
# der (der) <DET>
# Bevölkerung[21 (Bevölkerung[21) <NOUN>
# ] (]) <PROPN>
# weisen (weisen) <VERB>
# einige (einiger) <DET>
# Autoren (Autor) <NOUN>
# darauf (darauf) <ADV>
# hin (hin) <ADV>
# , (--) <PUNCT>
# dass (dass) <SCONJ>
# Schamanismus (Schamanismus) <NOUN>
# keine (kein) <DET>
# einheitliche (einheitlich) <ADJ>
# Ideologie (Ideologie) <NOUN>
# oder (oder) <CCONJ>
# Religion (Religion) <NOUN>
# bestimmter (bestimmt) <ADJ>
# Kulturen (Kultur) <NOUN>
# ist (sein) <AUX>
# . (--) <PUNCT>
# Es (es) <PRON>
# handle (handeln) <VERB>
# sich (sich) <PRON>
# vielmehr (vielmehr) <ADV>
# um (um) <ADP>
# ein (ein) <DET>
# wissenschaftliches (wissenschaftlich) <ADJ>
# Konstrukt (Konstrukt) <NOUN>
# aus (aus) <ADP>
# eurozentrischer (eurozentrisch) <ADJ>
# Perspektive (Perspektive) <NOUN>
# , (--) <PUNCT>
# um (um) <SCONJ>
# ähnliche (ähnlich) <ADJ>
# Phänomene (Phänomen) <NOUN>
# rund (rund) <ADV>
# um (um) <ADP>
# die (der) <DET>
# Geisterbeschwörer (Geisterbeschwörer) <NOUN>
# unterschiedlichster (unterschiedlichst) <ADJ>
# Herkunft (Herkunft) <NOUN>
# zu (zu) <PART>
# vergleichen (vergleichen) <VERB>
# und (und) <CCONJ>
# zu (zu) <ADP>
# klassifizieren.[14][22][23 (klassifizieren.[14][22][23) <PROPN>
# ] (]) <PROPN>
#
#  (
# ) <SPACE>
# Inhaltsverzeichnis (Inhaltsverzeichnis) <NOUN>
#
#
#      (
#
#     ) <SPACE>
# 1 (1) <NUM>
# Etymologie (Etymologie) <NOUN>
#
#      (
#     ) <SPACE>
# 2 (2) <NUM>
# Schamanen (Schaman) <NOUN>
# und (und) <CCONJ>
# Schamanismus (Schamanismus) <NOUN>
#
#      (
#     ) <SPACE>
# 3 (3) <NUM>
# Wissenschaftsgeschichte (Wissenschaftsgeschicht) <NOUN>
#
#      (
#     ) <SPACE>
# 4 (4) <NUM>
# Spirituelle (Spirituelle) <ADJ>
# Schamanismus-Konzepte (Schamanismus-Konzept) <NOUN>
# : (--) <PUNCT>
# Entstehung (Entstehung) <NOUN>
# , (--) <PUNCT>
# Popularität (Popularität) <NOUN>
# und (und) <CCONJ>
# Kritik (Kritik) <NOUN>
#
#      (
#     ) <SPACE>
# 5 (5) <NUM>
# Weitgehend (Weitgehend) <ADV>
# anerkannte (anerkannt) <ADJ>
# Thesen (These) <NOUN>
#
#          (
#         ) <SPACE>
# 5.1 (5.1) <NUM>
# Der (der) <DET>
# klassisch (klassisch) <ADV>
# sibirische (sibirisch) <ADJ>
# Schamanismus (Schamanismus) <NOUN>
# oder (oder) <CCONJ>
# Animismus (Animismus) <NOUN>
#
#              (
#             ) <SPACE>
# 5.1.1 (5.1.1) <NOUN>
# Historische (Historisch) <ADJ>
# Entwicklung (Entwicklung) <NOUN>
#
#              (
#             ) <SPACE>
# 5.1.2 (5.1.2) <NOUN>
# Kosmologie (Kosmologie) <NOUN>
#
#              (
#             ) <SPACE>
# 5.1.3 (5.1.3) <NOUN>
# Die (der) <DET>
# rituelle (rituell) <ADJ>
# Ekstase (Ekstase) <NOUN>
#
#          (
#         ) <SPACE>
# 5.2 (5.2) <NUM>
# Müller (Müller) <PROPN>
# : (--) <PUNCT>
# Elementar- (Elementar) <X>
# , (--) <PUNCT>
# Komplex- (Komplex) <X>
# und (und) <CCONJ>
# Besessenheitsschamanismus (Besessenheitsschamanismus) <NOUN>
#
#              (
#             ) <SPACE>
# 5.2.1 (5.2.1) <PROPN>
# Elementarschamanismus (Elementarschamanismus) <NOUN>
#
#              (
#             ) <SPACE>
# 5.2.2 (5.2.2) <PUNCT>
# Komplexschamanismus (Komplexschamanismus) <NOUN>
#
#              (
#             ) <SPACE>
# 5.2.3 (5.2.3) <PROPN>
# Besessenheitsschamanismus (Besessenheitsschamanismus) <NOUN>
#
#              (
#             ) <SPACE>
# 5.2.4 (5.2.4) <PROPN>
# Kritik (Kritik) <NOUN>
#
#          (
#         ) <SPACE>
# 5.3 (5.3) <NUM>
# Ganzheitliche (ganzheitlich) <ADJ>
# Heilkunde (Heilkunde) <NOUN>
#
#      (
#     ) <SPACE>
# 6 (6) <NUM>
# Generelle (Generelle) <ADJ>
# Kritik (Kritik) <NOUN>
# ; (--) <PUNCT>
# umstrittene (umstritten) <ADJ>
# und (und) <CCONJ>
# spekulative (spekulativ) <ADJ>
# Thesen (These) <NOUN>
#
#          (
#         ) <SPACE>
# 6.1 (6.1) <NUM>
# Umstrittene (Umstrittene) <ADJ>
# Thesen (These) <NOUN>
#
#              (
#             ) <SPACE>
# 6.1.1 (6.1.1) <NOUN>
# Prähistorischer (Prähistorischer) <NOUN>
# Schamanismus (Schamanismus) <NOUN>
#
#              (
#             ) <SPACE>
# 6.1.2 (6.1.2) <PROPN>
# Beziehung (Beziehung) <NOUN>
# zum (zu) <ADP>
# Sufismus (Sufismus) <NOUN>
#
#          (
#         ) <SPACE>
# 6.2 (6.2) <NUM>
# Spekulative (Spekulative) <ADJ>
# Thesen (These) <NOUN>
#
#              (
#             ) <SPACE>
# 6.2.1 (6.2.1) <PROPN>
# Schamanismus (Schamanismus) <NOUN>
# als (als) <ADP>
# archaische (archaisch) <ADJ>
# Ekstasetechnik (Ekstasetechnik) <NOUN>
#
#              (
#             ) <SPACE>
# 6.2.2 (6.2.2) <NOUN>
# Kritik (Kritik) <NOUN>
#
#      (
#     ) <SPACE>
# 7 (7) <NUM>
# Siehe (sehen) <VERB>
# auch (auch) <ADV>
#
#      (
#     ) <SPACE>
# 8 (8) <NUM>
# Literatur (Literatur) <NOUN>
#
#      (
#     ) <SPACE>
# 9 (9) <NUM>
# Weblinks (Weblink) <PROPN>
#
#      (
#     ) <SPACE>
# 10 (10) <NUM>
# Anmerkungen (Anmerkung) <NOUN>
#
#      (
#     ) <SPACE>
# 11 (11) <NUM>
# Einzelnachweise (Einzelnachweis) <NOUN>
#
#
#  (
#
# ) <SPACE>
# Etymologie (Etymologie) <NOUN>
#
#
#  (
#
# ) <SPACE>
# Die (der) <DET>
# Bezeichnung (Bezeichnung) <NOUN>
# Schamanismus (Schamanismus) <NOUN>
# leitet (leiten) <VERB>
# sich (sich) <PRON>
# den (der) <DET>
# meisten (meister) <DET>
# Autoren (Autor) <NOUN>
# zufolge (zufolge) <ADP>
# von (von) <ADP>
# dem (der) <DET>
# aus (aus) <ADP>
# Sibirien (Sibirien) <PROPN>
# entlehnten (entlehnt) <ADJ>
# Wort (Wort) <NOUN>
# Schamane (Schamane) <PROPN>
# ab (ab) <ADP>
# , (--) <PUNCT>
# mit (mit) <ADP>
# dem (der) <PRON>
# die (der) <DET>
# tungusischen (tungusisch) <ADJ>
# Völker (Volk) <NOUN>
# ihre (ihr) <DET>
# Geisterbeschwörer (Geisterbeschwörer) <NOUN>
# bezeichnen.[24 (bezeichnen.[24) <PROPN>
# ] (]) <NOUN>
# Das (der) <DET>
# Wort (Wort) <NOUN>
# entstammt (entstammen) <VERB>
# vermutlich (vermutlich) <ADV>
# dem (der) <DET>
# evenkischen (evenkisch) <ADJ>
# ( (--) <PUNCT>
# d. (der) <PRON>
# h. (heißen) <VERB>
# tungusischen (tungusisch) <ADJ>
# ) (--) <PUNCT>
# šaman (šaman) <PROPN>
# , (--) <PUNCT>
# dessen (der) <DET>
# weitere (weit) <ADJ>
# Etymologie (Etymologie) <NOUN>
# umstritten (umstritten) <ADV>
# ist (sein) <AUX>
# . (--) <PUNCT>
# Möglicherweise (möglicherweise) <ADV>
# liegt (liegen) <VERB>
# das (der) <DET>
# manjurische (manjurisch) <ADJ>
# Verb (Verb) <NOUN>
# sambi (sambi) <ADV>
# , (--) <PUNCT>
# „ (--) <PUNCT>
# wissen (wissen) <VERB>
# , (--) <PUNCT>
# kennen (kennen) <VERB>
# , (--) <PUNCT>
# durchschauen (durchschauen) <VERB>
# “ (--) <PUNCT>
# , (--) <PUNCT>
# zugrunde (zugrunde) <ADV>
# . (--) <PUNCT>
# Die (der) <DET>
# ältere (alt) <ADJ>
# Bezeichnung (Bezeichnung) <NOUN>
# Schamanentum (Schamanentum) <NOUN>
# bezieht (beziehen) <VERB>
# sich (sich) <PRON>
# nicht (nicht) <PART>
# auf (auf) <ADP>
# die (der) <DET>
# wissenschaftlichen (wissenschaftlich) <ADJ>
# Konzepte (Konzept) <NOUN>
# , (--) <PUNCT>
# sondern (sondern) <CCONJ>
# nur (nur) <ADV>
# auf (auf) <ADP>
# die (der) <DET>
# Existenz (Existenz) <NOUN>
# von (von) <ADP>
# Geisterbeschwörern (Geisterbeschwörer) <NOUN>
# in (in) <ADP>
# verschiedenen (verschieden) <ADJ>
# Kulturen (Kultur) <NOUN>
# , (--) <PUNCT>
# ohne (ohne) <SCONJ>
# dabei (dabei) <ADV>
# bestimmte (bestimmt) <ADJ>
# Zusammenhänge (Zusammenhang) <NOUN>
# herzustellen.[25 (herzustellen.[25) <PROPN>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# ( (--) <PUNCT>
# Weitere (weit) <ADJ>
# Informationen (Information) <NOUN>
# siehe (sehen) <VERB>
# : (--) <PUNCT>
# Etymologie (Etymologie) <NOUN>
# im (in) <ADP>
# Artikel (Artikel) <NOUN>
# „ (--) <PUNCT>
# Schamane (Schamane) <PROPN>
# “ (--) <PUNCT>
# ) (--) <PUNCT>
#
#  (
# ) <SPACE>
# Schamanen (Schaman) <NOUN>
# und (und) <CCONJ>
# Schamanismus (Schamanismus) <NOUN>
#
#  (
# ) <SPACE>
# George (George) <PROPN>
# Catlins (Catlins) <PROPN>
# Darstellung (Darstellung) <NOUN>
# eines (ein) <DET>
# Schamanen (Schaman) <NOUN>
# ( (--) <PUNCT>
# Medicine (Medicine) <PROPN>
# man (man) <PRON>
# ) (--) <PUNCT>
# der (der) <DET>
# Schwarzfuß-Indianer (Schwarzfuß-Indianer) <NOUN>
# , (--) <PUNCT>
# der (der) <DET>
# Riten (Rit) <NOUN>
# über (über) <ADP>
# einem (ein) <DET>
# sterbenden (sterbend) <ADJ>
# Häuptling (Häuptling) <NOUN>
# vollführt (vollführen) <VERB>
# . (--) <PUNCT>
#
#  (
# ) <SPACE>
# → (→) <PROPN>
# Hauptartikel (Hauptartikel) <PROPN>
# : (--) <PUNCT>
# Schamane (Schamane) <PROPN>
#
#
#  (
#
# ) <SPACE>
# Im (in) <ADP>
# Allgemeinen (allgemeinen) <NOUN>
# wird (werden) <AUX>
# die (der) <DET>
# aus (aus) <ADP>
# Sibirien (Sibirien) <PROPN>
# entlehnte (entlehnt) <ADJ>
# Bezeichnung (Bezeichnung) <NOUN>
# Schamane (Schamane) <PROPN>
# verwendet (verwenden) <VERB>
# , (--) <PUNCT>
# um (um) <SCONJ>
# spirituelle (spirituell) <ADJ>
# Spezialisten (Spezialist) <NOUN>
# zu (zu) <PART>
# bezeichnen (bezeichnen) <VERB>
# , (--) <PUNCT>
# die (der) <PRON>
# über (über) <ADP>
# ( (--) <PUNCT>
# angeblich (angeblich) <ADV>
# ) (--) <PUNCT>
# „ (--) <PUNCT>
# magische (magisch) <ADJ>
# “ (--) <PUNCT>
# Fähigkeiten (Fähigkeit) <NOUN>
# als (als) <ADP>
# Vermittler (Vermittler) <NOUN>
# zur (zu) <ADP>
# Geisterwelt (Geisterwelt) <NOUN>
# verfügen.[26][27][10 (verfügen.[26][27][10) <DET>
# ] (]) <X>
# Solche (solcher) <DET>
# Geisterbeschwörer (Geisterbeschwörer) <NOUN>
# sind (sein) <AUX>
# Teil (Teil) <NOUN>
# vieler (vieler) <DET>
# ethnischer (ethnisch) <ADJ>
# Religionen (Religion) <NOUN>
# , (--) <PUNCT>
# aber (aber) <CCONJ>
# auch (auch) <ADV>
# mancher (mancher) <DET>
# volksreligiöser (volksreligiös) <ADJ>
# Ausprägungen (Ausprägung) <NOUN>
# der (der) <DET>
# Weltreligionen.[12 (Weltreligionen.[12) <X>
# ] (]) <NOUN>
# Vornehmlich (Vornehmlich) <ADV>
# bei (bei) <ADP>
# einigen (einiger) <DET>
# indigenen (indigen) <NOUN>
# oder (oder) <CCONJ>
# traditionellen (traditionell) <ADJ>
# lokalen (lokal) <ADJ>
# Gemeinschaften (Gemeinschaft) <NOUN>
# spielen (spielen) <VERB>
# Schamanen (Schaman) <NOUN>
# heute (heute) <ADV>
# noch (noch) <ADV>
# eine (ein) <DET>
# wichtige (wichtig) <ADJ>
# Rolle (Rolle) <NOUN>
# ( (--) <PUNCT>
# → (→) <NOUN>
# „ (--) <PUNCT>
# Traditionelle (Traditionelle) <ADJ>
# spirituelle (spirituell) <ADJ>
# Spezialisten (Spezialist) <NOUN>
# der (der) <DET>
# Gegenwart (Gegenwart) <NOUN>
# im (in) <ADP>
# Licht (Licht) <NOUN>
# der (der) <DET>
# Geschichte (Geschichte) <NOUN>
# “ (--) <PUNCT>
# im (in) <ADP>
# Artikel (Artikel) <NOUN>
# Schamane (Schamane) <PROPN>
# ) (--) <PUNCT>
# . (--) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# Seit (seit) <ADP>
# den (der) <DET>
# ersten (erster) <ADJ>
# Beschreibungen (Beschreibung) <NOUN>
# solcher (solcher) <DET>
# spirituellen (spirituell) <ADJ>
# Experten (Experte) <NOUN>
# in (in) <ADP>
# verschiedenen (verschieden) <ADJ>
# Gesellschaften (Gesellschaft) <NOUN>
# haben (haben) <AUX>
# europäische (europäisch) <ADJ>
# Völkerkundler (Völkerkundler) <NOUN>
# versucht (versuchen) <VERB>
# , (--) <PUNCT>
# Ähnlichkeiten (Ähnlichkeiten) <NOUN>
# und (und) <CCONJ>
# eventuelle (eventuell) <ADJ>
# Muster (Muster) <NOUN>
# zu (zu) <PART>
# erkennen (erkennen) <VERB>
# und (und) <CCONJ>
# Zusammenhänge (Zusammenhang) <NOUN>
# abzuleiten (abzuleiten) <VERB>
# . (--) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# Die (der) <DET>
# Existenz (Existenz) <NOUN>
# eines (ein) <DET>
# Schamanen (Schaman) <NOUN>
# ist (sein) <AUX>
# zweifellos (zweifellos) <ADV>
# eine (ein) <DET>
# Voraussetzung (Voraussetzung) <NOUN>
# für (für) <ADP>
# jegliche (jeglicher) <DET>
# Schamanismus-These (Schamanismus-These) <NOUN>
# , (--) <PUNCT>
# jedoch (jedoch) <ADV>
# nicht (nicht) <PART>
# unbedingt (unbedingt) <ADV>
# der (der) <DET>
# zentrale (zentral) <ADJ>
# Gedanke (Gedanke) <NOUN>
# . (--) <PUNCT>
# Es (es) <PRON>
# geht (gehen) <VERB>
# häufig (häufig) <ADV>
# eher (eher) <ADV>
# um (um) <ADP>
# religiöse (religiös) <ADJ>
# Überzeugungen (Überzeugung) <NOUN>
# , (--) <PUNCT>
# Riten (Rite) <NOUN>
# und (und) <CCONJ>
# Traditionen,[28 (Traditionen,[28) <PROPN>
# ] (]) <PROPN>
# statt (statt) <ADP>
# um (um) <ADP>
# die (der) <DET>
# herausgehobene (herausgehoben) <ADJ>
# Rolle (Rolle) <NOUN>
# des (der) <DET>
# Schamanen (Schaman) <NOUN>
# . (--) <PUNCT>
# Insofern (insofern) <ADV>
# entstanden (entstehen) <VERB>
# die (der) <DET>
# verschiedenen (verschieden) <ADJ>
# , (--) <PUNCT>
# konzeptuell (konzeptuell) <ADV>
# abweichenden (abweichend) <ADJ>
# Definitionen.[3 (Definitionen.[3) <PUNCT>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# Die (der) <DET>
# Schamanen (Schaman) <NOUN>
# sind (sein) <AUX>
# eingebunden (einbinden) <VERB>
# in (in) <ADP>
# die (der) <DET>
# Lebenswelt (Lebenswelt) <NOUN>
# und (und) <CCONJ>
# naturräumliche (naturräumlich) <ADJ>
# Umwelt (Umwelt) <NOUN>
# ihrer (ihr) <DET>
# jeweiligen (jeweilig) <ADJ>
# Kulturen (Kultur) <NOUN>
# und (und) <CCONJ>
# können (können) <AUX>
# nicht (nicht) <PART>
# als (als) <ADP>
# Verkörperung (Verkörperung) <NOUN>
# einer (ein) <DET>
# bestimmten (bestimmt) <ADJ>
# schamanistischen (schamanistisch) <ADJ>
# Religion (Religion) <NOUN>
# oder (oder) <CCONJ>
# Kosmologie (Kosmologie) <NOUN>
# betrachtet (betrachten) <VERB>
# werden.[29 (werden.[29) <PROPN>
# ] (]) <PROPN>
# So (so) <ADV>
# hängt (hängen) <VERB>
# der (der) <DET>
# Schamanismus (Schamanismus) <NOUN>
# eng (eng) <ADV>
# mit (mit) <ADP>
# der (der) <DET>
# Heilung (Heilung) <NOUN>
# von (von) <ADP>
# Kranken (kranke) <NOUN>
# , (--) <PUNCT>
# mit (mit) <ADP>
# Bestattungsriten (Bestattungsrit) <NOUN>
# und (und) <CCONJ>
# mit (mit) <ADP>
# Jagdzauber (Jagdzauber) <NOUN>
# zusammen (zusammen) <ADV>
# . (--) <PUNCT>
# Michael (Michael) <PROPN>
# Lütge (Lütge) <PROPN>
# vergleicht (vergleichen) <VERB>
# seine (sein) <DET>
# Rolle (Rolle) <NOUN>
# mit (mit) <ADP>
# der (der) <DET>
# „ (--) <PUNCT>
# Anamnese (Anamnese) <NOUN>
# des (der) <DET>
# Gemeindepfarrers (Gemeindepfarrer) <NOUN>
# beim (bei) <ADP>
# Kondolenzbesuch (Kondolenzbesuch) <NOUN>
# “ (--) <PUNCT>
# , (--) <PUNCT>
# der (der) <DET>
# biographische (biographisch) <ADJ>
# Bruchstücke (Bruchstücke) <NOUN>
# des (der) <DET>
# Toten (tote) <NOUN>
# aufspürt (aufspüren) <VERB>
# , (--) <PUNCT>
# die (der) <PRON>
# ihn (ihn) <PRON>
# vom (von) <ADP>
# engeren (eng) <ADJ>
# Kreis (Kreis) <NOUN>
# der (der) <DET>
# Angehörigen (angehörige) <NOUN>
# her (her) <ADV>
# „ (--) <PUNCT>
# anwehen (anwehen) <VERB>
# “ (--) <PUNCT>
# . (--) <PUNCT>
# In (in) <ADP>
# anderen (anderer) <ADJ>
# Situationen (Situation) <NOUN>
# praktiziert (praktizieren) <VERB>
# er (er) <PRON>
# „ (--) <PUNCT>
# antizipative (antizipativ) <ADJ>
# [ ([) <PROPN>
# ... (--) <PUNCT>
# ] (]) <PROPN>
# Jagdpropädeutik (Jagdpropädeutik) <NOUN>
# ähnlich (ähnlich) <ADV>
# der (der) <DET>
# schulischen (schulisch) <ADJ>
# Brandschutzübung“.[30 (Brandschutzübung“.[30) <PROPN>
# ] (]) <PROPN>
#
#  (
# ) <SPACE>
# Wissenschaftsgeschichte (Wissenschaftsgeschichte) <NOUN>
#
#  (
# ) <SPACE>
# Sowjetische (sowjetisch) <ADJ>
# Ethnologen (Ethnolog) <NOUN>
# sahen (sehen) <VERB>
# in (in) <ADP>
# den (der) <DET>
# Schamanen (Schaman) <NOUN>
# Männer (Mann) <NOUN>
# , (--) <PUNCT>
# die (der) <PRON>
# mit (mit) <ADP>
# Hilfe (Hilfe) <NOUN>
# religiöser (religiös) <ADJ>
# Rituale (Ritual) <NOUN>
# politische (politisch) <ADJ>
# Macht (Macht) <NOUN>
# gewinnen (gewinnen) <VERB>
# wollten (wollen) <AUX>
# . (--) <PUNCT>
# Tatsächlich (tatsächlich) <ADV>
# gab (geben) <VERB>
# es (es) <PRON>
# ebenso (ebenso) <ADV>
# weibliche (weiblich) <ADJ>
# Schamanen (Schaman) <NOUN>
# und (und) <CCONJ>
# soziopolitisch (soziopolitisch) <ADV>
# standen (stehen) <VERB>
# Geisterbeschwörer (Geisterbeschwörer) <NOUN>
# eher (eher) <ADV>
# außerhalb (außerhalb) <ADP>
# der (der) <DET>
# Gesellschaft (Gesellschaft) <NOUN>
#
#  (
# ) <SPACE>
# Mircea (Mircea) <PROPN>
# Eliade (Eliade) <PROPN>
# gilt (gelten) <VERB>
# als (als) <ADP>
# Begründer (Begründer) <NOUN>
# der (der) <DET>
# „ (--) <PUNCT>
# Schamanismus-These (Schamanismus-These) <NOUN>
# “ (--) <PUNCT>
# , (--) <PUNCT>
# auf (auf) <ADP>
# die (der) <PRON>
# sich (sich) <PRON>
# heute (heute) <ADV>
# insbesondere (insbesondere) <ADV>
# der (der) <DET>
# esoterische (esoterisch) <ADJ>
# Neoschamanismus (Neoschamanismus) <NOUN>
# beruft (berufen) <VERB>
# . (--) <PUNCT>
# Die (der) <DET>
# Gültigkeit (Gültigkeit) <NOUN>
# seiner (sein) <DET>
# Theorie (Theorie) <NOUN>
# und (und) <CCONJ>
# die (der) <DET>
# Seriosität (Seriosität) <NOUN>
# seiner (sein) <DET>
# Arbeit (Arbeit) <NOUN>
# ist (sein) <AUX>
# in (in) <ADP>
# der (der) <DET>
# Wissenschaft (Wissenschaft) <NOUN>
# stark (stark) <ADV>
# umstritten.[31 (umstritten.[31) <ADJ>
# ] (]) <NOUN>
#
#  (
# ) <SPACE>
# Mexikanischer (Mexikanischer) <ADJ>
# Kahlkopf (Kahlkopf) <PROPN>
# , (--) <PUNCT>
# der (der) <DET>
# erste (erster) <ADJ>
# populäre (populär) <ADJ>
# „ (--) <PUNCT>
# Rauschpilz (Rauschpilz) <NOUN>
# “ (--) <PUNCT>
#
#  (
# ) <SPACE>
# Die (der) <DET>
# Hippiebewegung (Hippiebewegung) <NOUN>
# ebnete (ebnen) <VERB>
# den (der) <DET>
# Weg (Weg) <NOUN>
# für (für) <ADP>
# eine (ein) <DET>
# neue (neu) <ADJ>
# Spiritualität (Spiritualität) <NOUN>
# im (in) <ADP>
# Westen (Westen) <NOUN>
#
#  (
# ) <SPACE>
# Phantasie-Bildnis (Phantasie-Bildnis) <NOUN>
# der (der) <DET>
# literarischen (literarisch) <ADJ>
# Schamanengestalt (Schamanengestalt) <NOUN>
# Don (Don) <PROPN>
# Juan (Juan) <PROPN>
# Matus (Matus) <PROPN>
# ( (--) <PUNCT>
# Jacob (Jacob) <PROPN>
# Wayne (Wayne) <PROPN>
# Bryner (Bryner) <PROPN>
# ) (--) <PUNCT>
# , (--) <PUNCT>
# die (der) <PRON>
# den (der) <DET>
# Schriftsteller (Schriftsteller) <NOUN>
# Castañeda (Castañeda) <PROPN>
# weltberühmt (weltberühmt) <ADV>
# machte (machen) <VERB>
#
#  (
# ) <SPACE>
# Tuwinischer (Tuwinischer) <NOUN>
# Schamane (Schamane) <PROPN>
# : (--) <PUNCT>
# Traditionelles (traditionell) <ADJ>
# Wissen (wissen) <NOUN>
# wird (werden) <AUX>
# durch (durch) <ADP>
# neoschamanistische (neoschamanistisch) <ADJ>
# Einflüsse (Einfluß) <NOUN>
# verfälscht (verfälscht) <VERB>
#
#  (
# ) <SPACE>
# → (→) <PROPN>
# Hauptartikel (Hauptartikel) <PROPN>
# : (--) <PUNCT>
# Schamanismusforschung (Schamanismusforschung) <NOUN>
#
#
#      (
#
#     ) <SPACE>
# „ (--) <PUNCT>
# Schamanismus (Schamanismus) <NOUN>
# ist (sein) <AUX>
# keine (kein) <DET>
# einheitliche (einheitlich) <ADJ>
# Religion (Religion) <NOUN>
# , (--) <PUNCT>
# sondern (sondern) <CCONJ>
# eine (ein) <DET>
# kulturübergreifende (kulturübergreifend) <ADJ>
# Form (Form) <NOUN>
# religiöser (religiös) <ADJ>
# Wahrnehmung (Wahrnehmung) <NOUN>
# und (und) <CCONJ>
# Praxis (Praxis) <NOUN>
# . (--) <PUNCT>
# “ (--) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# – (--) <PUNCT>
# Piers (Pier) <PROPN>
# Vitebsky[7 (Vitebsky[7) <PROPN>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# Seit (seit) <ADP>
# Ende (Ende) <NOUN>
# des (der) <DET>
# 17. (17.) <ADJ>
# Jahrhunderts (Jahrhundert) <NOUN>
# gibt (geben) <VERB>
# es (es) <PRON>
# detaillierte (detailliert) <ADJ>
# Berichte (Bericht) <NOUN>
# über (über) <ADP>
# die (der) <DET>
# Schamanen (Schaman) <NOUN>
# Sibiriens (Sibirien) <PROPN>
# und (und) <CCONJ>
# ihre (ihr) <DET>
# Praktiken (Praktik) <NOUN>
# . (--) <PUNCT>
# Die (der) <DET>
# Einstellung (Einstellung) <NOUN>
# der (der) <DET>
# Europäer (Europäer) <NOUN>
# dazu (dazu) <ADV>
# pendelte (pendelen) <VERB>
# mehrmals (mehrmals) <ADV>
# zwischen (zwischen) <ADP>
# Hochachtung (Hochachtung) <NOUN>
# und (und) <CCONJ>
# Verachtung (Verachtung) <NOUN>
# hin (hin) <ADV>
# und (und) <CCONJ>
# her (her) <ADV>
# . (--) <PUNCT>
# Anfangs (anfangs) <ADV>
# riefen (rufen) <VERB>
# diese (dieser) <DET>
# Berichte (Bericht) <NOUN>
# nur (nur) <ADV>
# Abneigung (Abneigung) <NOUN>
# und (und) <CCONJ>
# Unverständnis (Unverständnis) <NOUN>
# hervor.[32 (hervor.[32) <PROPN>
# ] (]) <NOUN>
# Im (in) <ADP>
# Verlauf (Verlauf) <NOUN>
# der (der) <DET>
# deutschen (deutsch) <ADJ>
# Romantik (Romantik) <NOUN>
# schlug (schlagen) <VERB>
# das (der) <DET>
# Pendel (Pendel) <NOUN>
# in (in) <ADP>
# die (der) <DET>
# entgegengesetzte (entgegengesetzt) <ADJ>
# Richtung (Richtung) <NOUN>
# und (und) <CCONJ>
# Schamanen (Schaman) <NOUN>
# wurden (werden) <AUX>
# als (als) <ADP>
# „ (--) <PUNCT>
# charismatische (charismatisch) <ADJ>
# Genies (Genies) <NOUN>
# “ (--) <PUNCT>
# verklärt (verklären) <VERB>
# . (--) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# Auch (auch) <ADV>
# die (der) <DET>
# wissenschaftliche (wissenschaftlich) <ADJ>
# Forschung (Forschung) <NOUN>
# im (in) <ADP>
# Rahmen (Rahmen) <NOUN>
# der (der) <DET>
# Völkerkunde (Völkerkund) <NOUN>
# ist (sein) <AUX>
# von (von) <ADP>
# dieser (dieser) <DET>
# großen (groß) <ADJ>
# Diskrepanz (Diskrepanz) <NOUN>
# gekennzeichnet (kennzeichnen) <VERB>
# : (--) <PUNCT>
# Zunächst (zunächst) <ADV>
# wurden (werden) <AUX>
# Schamanen (Schaman) <NOUN>
# als (als) <ADP>
# krankhaft (krankhaft) <ADV>
# psychotisch (psychotisch) <ADV>
# angesehen (ansehen) <VERB>
# und (und) <CCONJ>
# ihre (ihr) <DET>
# Ausdrucksformen (Ausdrucksform) <NOUN>
# als (als) <ADP>
# „ (--) <PUNCT>
# arktische (arktisch) <ADJ>
# Hysterie (Hysterie) <NOUN>
# “ (--) <PUNCT>
# bezeichnet.[33 (bezeichnet.[33) <PROPN>
# ] (]) <PROPN>
# Später (spät) <ADV>
# wurden (werden) <AUX>
# Epilepsie (Epilepsie) <NOUN>
# oder (oder) <CCONJ>
# Schizophrenie (Schizophrenie) <NOUN>
# in (in) <ADP>
# Beziehung (Beziehung) <NOUN>
# zum (zu) <ADP>
# Schamanentum (Schamanentum) <NOUN>
# gesetzt.[34 (gesetzt.[34) <X>
# ] (]) <X>
#
#
#  (
#
# ) <SPACE>
# Doch (doch) <CCONJ>
# bereits (bereits) <ADV>
# Anfang (Anfang) <NOUN>
# des (der) <DET>
# 20. (20.) <ADJ>
# Jahrhunderts (Jahrhundert) <NOUN>
# wurden (werden) <AUX>
# die (der) <DET>
# besondere (besonderer) <ADJ>
# gesellschaftliche (gesellschaftlich) <ADJ>
# Stellung (Stellung) <NOUN>
# des (der) <DET>
# sibirischen (sibirisch) <ADJ>
# „ (--) <PUNCT>
# Master (Master) <PROPN>
# of (of) <PROPN>
# Spirits (Spirits) <PROPN>
# “ (--) <PUNCT>
# und (und) <CCONJ>
# die (der) <DET>
# Legitimation (Legitimation) <NOUN>
# seines (sein) <DET>
# Handelns (handeln) <NOUN>
# im (in) <ADP>
# jeweiligen (jeweilig) <ADJ>
# kulturellen (kulturell) <ADJ>
# und (und) <CCONJ>
# historischen (historisch) <ADJ>
# Kontext (Kontext) <NOUN>
# aus (aus) <ADP>
# soziologischer (soziologisch) <ADJ>
# und (und) <CCONJ>
# psychologischer (psychologisch) <ADJ>
# Sicht (Sicht) <NOUN>
# detailliert (detailliert) <ADV>
# untersucht (untersuchen) <VERB>
# : (--) <PUNCT>
# Er (er) <PRON>
# sei (sein) <AUX>
# legitimiert (legitimieren) <VERB>
# , (--) <PUNCT>
# Techniken (Technik) <NOUN>
# auszuführen (ausführen) <VERB>
# , (--) <PUNCT>
# die (der) <PRON>
# auch (auch) <ADV>
# andere (anderer) <ADJ>
# Gesellschaftsmitglieder (Gesellschaftsmitglied) <NOUN>
# im (in) <ADP>
# Alltag (Alltag) <NOUN>
# beherrschten (beherrschen) <VERB>
# . (--) <PUNCT>
# Shirokogoroff (Shirokogoroff) <PROPN>
# fand (finden) <VERB>
# bei (bei) <ADP>
# seinen (sein) <DET>
# Feldforschungen (Feldforschung) <NOUN>
# unter (unter) <ADP>
# Ewenken (Ewenk) <NOUN>
# und (und) <CCONJ>
# Mandschu (Mandschu) <NOUN>
# , (--) <PUNCT>
# dass (dass) <SCONJ>
# es (es) <PRON>
# sich (sich) <PRON>
# bei (bei) <ADP>
# den (der) <DET>
# Schamanen (Schaman) <NOUN>
# zwar (zwar) <ADV>
# häufig (häufig) <ADV>
# um (um) <ADP>
# neurotische (neurotisch) <ADJ>
# Personen (Person) <NOUN>
# handle (handeln) <VERB>
# ; (--) <PUNCT>
# er (er) <PRON>
# grenzte (grenzen) <VERB>
# sich (sich) <PRON>
# aber (aber) <ADV>
# von (von) <ADP>
# dem (der) <DET>
# damaligen (damalig) <ADJ>
# verbreiteten (verbreitet) <ADJ>
# Erklärungsmodell (Erklärungsmodell) <NOUN>
# für (für) <ADP>
# das (der) <DET>
# Handeln (handeln) <NOUN>
# der (der) <DET>
# Schamanen (Schaman) <NOUN>
# ab (ab) <ADP>
# : (--) <PUNCT>
# Die (der) <DET>
# Trancen (Trance) <NOUN>
# , (--) <PUNCT>
# rituelle (rituell) <ADJ>
# Ekstasen (Ekstase) <NOUN>
# oder (oder) <CCONJ>
# „ (--) <PUNCT>
# Anfälle (Anfälle) <NOUN>
# “ (--) <PUNCT>
# der (der) <DET>
# Schamanen (Schaman) <NOUN>
# seien (sein) <AUX>
# nicht (nicht) <PART>
# Ausdruck (Ausdruck) <NOUN>
# von (von) <ADP>
# Hysterie (Hysterie) <NOUN>
# oder (oder) <CCONJ>
# Besessenheit (Besessenheit) <NOUN>
# , (--) <PUNCT>
# sondern (sondern) <CCONJ>
# wohlinszenierte (wohlinszenieren) <VERB>
# , (--) <PUNCT>
# kulturell (kulturell) <ADV>
# codierte (codierte) <ADJ>
# performative (performativ) <ADJ>
# Konfliktlösungen (Konfliktlösunge) <NOUN>
# , (--) <PUNCT>
# die (der) <PRON>
# z. (z.) <ADP>
# B. (B.) <NOUN>
# gegen (gegen) <ADP>
# die (der) <DET>
# russische (russisch) <ADJ>
# Fremdherrschaft (Fremdherrschaft) <NOUN>
# eingesetzt (einsetzen) <VERB>
# wurden[35 (wurden[35) <PROPN>
# ] (]) <PROPN>
# – (--) <PUNCT>
# also (also) <ADV>
# historisch (historisch) <ADV>
# spezifisch (spezifisch) <ADV>
# ausgeprägte (ausgeprägt) <ADJ>
# Phänomene (Phänomen) <NOUN>
# . (--) <PUNCT>
# So (so) <ADV>
# wurden (werden) <AUX>
# in (in) <ADP>
# der (der) <DET>
# Sowjetunion (Sowjetunion) <PROPN>
# Schamanen (Schaman) <NOUN>
# als (als) <ADP>
# Scharlatane (Scharlatane) <NOUN>
# verunglimpft (verunglimpfen) <VERB>
# , (--) <PUNCT>
# die (der) <PRON>
# sich (sich) <PRON>
# angeblich (angeblich) <ADV>
# mit (mit) <ADP>
# Hilfe (Hilfe) <NOUN>
# religiöser (religiös) <ADJ>
# Rituale (Ritual) <NOUN>
# Macht (Macht) <NOUN>
# verschaffen (verschaffen) <VERB>
# wollten.[36 (wollten.[36) <X>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# Auch (auch) <ADV>
# die (der) <DET>
# „ (--) <PUNCT>
# Geistermänner (Geistermänner) <NOUN>
# “ (--) <PUNCT>
# oder (oder) <CCONJ>
# „ (--) <PUNCT>
# Zaubermänner (Zaubermänner) <NOUN>
# “ (--) <PUNCT>
# Nordamerikas (Nordamerikas) <PROPN>
# übernahmen (übernehmen) <VERB>
# im (in) <ADP>
# Verlauf (Verlauf) <NOUN>
# der (der) <DET>
# Westwanderung (Westwanderung) <NOUN>
# des (der) <DET>
# weißen (weiß) <ADJ>
# Kolonisten (Kolonist) <NOUN>
# immer (immer) <ADV>
# wieder (wieder) <ADV>
# die (der) <DET>
# Rolle (Rolle) <NOUN>
# politischer (politisch) <ADJ>
# Führer (Führer) <NOUN>
# und (und) <CCONJ>
# setzten (setzen) <VERB>
# sich (sich) <PRON>
# an (an) <ADP>
# die (der) <DET>
# Spitze (Spitze) <NOUN>
# nativistischer (nativistisch) <ADJ>
# Bewegungen (Bewegung) <NOUN>
# . (--) <PUNCT>
# So (so) <ADV>
# wurde (werden) <AUX>
# schon (schon) <ADV>
# 1680 (1680) <NUM>
# ein (ein) <DET>
# zeitweise (zeitweise) <ADV>
# erfolgreicher (erfolgreich) <ADJ>
# Aufstand (Aufstand) <NOUN>
# des (der) <DET>
# Tewa (Tewa) <NOUN>
# in (in) <ADP>
# New (New) <PROPN>
# Mexico (Mexico) <PROPN>
# gegen (gegen) <ADP>
# die (der) <DET>
# spanischen (spanisch) <ADJ>
# Kolonisten (Kolonist) <NOUN>
# vom (von) <ADP>
# Medizinmann (Medizinmann) <NOUN>
# El (El) <PROPN>
# Popé (Popé) <PROPN>
# organisiert (organisieren) <VERB>
# . (--) <PUNCT>
# In (in) <ADP>
# afrikanischen (afrikanisch) <ADJ>
# Revolten (Revolt) <NOUN>
# gegen (gegen) <ADP>
# die (der) <DET>
# Kolonialherren (Kolonialherr) <NOUN>
# spielten (spielen) <VERB>
# spirituelle (spirituell) <ADJ>
# Vermittler (Vermittler) <NOUN>
# häufig (häufig) <ADV>
# eine (ein) <DET>
# Rolle (Rolle) <NOUN>
# als (als) <ADP>
# Anführer (Anführer) <NOUN>
# , (--) <PUNCT>
# so (so) <ADV>
# der (der) <DET>
# angeblich (angeblich) <ADV>
# vom (von) <ADP>
# Geist (Geist) <NOUN>
# Hongo (Hongo) <PROPN>
# des (der) <DET>
# Schlangengotts (Schlangengott) <NOUN>
# besessene (besessen) <ADJ>
# Heiler (Heiler) <NOUN>
# Kinjikitile (Kinjikitil) <ADJ>
# Ngwale (Ngwale) <NOUN>
# im (in) <ADP>
# Maji-Maji-Aufstand (Maji-Maji-Aufstand) <NOUN>
# 1905–1907. (1905–1907.) <NUM>
# Wer (wer) <PRON>
# zeigte (zeigen) <VERB>
# , (--) <PUNCT>
# dass (dass) <SCONJ>
# er (er) <PRON>
# von (von) <ADP>
# einem (ein) <DET>
# Hongo (Hongo) <NOUN>
# besessen (besessen) <VERB>
# war (sein) <AUX>
# , (--) <PUNCT>
# konnte (können) <AUX>
# die (der) <DET>
# Religion (Religion) <NOUN>
# und (und) <CCONJ>
# Politik (Politik) <NOUN>
# seiner (sein) <DET>
# Ethnie (Ethnie) <NOUN>
# in (in) <ADP>
# hohem (hoch) <ADJ>
# Maße (Maß) <NOUN>
# beeinflussen (beeinflussen) <VERB>
# . (--) <PUNCT>
# Auch (auch) <ADV>
# Lévi-Strauss (Lévi-Strauss) <PROPN>
# berichtet (berichten) <VERB>
# von (von) <ADP>
# Schamanen (Schaman) <NOUN>
# , (--) <PUNCT>
# die (der) <PRON>
# in (in) <ADP>
# Konkurrenz (Konkurrenz) <NOUN>
# zu (zu) <ADP>
# Stammesführern (Stammesführ) <NOUN>
# traten.[37 (traten.[37) <NOUN>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# Mit (mit) <ADP>
# der (der) <DET>
# Aufgabe (Aufgabe) <NOUN>
# der (der) <DET>
# als (als) <ADP>
# rassistisch (rassistisch) <ADV>
# verpönten (verpönt) <ADJ>
# deutschen (deutsch) <ADJ>
# Kulturkreislehre (Kulturkreislehr) <NOUN>
# und (und) <CCONJ>
# der (der) <DET>
# evolutionistischen (evolutionistisch) <ADJ>
# „ (--) <PUNCT>
# Stufen-Ideologie (Stufen-Ideologie) <NOUN>
# “ (--) <PUNCT>
# in (in) <ADP>
# den (der) <DET>
# marxistisch (marxistisch) <ADV>
# beeinflussten (beeinflusst) <ADJ>
# Staaten (Staat) <NOUN>
# setzte (setzen) <VERB>
# sich (sich) <PRON>
# in (in) <ADP>
# der (der) <DET>
# Ethnologie (Ethnologie) <NOUN>
# eine (ein) <DET>
# respektvollere (respektvoll) <ADJ>
# Haltung (Haltung) <NOUN>
# zu (zu) <ADP>
# den (der) <DET>
# Kulturen (Kultur) <NOUN>
# der (der) <DET>
# sogenannten (sogenannter) <ADJ>
# Naturvölker (Naturvölker) <NOUN>
# durch.[38 (durch.[38) <PROPN>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# In (in) <ADP>
# Nordamerika (Nordamerika) <PROPN>
# kam (kommen) <VERB>
# es (es) <PRON>
# bereits (bereits) <ADV>
# um (um) <ADP>
# die (der) <DET>
# Wende (Wende) <NOUN>
# zum (zu) <ADP>
# 20. (20.) <ADJ>
# Jahrhundert (Jahrhundert) <NOUN>
# zu (zu) <ADP>
# einer (ein) <DET>
# gewissen (gewiß) <ADJ>
# Romantisierung (Romantisierung) <NOUN>
# und (und) <CCONJ>
# Idealisierung (Idealisierung) <NOUN>
# der (der) <DET>
# indianischen (indianisch) <ADJ>
# Kulturen (Kultur) <NOUN>
# Nordamerikas (Nordamerika) <PROPN>
# und (und) <CCONJ>
# mit (mit) <ADP>
# ihnen (ihnen) <PRON>
# der (der) <DET>
# spirituell-religiösen (spirituell-religiös) <ADJ>
# Vorstellungen (Vorstellung) <NOUN>
# , (--) <PUNCT>
# die (der) <PRON>
# bald (bald) <ADV>
# mit (mit) <ADP>
# dem (der) <DET>
# Ekstase-Schamanismus (Ekstase-Schamanismus) <NOUN>
# Sibiriens (Sibirien) <PROPN>
# und (und) <CCONJ>
# später (spät) <ADV>
# auch (auch) <ADV>
# mit (mit) <ADP>
# den (der) <DET>
# okkulten (okkult) <ADJ>
# Praktiken (Praktik) <NOUN>
# Südamerikas (Südamerika) <PROPN>
# bis (bis) <ADP>
# hin (hin) <ADV>
# zu (zu) <ADP>
# denen (der) <PRON>
# der (der) <DET>
# Selk (Selk) <PROPN>
# ’ (’) <PUNCT>
# nam (nam) <ADP>
# auf (auf) <ADP>
# Feuerland (Feuerland) <PROPN>
# als (als) <ADP>
# shamanistic (Shamanistic) <PROPN>
# complex (Complex) <NOUN>
# zusammengefasst (zusammengefasst) <VERB>
# wurden (werden) <AUX>
# . (--) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# Der (der) <DET>
# rumänische (rumänisch) <ADJ>
# Religionswissenschaftler (Religionswissenschaftler) <NOUN>
# und (und) <CCONJ>
# Roman-Autor (Roman-Autor) <NOUN>
# Mircea (Mircea) <PROPN>
# Eliade (Eliade) <PROPN>
# war (sein) <AUX>
# es (es) <PRON>
# schließlich (schließlich) <ADV>
# , (--) <PUNCT>
# der (der) <PRON>
# 1951 (1951) <NUM>
# den (der) <DET>
# Begriff (Begriff) <NOUN>
# „ (--) <PUNCT>
# Schamanismus (Schamanismus) <NOUN>
# “ (--) <PUNCT>
# entscheidend (entscheidend) <ADV>
# prägte (prägen) <VERB>
# und (und) <CCONJ>
# in (in) <ADP>
# akademischen (akademisch) <ADJ>
# und (und) <CCONJ>
# intellektuellen (intellektuell) <ADJ>
# Kreisen (Kreis) <NOUN>
# weltweit (weltweit) <ADV>
# populär (populär) <ADV>
# machte (machen) <VERB>
# . (--) <PUNCT>
# Eliade (Eliade) <PROPN>
# sah (sehen) <VERB>
# darin (darin) <ADV>
# die (der) <DET>
# älteste (alt) <ADJ>
# Form (Form) <NOUN>
# ...
# rencontre (rencontre) <X>
# des (der) <DET>
# chamans (Chaman) <X>
# un (un) <X>
# peu (peu) <X>
# partout (partout) <ADV>
# dans (dans) <PROPN>
# le (le) <PROPN>
# monde (monde) <PROPN>
# … (--) <PUNCT>
# “ (--) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# – (--) <PUNCT>
# Mircea (Mircea) <PROPN>
# Eliade[3 (Eliade[3) <PROPN>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# Dieses (dieser) <DET>
# Zitat (Zitat) <NOUN>
# des (der) <DET>
# rumänischen (rumänisch) <ADJ>
# Religionswissenschaftlers (Religionswissenschaftler) <NOUN>
# Mircea (Mircea) <PROPN>
# Eliade (Eliade) <PROPN>
# gibt (geben) <VERB>
# seinen (sein) <DET>
# zentralen (zentral) <ADJ>
# Gedanken (Gedanke) <NOUN>
# wieder (wieder) <ADV>
# : (--) <PUNCT>
# „ (--) <PUNCT>
# Es (es) <PRON>
# gibt (geben) <VERB>
# keinen (kein) <DET>
# bestimmten (bestimmt) <ADJ>
# geographischen (geographisch) <ADJ>
# Raum (Raum) <NOUN>
# ( (--) <PUNCT>
# des (der) <DET>
# Schamanismus (Schamanismus) <NOUN>
# ) (--) <PUNCT>
# , (--) <PUNCT>
# denn (denn) <CCONJ>
# die (der) <DET>
# schamanische (schamanisch) <ADJ>
# Trance (Trance) <NOUN>
# ist (sein) <AUX>
# ein (ein) <DET>
# spontanes (spontan) <ADJ>
# und (und) <CCONJ>
# organisches (organisch) <ADJ>
# Phänomen (Phänomen) <NOUN>
# , (--) <PUNCT>
# das (der) <PRON>
# man (man) <PRON>
# bei (bei) <ADP>
# allen (aller) <DET>
# Schamanen (Schaman) <NOUN>
# auf (auf) <ADP>
# der (der) <DET>
# Welt (Welt) <NOUN>
# antrifft (antrifft) <VERB>
# . (--) <PUNCT>
# “ (--) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# Aus (aus) <ADP>
# seinen (sein) <DET>
# umfangreichen (umfangreich) <ADJ>
# kulturvergleichenden (kulturvergleichend) <ADJ>
# Recherchen (Recherche) <NOUN>
# in (in) <ADP>
# russischen (russisch) <ADJ>
# und (und) <CCONJ>
# finnischen (finnisch) <ADJ>
# Ethnographien (Ethnographium) <NOUN>
# schuf (schaffen) <VERB>
# er (er) <PRON>
# einen (ein) <DET>
# Idealtypus (Idealtypus) <NOUN>
# des (der) <DET>
# Schamanen (Schaman) <NOUN>
# . (--) <PUNCT>
# Er (er) <PRON>
# konzipierte (konzipieren) <VERB>
# den (der) <DET>
# Schamanismus (Schamanismus) <NOUN>
# als (als) <ADP>
# das (der) <DET>
# weltweit (weltweit) <ADV>
# verbreitete (verbreitet) <ADJ>
# Ur-Phänomen (Ur-Phänomus) <NOUN>
# der (der) <DET>
# menschlichen (menschlich) <ADJ>
# Religiosität (Religiosität) <NOUN>
# und (und) <CCONJ>
# erhob (erheben) <VERB>
# die (der) <DET>
# ( (--) <PUNCT>
# passive (passiv) <ADJ>
# ) (--) <PUNCT>
# ekstatische (ekstatisch) <ADJ>
# Trance (Trance) <NOUN>
# mit (mit) <ADP>
# dem (der) <DET>
# „ (--) <PUNCT>
# Seelenflug (Seelenflug) <NOUN>
# in (in) <ADP>
# die (der) <DET>
# Geisterwelt (Geisterwelt) <NOUN>
# “ (--) <PUNCT>
# zum (zu) <ADP>
# zentralen (zentral) <ADJ>
# Merkmal (Merkmal) <NOUN>
# aller (aller) <DET>
# schamanischen (schamanisch) <ADJ>
# Phänomene (Phänomen) <NOUN>
# . (--) <PUNCT>
# Darüber (darüber) <ADV>
# hinaus (hinaus) <ADP>
# hielt (halten) <VERB>
# er (er) <PRON>
# die (der) <DET>
# klassisch-sibirische (klassisch-sibirisch) <ADJ>
# Kosmologie (Kosmologie) <NOUN>
# für (für) <ADP>
# eine (ein) <DET>
# Universalie (Universalie) <NOUN>
# , (--) <PUNCT>
# die (der) <PRON>
# in (in) <ADP>
# vielen (vieler) <DET>
# Kulturen (Kultur) <NOUN>
# durch (durch) <ADP>
# Fremdeinflüsse (Fremdeinfluß) <NOUN>
# überdeckt (überdecken) <VERB>
# sei (sein) <AUX>
# . (--) <PUNCT>
# Eliade (Eliade) <PROPN>
# hob (heben) <VERB>
# überdies (überdies) <ADV>
# deutlich (deutlich) <ADV>
# hervor (hervor) <ADV>
# , (--) <PUNCT>
# dass (dass) <SCONJ>
# für (für) <ADP>
# den (der) <DET>
# Urmenschen (Urmensch) <NOUN>
# sowie (sowie) <CCONJ>
# heutige (heutig) <ADJ>
# „ (--) <PUNCT>
# Naturvölker (Naturvölker) <NOUN>
# “ (--) <PUNCT>
# ein (ein) <DET>
# mystisch-sakraler (mystisch-sakral) <ADJ>
# Zustand (Zustand) <NOUN>
# kennzeichnend (kennzeichnend) <ADV>
# sei (sein) <AUX>
# , (--) <PUNCT>
# der (der) <PRON>
# einen (ein) <DET>
# direkten (direkt) <ADJ>
# Kontakt (Kontakt) <NOUN>
# zum (zu) <ADP>
# Göttlichen (göttlichen) <NOUN>
# ermöglicht (ermöglichen) <VERB>
# habe (haben) <AUX>
# . (--) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# Mit (mit) <ADP>
# seinem (sein) <DET>
# Werk (Werk) <NOUN>
# Schamanismus (Schamanismus) <NOUN>
# und (und) <CCONJ>
# archaische (archaisch) <ADJ>
# Ekstasetechnik (Ekstasetechnik) <NOUN>
# ( (--) <PUNCT>
# Erstausgabe (Erstausgabe) <NOUN>
# auf (auf) <ADP>
# Französisch (französische) <NOUN>
# 1957 (1957) <NUM>
# ) (--) <PUNCT>
# löste (lösen) <VERB>
# Eliade (Eliade) <PROPN>
# 1964 (1964) <NUM>
# bei (bei) <ADP>
# der (der) <DET>
# Veröffentlichung (Veröffentlichung) <NOUN>
# in (in) <ADP>
# den (der) <DET>
# USA (USA) <PROPN>
# in (in) <ADP>
# intellektuellen (intellektuell) <ADJ>
# Kreisen (Kreis) <NOUN>
# Begeisterung (Begeisterung) <NOUN>
# für (für) <ADP>
# ein (ein) <DET>
# Thema (Thema) <NOUN>
# aus (aus) <ADP>
# , (--) <PUNCT>
# das (der) <PRON>
# bis (bis) <ADP>
# dahin (dahin) <ADV>
# nur (nur) <ADV>
# Religionswissenschaftler (Religionswissenschaftler) <NOUN>
# am (an) <ADP>
# Rande (Rand) <NOUN>
# interessiert (interessieren) <VERB>
# hatte (haben) <AUX>
# . (--) <PUNCT>
# Dies (dieser) <PRON>
# lag (liegen) <VERB>
# nicht (nicht) <PART>
# nur (nur) <ADV>
# am (an) <ADP>
# Inhalt (Inhalt) <NOUN>
# seiner (sein) <DET>
# Studien (Studie) <NOUN>
# , (--) <PUNCT>
# sondern (sondern) <CCONJ>
# mindestens (mindestens) <ADV>
# ebenso (ebenso) <ADV>
# an (an) <ADP>
# der (der) <DET>
# ungewöhnlichen (ungewöhnlich) <ADJ>
# Herangehensweise (Herangehensweise) <NOUN>
# : (--) <PUNCT>
# Eliade (eliade) <ADV>
# führte (führen) <VERB>
# die (der) <DET>
# ethnologischen (ethnologisch) <ADJ>
# , (--) <PUNCT>
# philosophischen (philosophisch) <ADJ>
# , (--) <PUNCT>
# religionswissenschaftlichen (religionswissenschaftlich) <ADJ>
# und (und) <CCONJ>
# psychologischen (psychologisch) <ADJ>
# Perspektiven (Perspektive) <NOUN>
# in (in) <ADP>
# einer (ein) <DET>
# Synthese (Synthese) <NOUN>
# aus (aus) <ADP>
# empirischer (empirisch) <ADJ>
# Analyse (Analyse) <NOUN>
# und (und) <CCONJ>
# imaginativer (imaginativ) <ADJ>
# Religionsphilosophie (Religionsphilosophie) <NOUN>
# zusammen (zusammen) <ADV>
# . (--) <PUNCT>
# Lange (lang) <ADJ>
# Zeit (Zeit) <NOUN>
# galt (gelten) <VERB>
# seine (sein) <DET>
# These (These) <NOUN>
# als (als) <ADP>
# das (der) <DET>
# Standardwerk (Standardwerk) <NOUN>
# zum (zu) <ADP>
# Schamanismus (Schamanismus) <NOUN>
# . (--) <PUNCT>
# Es (es) <PRON>
# trug (tragen) <VERB>
# entscheidend (entscheidend) <ADV>
# zur (zu) <ADP>
# Rehabilitation (Rehabilitation) <NOUN>
# spiritueller (spirituell) <ADV>
# Praktiker (Praktiker) <NOUN>
# bei (bei) <ADP>
# , (--) <PUNCT>
# die (der) <PRON>
# bis (bis) <ADP>
# dato (dato) <X>
# als (als) <ADP>
# Geisteskranke (Geisteskranke) <NOUN>
# oder (oder) <CCONJ>
# Scharlatane (Scharlatane) <NOUN>
# angesehen (ansehen) <VERB>
# wurden (werden) <AUX>
# . (--) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# Seit (seit) <ADP>
# den (der) <DET>
# 1990er (1990er) <NUM>
# Jahren (Jahr) <NOUN>
# wurde (werden) <AUX>
# es (es) <PRON>
# in (in) <ADP>
# der (der) <DET>
# Ethnologie (Ethnologie) <NOUN>
# jedoch (jedoch) <ADV>
# mehr (mehr) <ADV>
# und (und) <CCONJ>
# mehr (mehr) <PRON>
# verpönt (verpönen) <VERB>
# . (--) <PUNCT>
# Kunsthistoriker (Kunsthistoriker) <NOUN>
# , (--) <PUNCT>
# Literaturwissenschaftler (Literaturwissenschaftler) <NOUN>
# sowie (sowie) <CCONJ>
# neoschamanistische (neoschamanistisch) <ADJ>
# und (und) <CCONJ>
# populärwissenschaftliche (populärwissenschaftlich) <ADJ>
# Autoren (Autor) <NOUN>
# berufen (berufen) <VERB>
# sich (sich) <PRON>
# allerdings (allerdings) <ADV>
# nach (nach) <ADV>
# wie (wie) <CCONJ>
# vor (vor) <ADV>
# auf (auf) <ADP>
# Eliade (Eliade) <NOUN>
# , (--) <PUNCT>
# obwohl (obwohl) <SCONJ>
# die (der) <DET>
# Kritikpunkte (Kritikpunkt) <NOUN>
# seine (sein) <DET>
# These (These) <NOUN>
# weitgehend (weitgehend) <ADV>
# demontieren.[82 (demontieren.[82) <PROPN>
# ] (]) <PROPN>
#
#  (
# ) <SPACE>
# Kritik (Kritik) <NOUN>
#
#  (
# ) <SPACE>
# Kritiker (Kritiker) <NOUN>
# erkennen (erkennen) <VERB>
# christliche (christlich) <ADJ>
# Motive (Motiv) <NOUN>
# ( (--) <PUNCT>
# Paradiesischer (Paradiesischer) <ADJ>
# Zustand (Zustand) <NOUN>
# , (--) <PUNCT>
# Sündenfall (Sündenfall) <PROPN>
# ) (--) <PUNCT>
# und (und) <CCONJ>
# romantische (romantisch) <ADJ>
# Verklärung (Verklärung) <NOUN>
# in (in) <ADP>
# Eliades (Eliad) <PROPN>
# Werk (Werk) <NOUN>
#
#
#  (
#
# ) <SPACE>
# Da (da) <SCONJ>
# sich (sich) <PRON>
# Eliade (Eliade) <NOUN>
# vollkommen (vollkommen) <ADV>
# auf (auf) <ADP>
# seinen (sein) <DET>
# ganzheitlich (ganzheitlich) <ADV>
# religionswissenschaftlichen (religionswissenschaftlich) <ADJ>
# Ansatz (Ansatz) <NOUN>
# konzentrieren (konzentrieren) <VERB>
# wollte (wollen) <AUX>
# , (--) <PUNCT>
# verzichtete (verzichten) <VERB>
# er (er) <PRON>
# darauf (darauf) <ADV>
# , (--) <PUNCT>
# den (der) <DET>
# historischen (historisch) <ADJ>
# und (und) <CCONJ>
# politischen (politisch) <ADJ>
# Kontext (Kontext) <NOUN>
# der (der) <DET>
# Phänomene (Phänomen) <NOUN>
# genauer (genau) <ADV>
# zu (zu) <PART>
# betrachten (betrachten) <VERB>
# . (--) <PUNCT>
# Stattdessen (stattdessen) <ADV>
# stellte (stellen) <VERB>
# er (er) <PRON>
# Vergleichskriterien (Vergleichskriterien) <NOUN>
# auf (auf) <ADP>
# , (--) <PUNCT>
# die (der) <PRON>
# man (man) <PRON>
# als (als) <ADP>
# „ (--) <PUNCT>
# ergebnisgeleitet (ergebnisgeleiten) <VERB>
# “ (--) <PUNCT>
# statt (statt) <ADP>
# „ (--) <PUNCT>
# ergebnisoffen (ergebnisoffen) <VERB>
# “ (--) <PUNCT>
# bezeichnen (bezeichnen) <VERB>
# kann (können) <AUX>
# . (--) <PUNCT>
# So (so) <ADV>
# entgingen (entgingen) <VERB>
# ihm (ihm) <PRON>
# auch (auch) <ADV>
# die (der) <DET>
# bereits (bereits) <ADV>
# erwähnten (erwähnt) <ADJ>
# Fehler (Fehler) <NOUN>
# in (in) <ADP>
# den (der) <DET>
# alten (alt) <ADJ>
# ethnographischen (ethnographisch) <ADJ>
# Aufzeichnungen (Aufzeichnung) <NOUN>
# aus (aus) <ADP>
# Russland.[74 (Russland.[74) <X>
# ] (]) <NOUN>
# Auf (auf) <ADP>
# der (der) <DET>
# Suche (Suche) <NOUN>
# nach (nach) <ADP>
# dem (der) <DET>
# tieferen (tief) <ADJ>
# Sinn (Sinn) <NOUN>
# vermischte (vermischen) <VERB>
# er (er) <PRON>
# religiöse (religiös) <NOUN>
# mit (mit) <ADP>
# mythisch-literarischen (mythisch-literarisch) <ADJ>
# Phänomenen (Phänomen) <NOUN>
# und (und) <CCONJ>
# stellte (stellen) <VERB>
# das (der) <DET>
# „ (--) <PUNCT>
# kreative (kreativ) <ADJ>
# vor (vor) <ADP>
# das (der) <DET>
# empirische (empirisch) <ADJ>
# Moment (Moment) <NOUN>
# “ (--) <PUNCT>
# . (--) <PUNCT>
# Er (er) <PRON>
# ging (gehen) <VERB>
# davon (davon) <ADV>
# aus (aus) <ADP>
# , (--) <PUNCT>
# dass (dass) <SCONJ>
# sich (sich) <PRON>
# der (der) <DET>
# „ (--) <PUNCT>
# sakrale (sakral) <ADJ>
# Charakter (Charakter) <NOUN>
# “ (--) <PUNCT>
# nicht (nicht) <PART>
# mit (mit) <ADP>
# Hilfe (Hilfe) <NOUN>
# der (der) <DET>
# reduktionistischen (reduktionistisch) <ADJ>
# Methoden (Methode) <NOUN>
# verschiedener (verschieden) <ADJ>
# Fachbereiche (Fachbereich) <NOUN>
# ( (--) <PUNCT>
# Physiologie (Physiologie) <NOUN>
# , (--) <PUNCT>
# Psychologie (Psychologie) <NOUN>
# , (--) <PUNCT>
# Sprachwissenschaft (Sprachwissenschaft) <NOUN>
# , (--) <PUNCT>
# Kunst (Kunst) <NOUN>
# u. (u.) <ADP>
# a. (a.) <X>
# ) (--) <PUNCT>
# offenbare (offenbaren) <VERB>
# , (--) <PUNCT>
# sondern (sondern) <CCONJ>
# nur (nur) <ADV>
# in (in) <ADP>
# seiner (sein) <DET>
# „ (--) <PUNCT>
# eigenen (eigen) <ADJ>
# religiösen (religiös) <ADJ>
# Modalität (Modalität) <NOUN>
# “ (--) <PUNCT>
# . (--) <PUNCT>
# Seine (sein) <DET>
# These (These) <NOUN>
# ist (sein) <AUX>
# keine (kein) <DET>
# rein (rein) <ADV>
# akademische (akademisch) <ADJ>
# , (--) <PUNCT>
# sondern (sondern) <CCONJ>
# eine (ein) <DET>
# metaphysische (metaphysisch) <ADJ>
# Deutung (Deutung) <NOUN>
# von (von) <ADP>
# Geschichte (Geschichte) <NOUN>
# und (und) <CCONJ>
# Welt (Welt) <NOUN>
# . (--) <PUNCT>
# Widersprüche (Widerspruch) <NOUN>
# und (und) <CCONJ>
# Abweichungen (Abweichung) <NOUN>
# erklärte (erklären) <VERB>
# er (er) <PRON>
# durch (durch) <ADP>
# „ (--) <PUNCT>
# Dekadenz (Dekadenz) <NOUN>
# “ (--) <PUNCT>
# und (und) <CCONJ>
# „ (--) <PUNCT>
# Kontamination (Kontamination) <NOUN>
# “ (--) <PUNCT>
# durch (durch) <ADP>
# andere (anderer) <ADJ>
# Kulturen (Kultur) <NOUN>
# und (und) <CCONJ>
# Religionen (Religion) <NOUN>
# . (--) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# Eliade (Eliade) <NOUN>
# idealisierte (idealisieren) <VERB>
# und (und) <CCONJ>
# romantisierte (romantisieren) <VERB>
# die (der) <DET>
# „ (--) <PUNCT>
# archaische (archaisch) <ADJ>
# Spiritualität (Spiritualität) <NOUN>
# “ (--) <PUNCT>
# und (und) <CCONJ>
# die (der) <DET>
# „ (--) <PUNCT>
# primitiven (primitiv) <ADJ>
# Kulturen (Kultur) <NOUN>
# “ (--) <PUNCT>
# in (in) <ADP>
# der (der) <DET>
# eurozentrischen (eurozentrisch) <ADJ>
# Tradition (Tradition) <NOUN>
# von (von) <ADP>
# Herder (Herder) <PROPN>
# und (und) <CCONJ>
# Boas (Boas) <NOUN>
# . (--) <PUNCT>
# Statt (statt) <SCONJ>
# sich (sich) <PRON>
# den (der) <DET>
# tatsächlichen (tatsächlich) <ADJ>
# ethnischen (ethnisch) <ADJ>
# Mentalitäten (Mentalität) <NOUN>
# zu (zu) <PART>
# nähern (nähern) <VERB>
# , (--) <PUNCT>
# erkennen (erkennen) <VERB>
# einige (einiger) <DET>
# Autoren (Autor) <NOUN>
# eher (eher) <ADV>
# christliche (christlich) <ADJ>
# Motive (Motiv) <NOUN>
# bei (bei) <ADP>
# ihm (ihm) <PRON>
# : (--) <PUNCT>
# Der (der) <DET>
# mystische (mystisch) <ADJ>
# Urzustand (Urzustand) <NOUN>
# entspricht (entsprechen) <VERB>
# dem (der) <DET>
# Paradies (Paradies) <NOUN>
# , (--) <PUNCT>
# der (der) <DET>
# geschichtliche (geschichtlich) <ADJ>
# Zivilisationsprozess (Zivilisationsprozess) <NOUN>
# dem (der) <DET>
# Sündenfall (Sündenfall) <NOUN>
# und (und) <CCONJ>
# die (der) <DET>
# schamanische (schamanisch) <ADJ>
# Seelenreise (Seelenreis) <NOUN>
# war (sein) <AUX>
# nach (nach) <ADP>
# Eliade (Eliade) <NOUN>
# angeblich (angeblich) <ADV>
# ursprünglich (ursprünglich) <ADV>
# eine (ein) <DET>
# „ (--) <PUNCT>
# Himmelsreise (Himmelsreise) <NOUN>
# “ (--) <PUNCT>
# in (in) <ADP>
# die (der) <DET>
# Oberwelt (Oberwelt) <NOUN>
# . (--) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# Sein (sein) <DET>
# Ansatz (Ansatz) <NOUN>
# hat (haben) <AUX>
# bis (bis) <ADP>
# in (in) <ADP>
# die (der) <DET>
# 1990er (1990er) <NUM>
# Jahre (Jahr) <NOUN>
# zu (zu) <ADP>
# scharfen (scharf) <ADJ>
# Debatten (Debatte) <NOUN>
# um (um) <ADP>
# seine (sein) <DET>
# Methodik (Methodik) <NOUN>
# , (--) <PUNCT>
# aber (aber) <CCONJ>
# demgegenüber (demgegenüber) <ADV>
# auch (auch) <ADV>
# um (um) <ADP>
# den (der) <DET>
# Reduktionismus (Reduktionismus) <NOUN>
# in (in) <ADP>
# den (der) <DET>
# Religionswissenschaften (Religionswissenschaft) <NOUN>
# geführt (führen) <VERB>
# . (--) <PUNCT>
# Aus (aus) <ADP>
# Sicht (Sicht) <NOUN>
# der (der) <DET>
# Anthropologie (Anthropologie) <NOUN>
# wird (werden) <AUX>
# Eliades (Eliad) <PROPN>
# Methode (Methode) <NOUN>
# vor (vor) <ADP>
# allem (alle) <PRON>
# kritisiert (kritisieren) <VERB>
# , (--) <PUNCT>
# weil (weil) <SCONJ>
# sie (sie) <PRON>
# mehr (mehr) <ADV>
# in (in) <ADP>
# seiner (sein) <DET>
# Rolle (Rolle) <NOUN>
# eines (ein) <DET>
# schamanischen (schamanisch) <ADJ>
# Propheten (Prophet) <NOUN>
# wurzele (wurzeln) <VERB>
# , (--) <PUNCT>
# denn (denn) <CCONJ>
# in (in) <ADP>
# seriöser (seriös) <ADJ>
# wissenschaftlicher (wissenschaftlich) <ADJ>
# Arbeit (Arbeit) <NOUN>
# . (--) <PUNCT>
# Verschiedene (verschieden) <ADJ>
# Autoren (Autor) <NOUN>
# bemängeln (bemängeln) <VERB>
# , (--) <PUNCT>
# dass (dass) <SCONJ>
# er (er) <PRON>
# historische (historisch) <VERB>
# , (--) <PUNCT>
# anthropologische (anthropologisch) <ADJ>
# , (--) <PUNCT>
# soziologische (soziologisch) <ADJ>
# und (und) <CCONJ>
# ökonomische (ökonomisch) <ADJ>
# Perspektiven (Perspektive) <NOUN>
# schlichtweg (schlichtweg) <ADV>
# ignoriert (ignorieren) <VERB>
# habe (haben) <AUX>
# , (--) <PUNCT>
# so (so) <ADV>
# dass (dass) <SCONJ>
# seine (sein) <DET>
# Darstellungen (Darstellung) <NOUN>
# nicht (nicht) <PART>
# verifizierbar (verifizierbar) <ADV>
# seien (sein) <AUX>
# . (--) <PUNCT>
# Darüber (darüber) <ADV>
# hinaus (hinaus) <ADP>
# wird (werden) <AUX>
# ihm (ihm) <PRON>
# angelastet (anlasten) <VERB>
# , (--) <PUNCT>
# dass (dass) <SCONJ>
# er (er) <PRON>
# über (über) <ADP>
# den (der) <DET>
# reinen (rein) <ADJ>
# Erklärungsversuch (Erklärungsversuch) <NOUN>
# hinausging (hinausgehen) <VERB>
# und (und) <CCONJ>
# dem (der) <DET>
# unwissenschaftlichen (unwissenschaftlich) <ADJ>
# Neoschamanismus (Neoschamanismus) <NOUN>
# mit (mit) <ADP>
# der (der) <DET>
# Aussage (Aussage) <NOUN>
# „ (--) <PUNCT>
# dass (dass) <SCONJ>
# der (der) <DET>
# mystische (mystisch) <ADJ>
# Urzustand (Urzustand) <NOUN>
# mit (mit) <ADP>
# Hilfe (Hilfe) <NOUN>
# der (der) <DET>
# schamanischen (schamanisch) <ADJ>
# Ekstase (Ekstase) <NOUN>
# quasi (quasi) <ADV>
# jederzeit (jederzeit) <ADV>
# von (von) <ADP>
# jedermann (jedermann) <PRON>
# vergegenwärtigt (vergegenwärtigen) <VERB>
# werden (werden) <AUX>
# könne (können) <AUX>
# “ (--) <PUNCT>
# eine (ein) <DET>
# Legitimation (Legitimation) <NOUN>
# geliefert (liefern) <VERB>
# hat.[83][82 (hat.[83][82) <X>
# ] (]) <NOUN>
# Klaus (Klaus) <PROPN>
# E. (E.) <PROPN>
# Müller (Müller) <PROPN>
# bezeichnete (bezeichnen) <VERB>
# Eliades (Eliad) <ADJ>
# Thesen (These) <NOUN>
# als (als) <ADP>
# „ (--) <PUNCT>
# inhaltlich (inhaltlich) <ADV>
# sehr (sehr) <ADV>
# spekulativ“.[84 (spekulativ“.[84) <X>
# ] (]) <X>

# %%
# POS-filter sentences 

ALLOWED_POS = {"NOUN", "ADJ", "PROPN"}
filtered_sentences = []

for sent in doc.sents:
    tmp_sent = []
    for token in sent:
        
        if token.lemma_.lower() in stops:
            continue
            
        if token.pos_ not in ALLOWED_POS:
            continue
        
        tmp_sent.append(token.lemma_)
    
    if len(tmp_sent) > 0:
        filtered_sentences.append(tmp_sent)

# %%
print(filtered_sentences[0])
# Out:
# ['Schamanismus', 'eng', 'Sinn', 'traditionell', 'ethnisch', 'Religion', 'Kulturareale', 'Sibirien', 'Nenzen', 'Jakut', 'Altaier', 'Burjat', 'Ewenk', 'europäisch', 'Samen', 'Vorhandensein', 'Schaman', 'europäisch', 'Forscher', 'Expansionszeit', 'wesentlich', 'gemeinsam', 'Kennzeichen', 'wurde.[1', ']']

# %%
all_tokens = [token for sent in filtered_sentences for token in sent]
token_count = Counter(all_tokens)
print(token_count.most_common(25))
# Out:
# [(']', 92), ('Schamanismus', 67), ('Schaman', 52), ('sibirisch', 24), ('Religion', 23), ('Volk', 22), ('Schamane', 20), ('schamanisch', 20), ('These', 20), ('Ekstase', 19), ('traditionell', 18), ('\ufeff', 18), ('Sibirien', 17), ('Phänomen', 17), ('Trance', 17), ('Form', 17), ('Jahrhundert', 17), ('verschieden', 16), ('Kultur', 16), ('Müller', 16), ('religiös', 15), ('rituell', 14), ('Autor', 14), ('Eliade', 14), ('Kritik', 13)]

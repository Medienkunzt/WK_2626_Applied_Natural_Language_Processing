# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

import re
from collections import defaultdict
from collections import Counter

# https://de.wikipedia.org/wiki/Schamanismus

# %%
# Downloads. Run only once

nltk.download('stopwords')  # Stopwords
nltk.download('punkt')  # Tokenizers
# Out:
# [nltk_data] Downloading package stopwords to /Users/dbr/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/dbr/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
stops = list(stopwords.words('german'))  # english
print(stops[:5], len(stops))
# Out:
# ['aber', 'alle', 'allem', 'allen', 'aller'] 232

# %%
# Or "alice.txt"
with open("Schamanismus.txt", "r", encoding="utf-8") as inf:
    text = inf.read()

# %%
print("Unique characters", len(set(text)))
print(" ".join(set(text)))

print("\n" * 2)

char_count = Counter(text)
print("Most common chars:", char_count.most_common(20))  # Zipf?
# Out:
# Unique characters 102
# x J A “ 8 Ü r [ . ) é ‚ i m E 	 R b ü ] y 9 q : 6 „ * F - j M t è 1 k Z ` l ﻿ s D ? U v ; – f O   w ’ o ö á ó c h P 3 ‘ T n d B 7 H
#  , 4 → š C ä u G g í N S e 5 = " ñ V ´ p 0 L W a / … ù z ( I K 2 ß Y Ä
#
#
#
# Most common chars: [('e', 8453), (' ', 8370), ('n', 5251), ('i', 4565), ('s', 3696), ('r', 3636), ('t', 2969), ('a', 2949), ('h', 2468), ('d', 2234), ('l', 2082), ('u', 2075), ('c', 1736), ('o', 1454), ('m', 1408), ('g', 1226), ('b', 758), ('k', 665), ('f', 605), ('w', 519)]

# %%
# Cleaning
s = 2000
print(text[s:s+100])
text_cleaned = re.sub(r"[^a-zA-Z0-9äöüÄÖÜß\.,!\?-]", " ", text)

print(text_cleaned[s:s+100])
print("\n\nUnique characters", len(set(text_cleaned)))
# Out:
#  „westlich idealistischen Konstrukt Schamanismus“ jeglichen Erklärungswert ab.[A 2]
#
# Einig ist man s
#   westlich idealistischen Konstrukt Schamanismus  jeglichen Erklärungswert ab. A 2   Einig ist man s
#
#
# Unique characters 71

# %%
# Segmentation
sentences = sent_tokenize(text_cleaned, language="german")

print(len(sentences), "sentences.")
print(sentences[3:5])
# Out:
# 298 sentences.
# ['Nach L szl  Vajda 3  und Jane Monnig Atkinson A 1  sollte aufgrund der Vielzahl unterschiedlicher Konzepte treffender von Schamanismen im Plural gesprochen werden.', 'Sibirische Schamanen und verschiedene Geisterbeschwörer anderer Ethnien   die ebenfalls häufig verallgemeinernd als Schamanen bezeichnet werden   hatten oder haben in vielen traditionellen Weltanschauungen angeblich Einfluss auf die Mächte des Jenseits.']

# %%
# Tokenization
tokenized_sentences = []
for sent in sentences:
    tokens = word_tokenize(sent, language="german")
    tokenized_sentences.append(tokens)
    
print(tokenized_sentences[0])
# Out:
# ['Schamanismus', 'bezeichnet', 'im', 'engeren', 'Sinne', 'die', 'traditionellen', 'ethnischen', 'Religionen', 'des', 'Kulturareales', 'Sibirien', 'Nenzen', ',', 'Jakuten', ',', 'Altaier', ',', 'Burjaten', ',', 'Ewenken', ',', 'auch', 'europäische', 'Samen', 'und', 'andere', ',', 'bei', 'denen', 'das', 'Vorhandensein', 'von', 'Schamanen', 'von', 'europäischen', 'Forschern', 'der', 'Expansionszeit', 'als', 'wesentliches', 'gemeinsames', 'Kennzeichen', 'erachtet', 'wurde', '.']

# %%
# Filter stopwords
stops = set(stops)
filtered_sentences = []
for sent in tokenized_sentences:
    filtered_sent = [token for token in sent if token not in stops]
    filtered_sentences.append(filtered_sent)

# %%
print(filtered_sentences[0])
# Out:
# ['Schamanismus', 'bezeichnet', 'engeren', 'Sinne', 'traditionellen', 'ethnischen', 'Religionen', 'Kulturareales', 'Sibirien', 'Nenzen', ',', 'Jakuten', ',', 'Altaier', ',', 'Burjaten', ',', 'Ewenken', ',', 'europäische', 'Samen', ',', 'denen', 'Vorhandensein', 'Schamanen', 'europäischen', 'Forschern', 'Expansionszeit', 'wesentliches', 'gemeinsames', 'Kennzeichen', 'erachtet', 'wurde', '.']

# %%
# Lower all tokens
lowered_sentences = list(map(lambda sent: list(map(str.lower, sent)), filtered_sentences))

# %%
print(lowered_sentences[0])
# Out:
# ['schamanismus', 'bezeichnet', 'engeren', 'sinne', 'traditionellen', 'ethnischen', 'religionen', 'kulturareales', 'sibirien', 'nenzen', ',', 'jakuten', ',', 'altaier', ',', 'burjaten', ',', 'ewenken', ',', 'europäische', 'samen', ',', 'denen', 'vorhandensein', 'schamanen', 'europäischen', 'forschern', 'expansionszeit', 'wesentliches', 'gemeinsames', 'kennzeichen', 'erachtet', 'wurde', '.']

# %%
# Help from spacy


import spacy
# python -m spacy download de_core_news_sm

# %%
nlp = spacy.load("de_core_news_sm")

# %%
doc = nlp(text)

# %%
for sent in doc.sents:
    print(sent)
    break
# Out:
# Schamanismus bezeichnet im engeren Sinne die traditionellen ethnischen Religionen des Kulturareales Sibirien (Nenzen, Jakuten, Altaier, Burjaten, Ewenken, auch europäische Samen und andere), bei denen das Vorhandensein von Schamanen von europäischen Forschern der Expansionszeit als wesentliches gemeinsames Kennzeichen erachtet wurde.[1]

# %%
c = 0
for sent in doc.sents:
    for token in sent:
        print(f"{token} ({token.lemma_}) <{token.pos_}>")
# Out:
# Schamanismus (Schamanismus) <NOUN>
# bezeichnet (bezeichnen) <VERB>
# im (im) <ADP>
# engeren (eng) <ADJ>
# Sinne (Sinn) <NOUN>
# die (der) <DET>
# traditionellen (traditionell) <ADJ>
# ethnischen (ethnisch) <ADJ>
# Religionen (Religion) <NOUN>
# des (der) <DET>
# Kulturareales (Kulturareales) <PROPN>
# Sibirien (Sibirien) <PROPN>
# ( (() <PUNCT>
# Nenzen (Nenzen) <NOUN>
# , (,) <PUNCT>
# Jakuten (Jakuten) <NOUN>
# , (,) <PUNCT>
# Altaier (Altaier) <NOUN>
# , (,) <PUNCT>
# Burjaten (Burjaten) <NOUN>
# , (,) <PUNCT>
# Ewenken (Ewenken) <NOUN>
# , (,) <PUNCT>
# auch (auch) <ADV>
# europäische (europäische) <ADJ>
# Samen (Samen) <NOUN>
# und (und) <CCONJ>
# andere (ander) <PRON>
# ) ()) <PUNCT>
# , (,) <PUNCT>
# bei (bei) <ADP>
# denen (der) <PRON>
# das (der) <DET>
# Vorhandensein (Vorhandensein) <NOUN>
# von (von) <ADP>
# Schamanen (Schamane) <NOUN>
# von (von) <ADP>
# europäischen (europäisch) <ADJ>
# Forschern (Forscher) <NOUN>
# der (der) <DET>
# Expansionszeit (Expansionszeit) <NOUN>
# als (als) <ADP>
# wesentliches (wesentlich) <ADJ>
# gemeinsames (gemeinsam) <ADJ>
# Kennzeichen (Kennzeichen) <NOUN>
# erachtet (erachten) <VERB>
# wurde.[1 (wurde.[1) <PROPN>
# ] (]) <PROPN>
# Zur (Zur) <ADP>
# besseren (gut) <ADJ>
# Abgrenzung (Abgrenzung) <NOUN>
# werden (werden) <AUX>
# diese (dies) <DET>
# Religionen (Religion) <NOUN>
# häufig (häufig) <ADV>
# „ („) <PUNCT>
# klassischer (klassisch) <ADJ>
# Schamanismus (Schamanismus) <NOUN>
# “ (“) <PUNCT>
# oder (oder) <CCONJ>
# auch (auch) <ADV>
# „ („) <PUNCT>
# sibirischer (sibirisch) <ADJ>
# Animismus (Animismus) <NOUN>
# “ (“) <PUNCT>
# genannt.[2 (genannt.[2) <PROPN>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# Im (Im) <ADP>
# weiteren (weit) <ADJ>
# Sinne (Sinn) <NOUN>
# meint (meinen) <VERB>
# Schamanismus (Schamanismus) <NOUN>
# alle (all) <DET>
# wissenschaftlichen (wissenschaftlich) <ADJ>
# Konzepte (Konzept) <NOUN>
# , (,) <PUNCT>
# die (der) <PRON>
# aufgrund (aufgrund) <ADP>
# von (von) <ADP>
# ähnlichen (ähnlich) <ADJ>
# Praktiken (Praktik) <NOUN>
# spiritueller (spirituell) <ADJ>
# Spezialisten (Spezialist) <NOUN>
# in (in) <ADP>
# verschiedenen (verschieden) <ADJ>
# traditionellen (traditionell) <ADJ>
# Gesellschaften (Gesellschaft) <NOUN>
# die (der) <DET>
# kulturübergreifende (kulturübergreifende) <ADJ>
# Existenz (Existenz) <NOUN>
# des (der) <DET>
# Schamanismus (Schamanismus) <NOUN>
# postulieren (postulieren) <VERB>
# . (.) <PUNCT>
# Nach (Nach) <ADP>
# László (László) <PROPN>
# Vajda[3 (Vajda[3) <PROPN>
# ] (]) <PROPN>
# und (und) <CCONJ>
# Jane (Jane) <NOUN>
# Monnig (Monnig) <PROPN>
# Atkinson (Atkinson) <PROPN>
# [ ([) <PROPN>
# A (A) <PROPN>
# 1 (1) <NUM>
# ] (]) <PROPN>
# sollte (sollen) <AUX>
# aufgrund (aufgrund) <ADP>
# der (der) <DET>
# Vielzahl (Vielzahl) <NOUN>
# unterschiedlicher (unterschiedlich) <ADJ>
# Konzepte (Konzept) <NOUN>
# treffender (treffend) <ADV>
# von (von) <ADP>
# Schamanismen (Schamanismen) <NOUN>
# im (im) <ADP>
# Plural (Plural) <NOUN>
# gesprochen (sprechen) <VERB>
# werden (werden) <AUX>
# . (.) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# Sibirische (Sibirische) <ADJ>
# Schamanen (Schamane) <NOUN>
# und (und) <CCONJ>
# verschiedene (verschieden) <ADJ>
# Geisterbeschwörer (Geisterbeschwörer) <NOUN>
# anderer (ander) <ADJ>
# Ethnien (Ethnien) <NOUN>
# – (–) <PUNCT>
# die (der) <PRON>
# ebenfalls (ebenfalls) <ADV>
# häufig (häufig) <ADV>
# verallgemeinernd (verallgemeinern) <ADV>
# als (als) <ADP>
# Schamanen (Schamane) <NOUN>
# bezeichnet (bezeichnen) <VERB>
# werden (werden) <AUX>
# – (–) <PUNCT>
# hatten (haben) <AUX>
# oder (oder) <CCONJ>
# haben (haben) <AUX>
# in (in) <ADP>
# vielen (viel) <DET>
# traditionellen (traditionell) <ADJ>
# Weltanschauungen (Weltanschauungen) <NOUN>
# angeblich (angeblich) <ADV>
# Einfluss (Einfluss) <PROPN>
# auf (auf) <ADP>
# die (der) <DET>
# Mächte (Macht) <NOUN>
# des (der) <DET>
# Jenseits (Jenseits) <NOUN>
# . (.) <PUNCT>
# Sie (ich) <PRON>
# setzten (setzen) <VERB>
# ihre (mein) <DET>
# Fähigkeiten (Fähigkeit) <NOUN>
# vorwiegend (vorwiegen) <ADV>
# zum (zum) <ADP>
# Wohle (Wohle) <NOUN>
# der (der) <DET>
# Gemeinschaft (Gemeinschaft) <NOUN>
# ein (einen) <ADV>
# , (,) <PUNCT>
# um (um) <SCONJ>
# in (in) <ADP>
# unlösbar (unlösbar) <ADV>
# erscheinenden (erscheinend) <ADJ>
# Krisensituationen (Krisensituationen) <NOUN>
# die (der) <DET>
# „ („) <PUNCT>
# kosmische (kosmisch) <ADJ>
# Harmonie (Harmonie) <NOUN>
# “ (“) <PUNCT>
# zwischen (zwischen) <ADP>
# Diesseits (Diesseits) <ADJ>
# und (und) <CCONJ>
# Jenseits (Jenseits) <NOUN>
# wiederherzustellen (wiederherstellen) <VERB>
# . (.) <PUNCT>
# In (In) <ADP>
# diesem (dies) <DET>
# weiten (weit) <ADJ>
# Sinne (Sinn) <NOUN>
# bezeichnet (bezeichnen) <VERB>
# Schamanismus (Schamanismus) <NOUN>
# eine (einen) <DET>
# Reihe (Reihe) <NOUN>
# unscharf (unscharf) <ADV>
# bestimmter (bestimmt) <ADJ>
# Phänomene (Phänomen) <NOUN>
# „ („) <PUNCT>
# zwischen (zwischen) <ADP>
# Religion (Religion) <NOUN>
# und (und) <CCONJ>
# Heilritual“.[4][5][6][7][8][9][Anmerkung (Heilritual“.[4][5][6][7][8][9][Anmerkung) <NOUN>
# 1 (1) <NUM>
# ] (]) <NOUN>
#
#
#  (
#
# ) <SPACE>
# Eine (Eine) <DET>
# nähere (nah) <ADJ>
# allgemeingültige (allgemeingültig) <ADJ>
# Bestimmung (Bestimmung) <NOUN>
# ist (sein) <AUX>
# nicht (nicht) <PART>
# möglich (möglich) <ADV>
# , (,) <PUNCT>
# da (da) <SCONJ>
# die (der) <DET>
# Definition (Definition) <NOUN>
# verschiedene (verschieden) <ADJ>
# Betrachtungsweisen (Betrachtungsweise) <NOUN>
# aus (aus) <ADP>
# Sicht (Sicht) <NOUN>
# der (der) <DET>
# Ethnologie (Ethnologie) <NOUN>
# , (,) <PUNCT>
# Kulturanthropologie (Kulturanthropologie) <NOUN>
# , (,) <PUNCT>
# Religionswissenschaften (Religionswissenschaften) <NOUN>
# , (,) <PUNCT>
# Archäologie (Archäologie) <NOUN>
# , (,) <PUNCT>
# Soziologie (Soziologie) <NOUN>
# und (und) <CCONJ>
# Psychologie (Psychologie) <NOUN>
# enthält.[10][11 (enthält.[10][11) <PROPN>
# ] (]) <PROPN>
# Dies (Dies) <PRON>
# hat (haben) <AUX>
# unter (unter) <ADP>
# anderem (ander) <PRON>
# zur (zur) <ADP>
# Folge (Folge) <NOUN>
# , (,) <PUNCT>
# dass (dass) <SCONJ>
# Angaben (Angabe) <NOUN>
# zur (zur) <ADP>
# räumlichen (räumlich) <ADJ>
# und (und) <CCONJ>
# zeitlichen (zeitlich) <ADJ>
# Verbreitung (Verbreitung) <NOUN>
# der (der) <DET>
# „ („) <PUNCT>
# Schamanismen (Schamanismen) <NOUN>
# “ (“) <PUNCT>
# erheblich (erheblich) <ADV>
# voneinander (voneinander) <ADV>
# abweichen (abweichen) <VERB>
# und (und) <CCONJ>
# in (in) <ADP>
# vielen (viel) <DET>
# Fällen (Fall) <NOUN>
# umstritten (umstritten) <ADV>
# sind.[12][13][14 (sind.[12][13][14) <PROPN>
# ] (]) <X>
# Der (der) <DET>
# amerikanische (amerikanische) <ADJ>
# Ethnologe (Ethnologe) <NOUN>
# Clifford (Clifford) <PROPN>
# Geertz (Geertz) <PROPN>
# sprach (sprechen) <VERB>
# daher (daher) <ADV>
# bereits (bereits) <ADV>
# in (in) <ADP>
# den (der) <DET>
# 1960er (1960er) <ADJ>
# Jahren (Jahr) <NOUN>
# dem (der) <DET>
# „ („) <PUNCT>
# westlich (westlich) <ADV>
# idealistischen (idealistisch) <ADJ>
# Konstrukt (Konstrukt) <NOUN>
# Schamanismus (Schamanismus) <NOUN>
# “ (“) <PUNCT>
# jeglichen (jeglich) <DET>
# Erklärungswert (Erklärungswert) <PROPN>
# ab.[A (ab.[A) <NOUN>
# 2 (2) <NUM>
# ] (]) <NOUN>
#
#
#  (
#
# ) <SPACE>
# Einig (Einig) <ADV>
# ist (sein) <AUX>
# man (man) <PRON>
# sich (sich) <PRON>
# lediglich (lediglich) <ADV>
# bei (bei) <ADP>
# der (der) <DET>
# „ („) <PUNCT>
# engen (eng) <ADJ>
# Definition (Definition) <NOUN>
# “ (“) <PUNCT>
# des (der) <DET>
# klassisch (klassisch) <ADV>
# sibirischen (sibirisch) <ADJ>
# Schamanismus (Schamanismus) <NOUN>
# – (–) <PUNCT>
# dem (der) <DET>
# Ausgangspunkt (Ausgangspunkt) <NOUN>
# der (der) <DET>
# ersten (erst) <ADJ>
# „ („) <PUNCT>
# Schamanismen (Schamanismen) <NOUN>
# “ (“) <PUNCT>
# . (.) <PUNCT>
# Dazu (Dazu) <ADV>
# gehört (hören) <VERB>
# vor (vor) <ADP>
# allem (alle) <PRON>
# die (der) <DET>
# genaue (genau) <ADJ>
# Beschreibung (Beschreibung) <NOUN>
# der (der) <DET>
# dort (dort) <ADV>
# praktizierten (praktizieren) <ADJ>
# rituellen (rituellen) <ADJ>
# Ekstase (Ekstase) <NOUN>
# , (,) <PUNCT>
# eine (einen) <DET>
# weitgehend (weitgehend) <ADV>
# übereinstimmende (übereinstimmend) <ADJ>
# ethnische (ethnisch) <ADJ>
# Religion (Religion) <NOUN>
# sowie (sowie) <CCONJ>
# eine (einen) <DET>
# ähnliche (ähnlich) <ADJ>
# Kosmologie (Kosmologie) <NOUN>
# und (und) <CCONJ>
# Lebensweise.[15][11][16 (Lebensweise.[15][11][16) <NOUN>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# Nach (Nach) <ADP>
# weiter (weit) <ADV>
# gefassten (gefassten) <ADJ>
# Definitionen (Definition) <NOUN>
# wird (werden) <AUX>
# Schamanismus (Schamanismus) <NOUN>
# bis (bis) <ADP>
# in (in) <ADP>
# die (der) <DET>
# 1980er (1980er) <ADJ>
# Jahre (Jahr) <NOUN>
# als (als) <ADP>
# frühe (frühe) <ADJ>
# , (,) <PUNCT>
# kulturübergreifende (kulturübergreifende) <ADJ>
# Entwicklungsstufe (Entwicklungsstufe) <NOUN>
# jeglicher (jeglich) <DET>
# Religion (Religion) <NOUN>
# betrachtet.[15 (betrachtet.[15) <NOUN>
# ] (]) <NOUN>
# Vor (Vor) <ADP>
# allem (alle) <PRON>
# das (der) <DET>
# Konzept (Konzept) <NOUN>
# des (der) <DET>
# Core-Schamanismus (Core-Schamanismus) <NOUN>
# von (von) <ADP>
# Michael (Michael) <PROPN>
# Harner (Harner) <PROPN>
# ist (sein) <AUX>
# hier (hier) <ADV>
# zu (zu) <PART>
# nennen (nennen) <VERB>
# . (.) <PUNCT>
# Diese (Diese) <DET>
# Auslegung (Auslegung) <NOUN>
# gilt (gelten) <VERB>
# jedoch (jedoch) <ADV>
# mittlerweile (mittlerweile) <ADV>
# als (als) <ADP>
# nicht (nicht) <PART>
# konsensfähig.[14 (konsensfähig.[14) <ADJ>
# ] (]) <PROPN>
# Seit (seit) <ADP>
# den (der) <DET>
# 1990er (1990er) <NUM>
# Jahren (Jahr) <NOUN>
# steht (stehen) <VERB>
# häufig (häufig) <ADV>
# der (der) <DET>
# Aspekt (Aspekt) <NOUN>
# des (der) <DET>
# „ („) <PUNCT>
# Heilens (Heilen) <NOUN>
# “ (“) <PUNCT>
# im (im) <ADP>
# Mittelpunkt (Mittelpunkt) <NOUN>
# des (der) <DET>
# Interesses (Interesse) <NOUN>
# ( (() <PUNCT>
# und (und) <CCONJ>
# der (der) <DET>
# jeweiligen (jeweilig) <ADJ>
# Definition).[10 (Definition).[10) <NOUN>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# Demgegenüber (Demgegenüber) <ADV>
# geht (gehen) <VERB>
# der (der) <DET>
# Indologe (Indologe) <NOUN>
# Michael (Michael) <PROPN>
# Witzel (Witzel) <PROPN>
# davon (davon) <ADV>
# aus (aus) <ADP>
# , (,) <PUNCT>
# dass (dass) <SCONJ>
# es (ich) <PRON>
# angesichts (angesichts) <ADP>
# der (der) <DET>
# Ähnlichkeit (Ähnlichkeit) <NOUN>
# australischer (australisch) <ADJ>
# , (,) <PUNCT>
# andamanischer (andamanischer) <ADJ>
# , (,) <PUNCT>
# indischer (indisch) <ADJ>
# und (und) <CCONJ>
# afrikanischer (afrikanisch) <ADJ>
# Initiationsrituale (Initiationsrituale) <NOUN>
# mit (mit) <ADP>
# den (der) <DET>
# entsprechenden (entsprechend) <ADJ>
# sibirischen (sibirisch) <ADJ>
# Ritualen (Ritual) <NOUN>
# , (,) <PUNCT>
# die (der) <PRON>
# die (der) <DET>
# Phänomene (Phänomen) <NOUN>
# der (der) <DET>
# aufsteigenden (aufsteigend) <ADJ>
# Hitze (Hitze) <NOUN>
# , (,) <PUNCT>
# Trancen (Trancen) <NOUN>
# ( (() <PUNCT>
# Dreamers (Dreamers) <PROPN>
# ) ()) <PUNCT>
# , (,) <PUNCT>
# Ekstase (Ekstase) <NOUN>
# und (und) <CCONJ>
# Kollaps (Kollaps) <NOUN>
# , (,) <PUNCT>
# symbolischen (symbolisch) <ADJ>
# Tod (Tod) <NOUN>
# und (und) <CCONJ>
# Wiedergeburt (Wiedergeburt) <NOUN>
# , (,) <PUNCT>
# Verwendung (Verwendung) <NOUN>
# psychoaktiver (psychoaktiver) <ADJ>
# Drogen (Droge) <NOUN>
# , (,) <PUNCT>
# Tabubewahrung (Tabubewahrung) <NOUN>
# , (,) <PUNCT>
# Zauberei (Zauberei) <NOUN>
# und (und) <CCONJ>
# Heilung (Heilung) <NOUN>
# umfassen (umfassen) <VERB>
# , (,) <PUNCT>
# einen (ein) <DET>
# älteren (alt) <ADJ>
# Prototyp (Prototyp) <NOUN>
# des (der) <DET>
# Schamanismus (Schamanismus) <NOUN>
# gegeben (geben) <VERB>
# habe (habe) <AUX>
# . (.) <PUNCT>
# Dieser (Dieser) <PRON>
# habe (habe) <AUX>
# sich (sich) <PRON>
# mit (mit) <ADP>
# der (der) <DET>
# Out-of-Africa-Wanderung (Out-of-Africa-Wanderung) <NOUN>
# des (der) <DET>
# modernen (modern) <ADJ>
# Menschen (Mensch) <NOUN>
# entlang (entlang) <ADP>
# der (der) <DET>
# Küsten (Küste) <NOUN>
# des (der) <DET>
# Indischen (Indische) <ADJ>
# Ozeans (Ozean) <NOUN>
# und (und) <CCONJ>
# früh (früh) <ADV>
# auch (auch) <ADV>
# nach (nach) <ADP>
# Eurasien (Eurasien) <PROPN>
# und (und) <CCONJ>
# Nordamerika (Nordamerika) <PROPN>
# verbreitet (verbreiten) <VERB>
# . (.) <PUNCT>
# Dafür (Dafür) <ADV>
# sprächen (sprechen) <VERB>
# spätpaläolithische (spätpaläolithische) <ADJ>
# Bärenkulte (Bärenkulte) <NOUN>
# und (und) <CCONJ>
# Felszeichnungen (Felszeichnungen) <NOUN>
# wie (wie) <ADP>
# in (in) <ADP>
# Les (Les) <PROPN>
# trois (trois) <PROPN>
# frères (frères) <PROPN>
# ( (() <PUNCT>
# Abb. (Abb.) <NOUN>
# siehe (siehe) <VERB>
# unten (unten) <ADV>
# ) ()) <PUNCT>
# . (.) <PUNCT>
# Der (der) <DET>
# sibirische (sibirisch) <ADJ>
# Schamanismus (Schamanismus) <NOUN>
# stelle (stelle) <VERB>
# eine (einen) <DET>
# jüngere (jung) <ADJ>
# Evolutionsstufe (Evolutionsstufe) <NOUN>
# dieses (dies) <DET>
# Prototyps (Prototyp) <NOUN>
# dar (dar) <ADV>
# ( (() <PUNCT>
# mit (mit) <ADP>
# Fellkleidung (Fellkleidung) <NOUN>
# , (,) <PUNCT>
# Trommel (Trommel) <NOUN>
# usw. (usw.) <ADV>
# ) ()) <PUNCT>
# ; (;) <PUNCT>
# er (ich) <PRON>
# habe (habe) <AUX>
# über (über) <ADP>
# weitere (weit) <ADJ>
# Wanderungswellen (Wanderungswellen) <NOUN>
# die (der) <DET>
# nordamerikanischen (nordamerikanischen) <ADJ>
# Jägerkulturen (Jägerkulturen) <NOUN>
# sekundär (sekundär) <ADV>
# beeinflusst (beeinflusst) <VERB>
# . (.) <PUNCT>
# An (an) <ADP>
# die (der) <DET>
# Stelle (Stelle) <NOUN>
# des (der) <DET>
# Opfers (Opfer) <NOUN>
# wilder (wildern) <ADJ>
# Tiere (Tier) <NOUN>
# , (,) <PUNCT>
# die (der) <PRON>
# der (der) <DET>
# Schamane (Schamane) <NOUN>
# vorher (vorher) <ADV>
# um (um) <ADP>
# Erlaubnis (Erlaubnis) <NOUN>
# für (für) <ADP>
# die (der) <DET>
# Tötung (Tötung) <NOUN>
# fragt (fragen) <VERB>
# oder (oder) <CCONJ>
# bei (bei) <ADP>
# denen (der) <PRON>
# er (ich) <PRON>
# sich (sich) <PRON>
# für (für) <ADP>
# die (der) <DET>
# Tat (Tat) <NOUN>
# entschuldigt (entschuldigen) <VERB>
# ( (() <PUNCT>
# so (so) <ADV>
# bei (bei) <ADP>
# den (der) <DET>
# Bärenkulten (Bärenkulten) <NOUN>
# der (der) <DET>
# Schamanen (Schamane) <NOUN>
# der (der) <DET>
# Ainu (Ainu) <NOUN>
# , (,) <PUNCT>
# Aleuten (Aleuten) <NOUN>
# und (und) <CCONJ>
# der (der) <DET>
# transbaikalischen (transbaikalischen) <ADJ>
# Völker (Volk) <NOUN>
# ) ()) <PUNCT>
# , (,) <PUNCT>
# seien (sein) <AUX>
# später (spät) <ADV>
# domestizierte (domestizieren) <ADJ>
# Tiere (Tier) <NOUN>
# wie (wie) <ADP>
# das (der) <DET>
# Rentier (Rentier) <NOUN>
# ( (() <PUNCT>
# in (in) <ADP>
# Sibirien (Sibirien) <PROPN>
# ) ()) <PUNCT>
# oder (oder) <CCONJ>
# Hunde (Hund) <NOUN>
# ( (() <PUNCT>
# wie (wie) <ADP>
# in (in) <ADP>
# Russland (Russland) <PROPN>
# oder (oder) <CCONJ>
# Indien (Indien) <PROPN>
# ) ()) <PUNCT>
# getreten.[17 (getreten.[17) <PROPN>
# ] (]) <PROPN>
# Insofern (insofern) <ADV>
# folgt (folgen) <VERB>
# Witzel (Witzel) <NOUN>
# der (der) <DET>
# weiten (weit) <ADJ>
# phänomenologischen (phänomenologisch) <ADJ>
# Schamanismus-Definition (Schamanismus-Definition) <NOUN>
# von (von) <ADP>
# Walter (Walter) <PROPN>
# und (und) <CCONJ>
# Fridman.[18 (Fridman.[18) <NOUN>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# Da (da) <SCONJ>
# bereits (bereits) <ADV>
# der (der) <DET>
# klassische (klassische) <ADJ>
# Schamanismus (Schamanismus) <NOUN>
# Sibiriens (Sibiriens) <PROPN>
# etliche (etlich) <DET>
# Varianten (Variante) <NOUN>
# aufweist (aufweisen) <VERB>
# , (,) <PUNCT>
# werden (werden) <AUX>
# weiter (weit) <ADV>
# reichende (reichend) <ADJ>
# geographische (geographisch) <ADJ>
# oder (oder) <CCONJ>
# historische (historische) <ADJ>
# Auslegungen (Auslegung) <NOUN>
# , (,) <PUNCT>
# die (der) <PRON>
# solche (solche) <DET>
# Phänomene (Phänomen) <NOUN>
# aus (aus) <ADP>
# ihrem (mein) <DET>
# kulturellen (kulturell) <ADJ>
# Kontext (Kontext) <NOUN>
# gelöst (lösen) <VERB>
# betrachten (betrachten) <VERB>
# und (und) <CCONJ>
# verallgemeinern (verallgemeinern) <VERB>
# , (,) <PUNCT>
# von (von) <ADP>
# vielen (viel) <DET>
# Autoren (Autor) <NOUN>
# als (als) <ADP>
# spekulativ (spekulativ) <ADV>
# kritisiert.[19][13 (kritisiert.[19][13) <X>
# ] (]) <X>
# In (In) <ADP>
# der (der) <DET>
# zeitgenössischen (zeitgenössisch) <ADJ>
# Literatur (Literatur) <NOUN>
# – (–) <PUNCT>
# populärwissenschaftlichen (populärwissenschaftlichen) <VERB>
# ( (() <PUNCT>
# insbesondere (insbesondere) <ADV>
# esoterischen (esoterisch) <ADJ>
# ) ()) <PUNCT>
# Büchern (Buch) <NOUN>
# , (,) <PUNCT>
# aber (aber) <CCONJ>
# auch (auch) <ADV>
# wissenschaftlichen (wissenschaftlich) <ADJ>
# Schriften (Schrift) <NOUN>
# – (–) <PUNCT>
# wird (werden) <AUX>
# in (in) <ADP>
# diesem (dies) <DET>
# Zusammenhang (Zusammenhang) <NOUN>
# oftmals (oftmals) <ADV>
# nicht (nicht) <PART>
# deutlich (deutlich) <ADV>
# gemacht (machen) <VERB>
# , (,) <PUNCT>
# auf (auf) <ADP>
# welche (welch) <DET>
# Ethnien (Ethnien) <NOUN>
# sich (sich) <PRON>
# Darstellungen (Darstellung) <NOUN>
# zu (zu) <ADP>
# bestimmten (bestimmen) <ADJ>
# schamanischen (schamanischen) <ADJ>
# Praktiken (Praktik) <NOUN>
# konkret (konkret) <ADV>
# beziehen (beziehen) <VERB>
# , (,) <PUNCT>
# so (so) <ADV>
# dass (dass) <SCONJ>
# regionale (regionale) <ADJ>
# ( (() <PUNCT>
# oft (oft) <ADV>
# sibirische (sibirisch) <ADJ>
# ) ()) <PUNCT>
# Phänomene (Phänomen) <NOUN>
# auch (auch) <ADV>
# in (in) <ADP>
# anderen (ander) <ADJ>
# Kulturen (Kultur) <NOUN>
# verortet (verortet) <VERB>
# werden (werden) <AUX>
# , (,) <PUNCT>
# in (in) <ADP>
# deren (der) <DET>
# Traditionen (Tradition) <NOUN>
# sie (ich) <PRON>
# tatsächlich (tatsächlich) <ADV>
# jedoch (jedoch) <ADV>
# fremd (fremd) <ADV>
# sind (sein) <AUX>
# . (.) <PUNCT>
# Beispiele (Beispiel) <NOUN>
# dafür (dafür) <ADV>
# sind (sein) <AUX>
# der (der) <DET>
# Weltenbaum (Weltenbaum) <NOUN>
# und (und) <CCONJ>
# die (der) <DET>
# gesamte (gesamt) <ADJ>
# schamanische (schamanische) <ADJ>
# Kosmologie (Kosmologie) <NOUN>
# : (:) <PUNCT>
# in (in) <ADP>
# Eurasien (Eurasien) <PROPN>
# verankerte (verankern) <ADJ>
# mythologische (mythologische) <ADJ>
# Konzepte (Konzept) <NOUN>
# , (,) <PUNCT>
# die (der) <PRON>
# hier (hier) <ADV>
# mit (mit) <ADP>
# ähnlichen (ähnlich) <ADJ>
# Archetypen (Archetypen) <NOUN>
# anderer (ander) <ADJ>
# Weltgegenden (Weltgegenden) <NOUN>
# gleichgesetzt (gleichsetzen) <VERB>
# werden (werden) <AUX>
# und (und) <CCONJ>
# so (so) <ADV>
# das (der) <DET>
# irreführende (irreführend) <ADJ>
# Bild (Bild) <NOUN>
# eines (ein) <DET>
# einheitlichen (einheitlich) <ADJ>
# Schamanismus (Schamanismus) <NOUN>
# erzeugen.[13 (erzeugen.[13) <PROPN>
# ] (]) <PROPN>
# Witzel (Witzel) <NOUN>
# sieht (sehen) <VERB>
# jedoch (jedoch) <ADV>
# in (in) <ADP>
# der (der) <DET>
# eurasischen (eurasisch) <ADJ>
# ( (() <PUNCT>
# germanischen (germanisch) <ADJ>
# , (,) <PUNCT>
# indischen (indisch) <ADJ>
# , (,) <PUNCT>
# japanischen (japanisch) <ADJ>
# usw. (usw.) <ADV>
# ) ()) <PUNCT>
# Vorstellung (Vorstellung) <NOUN>
# vom (vom) <ADP>
# Baum (Baum) <NOUN>
# des (der) <DET>
# Lebens (Leben) <NOUN>
# , (,) <PUNCT>
# der (der) <DET>
# erstiegen (erstiegen) <VERB>
# werden (werden) <AUX>
# muss (muss) <ADV>
# , (,) <PUNCT>
# beziehungsweise (beziehungsweise) <CCONJ>
# im (im) <ADP>
# Weltenbaum (Weltenbaum) <NOUN>
# nur (nur) <ADV>
# eine (einen) <DET>
# Analogie (Analogie) <NOUN>
# zur (zur) <ADP>
# älteren (alt) <ADJ>
# Vorstellung (Vorstellung) <NOUN>
# des (der) <DET>
# Schamanenflugs (Schamanenflugs) <NOUN>
# , (,) <PUNCT>
# die (der) <PRON>
# nichts (nichts) <PRON>
# mit (mit) <ADP>
# anderen (ander) <ADJ>
# Baummythen (Baummythen) <NOUN>
# zu (zu) <PART>
# tun (tun) <VERB>
# habe.[20 (habe.[20) <PROPN>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# Insbesondere (Insbesondere) <ADV>
# die (der) <DET>
# äußerst (äußern) <ADV>
# erfolgreichen (erfolgreich) <ADJ>
# Bücher (Buch) <NOUN>
# von (von) <ADP>
# Mircea (Mircea) <PROPN>
# Eliade (Eliade) <PROPN>
# , (,) <PUNCT>
# Carlos (Carlos) <PROPN>
# Castaneda (Castaneda) <PROPN>
# und (und) <CCONJ>
# Harner (Harner) <NOUN>
# haben (haben) <AUX>
# den (der) <DET>
# „ („) <PUNCT>
# modernen (modern) <ADJ>
# Mythos (Mythos) <NOUN>
# Schamanismus (Schamanismus) <NOUN>
# “ (“) <PUNCT>
# erzeugt (erzeugen) <VERB>
# , (,) <PUNCT>
# der (der) <PRON>
# suggeriert (suggerieren) <VERB>
# , (,) <PUNCT>
# dass (dass) <SCONJ>
# es (ich) <PRON>
# sich (sich) <PRON>
# dabei (dabei) <ADV>
# um (um) <ADP>
# ein (einen) <DET>
# universelles (universelles) <ADJ>
# und (und) <CCONJ>
# homolog (homolog) <NOUN>
# entstandenes (entstanden) <ADJ>
# religiös-spirituelles (religiös-spirituelles) <ADJ>
# Phänomen (Phänomen) <NOUN>
# handeln (handeln) <VERB>
# würde (werden) <AUX>
# . (.) <PUNCT>
# Im (Im) <ADP>
# Hinblick (Hinblick) <NOUN>
# auf (auf) <ADP>
# das (der) <DET>
# große (groß) <ADJ>
# Interesse (Interesse) <NOUN>
# in (in) <ADP>
# der (der) <DET>
# Bevölkerung[21 (Bevölkerung[21) <NOUN>
# ] (]) <PROPN>
# weisen (weise) <VERB>
# einige (einig) <DET>
# Autoren (Autor) <NOUN>
# darauf (darauf) <ADV>
# hin (hin) <ADV>
# , (,) <PUNCT>
# dass (dass) <SCONJ>
# Schamanismus (Schamanismus) <NOUN>
# keine (kein) <DET>
# einheitliche (einheitliche) <ADJ>
# Ideologie (Ideologie) <NOUN>
# oder (oder) <CCONJ>
# Religion (Religion) <NOUN>
# bestimmter (bestimmt) <ADJ>
# Kulturen (Kultur) <NOUN>
# ist (sein) <AUX>
# . (.) <PUNCT>
# Es (ich) <PRON>
# handle (handeln) <VERB>
# sich (sich) <PRON>
# vielmehr (vielmehr) <ADV>
# um (um) <ADP>
# ein (einen) <DET>
# wissenschaftliches (wissenschaftlich) <ADJ>
# Konstrukt (Konstrukt) <NOUN>
# aus (aus) <ADP>
# eurozentrischer (eurozentrischer) <ADJ>
# Perspektive (Perspektive) <NOUN>
# , (,) <PUNCT>
# um (um) <SCONJ>
# ähnliche (ähnlich) <ADJ>
# Phänomene (Phänomen) <NOUN>
# rund (rund) <ADV>
# um (um) <ADP>
# die (der) <DET>
# Geisterbeschwörer (Geisterbeschwörer) <NOUN>
# unterschiedlichster (unterschiedlich) <ADJ>
# Herkunft (Herkunft) <NOUN>
# zu (zu) <PART>
# vergleichen (vergleichen) <VERB>
# und (und) <CCONJ>
# zu (zu) <ADP>
# klassifizieren.[14][22][23 (klassifizieren.[14][22][23) <PROPN>
# ] (]) <PROPN>
#
#  (
# ) <SPACE>
# Inhaltsverzeichnis (Inhaltsverzeichnis) <X>
#
#
#      (
#
#     ) <SPACE>
# 1 (1) <NUM>
# Etymologie (Etymologie) <NOUN>
#
#      (
#     ) <SPACE>
# 2 (2) <NUM>
# Schamanen (Schamane) <NOUN>
# und (und) <CCONJ>
# Schamanismus (Schamanismus) <NOUN>
#
#      (
#     ) <SPACE>
# 3 (3) <NUM>
# Wissenschaftsgeschichte (Wissenschaftsgeschichte) <NOUN>
#
#      (
#     ) <SPACE>
# 4 (4) <NUM>
# Spirituelle (Spirituelle) <NOUN>
# Schamanismus-Konzepte (Schamanismus-Konzepte) <NOUN>
# : (:) <PUNCT>
# Entstehung (Entstehung) <NOUN>
# , (,) <PUNCT>
# Popularität (Popularität) <NOUN>
# und (und) <CCONJ>
# Kritik (Kritik) <NOUN>
#
#      (
#     ) <SPACE>
# 5 (5) <NUM>
# Weitgehend (Weitgehend) <ADV>
# anerkannte (anerkannt) <ADJ>
# Thesen (These) <NOUN>
#
#          (
#         ) <SPACE>
# 5.1 (5.1) <NUM>
# Der (der) <DET>
# klassisch (klassisch) <ADV>
# sibirische (sibirisch) <ADJ>
# Schamanismus (Schamanismus) <NOUN>
# oder (oder) <CCONJ>
# Animismus (Animismus) <NOUN>
#
#              (
#             ) <SPACE>
# 5.1.1 (5.1.1) <NOUN>
# Historische (historisch) <ADJ>
# Entwicklung (Entwicklung) <NOUN>
#
#              (
#             ) <SPACE>
# 5.1.2 (5.1.2) <X>
# Kosmologie (Kosmologie) <NOUN>
#
#              (
#             ) <SPACE>
# 5.1.3 (5.1.3) <X>
# Die (der) <DET>
# rituelle (rituelle) <ADJ>
# Ekstase (Ekstase) <NOUN>
#
#          (
#         ) <SPACE>
# 5.2 (5.2) <NUM>
# Müller (Müller) <PROPN>
# : (:) <PUNCT>
# Elementar- (Elementar-) <X>
# , (,) <PUNCT>
# Komplex- (Komplex-) <X>
# und (und) <CCONJ>
# Besessenheitsschamanismus (Besessenheitsschamanismus) <NOUN>
#
#              (
#             ) <SPACE>
# 5.2.1 (5.2.1) <X>
# Elementarschamanismus (Elementarschamanismus) <NOUN>
#
#              (
#             ) <SPACE>
# 5.2.2 (5.2.2) <ADJ>
# Komplexschamanismus (Komplexschamanismus) <NOUN>
#
#              (
#             ) <SPACE>
# 5.2.3 (5.2.3) <NUM>
# Besessenheitsschamanismus (Besessenheitsschamanismus) <NOUN>
#
#              (
#             ) <SPACE>
# 5.2.4 (5.2.4) <PROPN>
# Kritik (Kritik) <NOUN>
#
#          (
#         ) <SPACE>
# 5.3 (5.3) <NUM>
# Ganzheitliche (Ganzheitliche) <ADJ>
# Heilkunde (Heilkunde) <NOUN>
#
#      (
#     ) <SPACE>
# 6 (6) <NUM>
# Generelle (generell) <ADJ>
# Kritik (Kritik) <NOUN>
# ; (;) <PUNCT>
# umstrittene (umstritten) <ADJ>
# und (und) <CCONJ>
# spekulative (spekulative) <ADJ>
# Thesen (These) <NOUN>
#
#          (
#         ) <SPACE>
# 6.1 (6.1) <NUM>
# Umstrittene (Umstrittene) <NOUN>
# Thesen (These) <NOUN>
#
#              (
#             ) <SPACE>
# 6.1.1 (6.1.1) <NOUN>
# Prähistorischer (Prähistorischer) <NOUN>
# Schamanismus (Schamanismus) <NOUN>
#
#              (
#             ) <SPACE>
# 6.1.2 (6.1.2) <X>
# Beziehung (Beziehung) <NOUN>
# zum (zum) <ADP>
# Sufismus (Sufismus) <NOUN>
#
#          (
#         ) <SPACE>
# 6.2 (6.2) <NUM>
# Spekulative (spekulativ) <NOUN>
# Thesen (These) <NOUN>
#
#              (
#             ) <SPACE>
# 6.2.1 (6.2.1) <X>
# Schamanismus (Schamanismus) <NOUN>
# als (als) <ADP>
# archaische (archaische) <ADJ>
# Ekstasetechnik (Ekstasetechnik) <NOUN>
#
#              (
#             ) <SPACE>
# 6.2.2 (6.2.2) <ADJ>
# Kritik (Kritik) <NOUN>
#
#      (
#     ) <SPACE>
# 7 (7) <NUM>
# Siehe (Siehe) <VERB>
# auch (auch) <ADV>
#
#      (
#     ) <SPACE>
# 8 (8) <NUM>
# Literatur (Literatur) <NOUN>
#
#      (
#     ) <SPACE>
# 9 (9) <NUM>
# Weblinks (Weblinks) <NOUN>
#
#      (
#     ) <SPACE>
# 10 (10) <NUM>
# Anmerkungen (Anmerkung) <NOUN>
#
#      (
#     ) <SPACE>
# 11 (11) <NUM>
# Einzelnachweise (Einzelnachweise) <NOUN>
#
#
#  (
#
# ) <SPACE>
# Etymologie (Etymologie) <NOUN>
#
#
#  (
#
# ) <SPACE>
# Die (der) <DET>
# Bezeichnung (Bezeichnung) <NOUN>
# Schamanismus (Schamanismus) <NOUN>
# leitet (leiten) <VERB>
# sich (sich) <PRON>
# den (der) <DET>
# meisten (meist) <DET>
# Autoren (Autor) <NOUN>
# zufolge (zufolge) <ADP>
# von (von) <ADP>
# dem (der) <DET>
# aus (aus) <ADP>
# Sibirien (Sibirien) <PROPN>
# entlehnten (entlehnten) <VERB>
# Wort (Wort) <NOUN>
# Schamane (Schamane) <PROPN>
# ab (ab) <ADP>
# , (,) <PUNCT>
# mit (mit) <ADP>
# dem (der) <PRON>
# die (der) <DET>
# tungusischen (tungusischen) <ADJ>
# Völker (Volk) <NOUN>
# ihre (mein) <DET>
# Geisterbeschwörer (Geisterbeschwörer) <NOUN>
# bezeichnen.[24 (bezeichnen.[24) <PROPN>
# ] (]) <PROPN>
# Das (der) <DET>
# Wort (Wort) <NOUN>
# entstammt (entstammen) <VERB>
# vermutlich (vermutlich) <ADV>
# dem (der) <DET>
# evenkischen (evenkischen) <ADJ>
# ( (() <PUNCT>
# d. (d.) <PRON>
# h. (h.) <ADV>
# tungusischen (tungusischen) <ADJ>
# ) ()) <PUNCT>
# šaman (šaman) <NOUN>
# , (,) <PUNCT>
# dessen (der) <DET>
# weitere (weit) <ADJ>
# Etymologie (Etymologie) <NOUN>
# umstritten (umstritten) <ADV>
# ist (sein) <AUX>
# . (.) <PUNCT>
# Möglicherweise (Möglicherweise) <ADV>
# liegt (liegen) <VERB>
# das (der) <DET>
# manjurische (manjurische) <ADJ>
# Verb (Verb) <NOUN>
# sambi (sambi) <PROPN>
# , (,) <PUNCT>
# „ („) <PUNCT>
# wissen (wissen) <VERB>
# , (,) <PUNCT>
# kennen (kennen) <ADJ>
# , (,) <PUNCT>
# durchschauen (durchschauen) <VERB>
# “ (“) <PUNCT>
# , (,) <PUNCT>
# zugrunde (zugrunde) <ADV>
# . (.) <PUNCT>
# Die (der) <DET>
# ältere (alt) <ADJ>
# Bezeichnung (Bezeichnung) <NOUN>
# Schamanentum (Schamanentum) <NOUN>
# bezieht (beziehen) <VERB>
# sich (sich) <PRON>
# nicht (nicht) <PART>
# auf (auf) <ADP>
# die (der) <DET>
# wissenschaftlichen (wissenschaftlich) <ADJ>
# Konzepte (Konzept) <NOUN>
# , (,) <PUNCT>
# sondern (sondern) <CCONJ>
# nur (nur) <ADV>
# auf (auf) <ADP>
# die (der) <DET>
# Existenz (Existenz) <NOUN>
# von (von) <ADP>
# Geisterbeschwörern (Geisterbeschwörern) <NOUN>
# in (in) <ADP>
# verschiedenen (verschieden) <ADJ>
# Kulturen (Kultur) <NOUN>
# , (,) <PUNCT>
# ohne (ohne) <SCONJ>
# dabei (dabei) <ADV>
# bestimmte (bestimmen) <ADJ>
# Zusammenhänge (Zusammenhang) <NOUN>
# herzustellen.[25 (herzustellen.[25) <PROPN>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# ( (() <PUNCT>
# Weitere (Weitere) <ADJ>
# Informationen (Information) <NOUN>
# siehe (siehe) <VERB>
# : (:) <PUNCT>
# Etymologie (Etymologie) <NOUN>
# im (im) <ADP>
# Artikel (Artikel) <NOUN>
# „ („) <PUNCT>
# Schamane (Schamane) <PROPN>
# “ (“) <PUNCT>
# ) ()) <PUNCT>
#
#  (
# ) <SPACE>
# Schamanen (Schamane) <NOUN>
# und (und) <CCONJ>
# Schamanismus (Schamanismus) <NOUN>
#
#  (
# ) <SPACE>
# George (George) <PROPN>
# Catlins (Catlins) <PROPN>
# Darstellung (Darstellung) <NOUN>
# eines (ein) <DET>
# Schamanen (Schamane) <NOUN>
# ( (() <PUNCT>
# Medicine (Medicine) <PROPN>
# man (man) <PRON>
# ) ()) <PUNCT>
# der (der) <DET>
# Schwarzfuß-Indianer (Schwarzfuß-Indianer) <NOUN>
# , (,) <PUNCT>
# der (der) <PRON>
# Riten (Riten) <NOUN>
# über (über) <ADP>
# einem (einer) <DET>
# sterbenden (sterbend) <ADJ>
# Häuptling (Häuptling) <NOUN>
# vollführt (vollführen) <VERB>
# . (.) <PUNCT>
#
#  (
# ) <SPACE>
# → (→) <ADJ>
# Hauptartikel (Hauptartikel) <PROPN>
# : (:) <PUNCT>
# Schamane (Schamane) <PROPN>
#
#
#  (
#
# ) <SPACE>
# Im (Im) <ADP>
# Allgemeinen (Allgemeine) <NOUN>
# wird (werden) <AUX>
# die (der) <DET>
# aus (aus) <ADP>
# Sibirien (Sibirien) <PROPN>
# entlehnte (entlehnte) <ADJ>
# Bezeichnung (Bezeichnung) <NOUN>
# Schamane (Schamane) <PROPN>
# verwendet (verwenden) <VERB>
# , (,) <PUNCT>
# um (um) <SCONJ>
# spirituelle (spirituell) <ADJ>
# Spezialisten (Spezialist) <NOUN>
# zu (zu) <PART>
# bezeichnen (bezeichnen) <VERB>
# , (,) <PUNCT>
# die (der) <PRON>
# über (über) <ADP>
# ( (() <PUNCT>
# angeblich (angeblich) <ADV>
# ) ()) <PUNCT>
# „ („) <PUNCT>
# magische (magische) <ADJ>
# “ (“) <PUNCT>
# Fähigkeiten (Fähigkeit) <NOUN>
# als (als) <ADP>
# Vermittler (Vermittler) <NOUN>
# zur (zur) <ADP>
# Geisterwelt (Geisterwelt) <NOUN>
# verfügen.[26][27][10 (verfügen.[26][27][10) <NOUN>
# ] (]) <NOUN>
# Solche (solch) <DET>
# Geisterbeschwörer (Geisterbeschwörer) <NOUN>
# sind (sein) <AUX>
# Teil (Teil) <NOUN>
# vieler (viel) <DET>
# ethnischer (ethnisch) <ADJ>
# Religionen (Religion) <NOUN>
# , (,) <PUNCT>
# aber (aber) <CCONJ>
# auch (auch) <ADV>
# mancher (manch) <DET>
# volksreligiöser (volksreligiöser) <ADJ>
# Ausprägungen (Ausprägung) <NOUN>
# der (der) <DET>
# Weltreligionen.[12 (Weltreligionen.[12) <NOUN>
# ] (]) <PROPN>
# Vornehmlich (Vornehmlich) <ADV>
# bei (bei) <ADP>
# einigen (einig) <DET>
# indigenen (indigenen) <ADJ>
# oder (oder) <CCONJ>
# traditionellen (traditionell) <ADJ>
# lokalen (lokal) <ADJ>
# Gemeinschaften (Gemeinschaft) <NOUN>
# spielen (spielen) <VERB>
# Schamanen (Schamane) <NOUN>
# heute (heute) <ADV>
# noch (noch) <ADV>
# eine (einen) <DET>
# wichtige (wichtig) <ADJ>
# Rolle (Rolle) <NOUN>
# ( (() <PUNCT>
# → (→) <PROPN>
# „ („) <PUNCT>
# Traditionelle (Traditionelle) <ADJ>
# spirituelle (spirituell) <ADJ>
# Spezialisten (Spezialist) <NOUN>
# der (der) <DET>
# Gegenwart (Gegenwart) <NOUN>
# im (im) <ADP>
# Licht (Licht) <NOUN>
# der (der) <DET>
# Geschichte (Geschichte) <NOUN>
# “ (“) <PUNCT>
# im (im) <ADP>
# Artikel (Artikel) <NOUN>
# Schamane (Schamane) <PROPN>
# ) ()) <PUNCT>
# . (.) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# Seit (seit) <ADP>
# den (der) <DET>
# ersten (erst) <ADJ>
# Beschreibungen (Beschreibung) <NOUN>
# solcher (solch) <DET>
# spirituellen (spirituell) <ADJ>
# Experten (Experte) <NOUN>
# in (in) <ADP>
# verschiedenen (verschieden) <ADJ>
# Gesellschaften (Gesellschaft) <NOUN>
# haben (haben) <AUX>
# europäische (europäische) <ADJ>
# Völkerkundler (Völkerkundler) <NOUN>
# versucht (versuchen) <VERB>
# , (,) <PUNCT>
# Ähnlichkeiten (Ähnlichkeit) <NOUN>
# und (und) <CCONJ>
# eventuelle (eventuelle) <ADJ>
# Muster (Muster) <NOUN>
# zu (zu) <PART>
# erkennen (erkennen) <VERB>
# und (und) <CCONJ>
# Zusammenhänge (Zusammenhang) <NOUN>
# abzuleiten (ableiten) <VERB>
# . (.) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# Die (der) <DET>
# Existenz (Existenz) <NOUN>
# eines (ein) <DET>
# Schamanen (Schamane) <NOUN>
# ist (sein) <AUX>
# zweifellos (zweifellos) <ADV>
# eine (einen) <DET>
# Voraussetzung (Voraussetzung) <NOUN>
# für (für) <ADP>
# jegliche (jeglich) <DET>
# Schamanismus-These (Schamanismus-These) <NOUN>
# , (,) <PUNCT>
# jedoch (jedoch) <ADV>
# nicht (nicht) <PART>
# unbedingt (unbedingt) <ADV>
# der (der) <DET>
# zentrale (zentrale) <ADJ>
# Gedanke (Gedanke) <NOUN>
# . (.) <PUNCT>
# Es (ich) <PRON>
# geht (gehen) <VERB>
# häufig (häufig) <ADV>
# eher (eher) <ADV>
# um (um) <ADP>
# religiöse (religiös) <ADJ>
# Überzeugungen (Überzeugung) <NOUN>
# , (,) <PUNCT>
# Riten (Riten) <NOUN>
# und (und) <CCONJ>
# Traditionen,[28 (Traditionen,[28) <PROPN>
# ] (]) <PROPN>
# statt (statt) <ADP>
# um (um) <ADP>
# die (der) <DET>
# herausgehobene (herausgehoben) <ADJ>
# Rolle (Rolle) <NOUN>
# des (der) <DET>
# Schamanen (Schamane) <NOUN>
# . (.) <PUNCT>
# Insofern (insofern) <ADV>
# entstanden (entstehen) <VERB>
# die (der) <DET>
# verschiedenen (verschieden) <ADJ>
# , (,) <PUNCT>
# konzeptuell (konzeptuell) <ADV>
# abweichenden (abweichend) <ADJ>
# Definitionen.[3 (Definitionen.[3) <PROPN>
# ] (]) <ADJ>
#
#
#  (
#
# ) <SPACE>
# Die (der) <DET>
# Schamanen (Schamane) <NOUN>
# sind (sein) <AUX>
# eingebunden (einbinden) <VERB>
# in (in) <ADP>
# die (der) <DET>
# Lebenswelt (Lebenswelt) <NOUN>
# und (und) <CCONJ>
# naturräumliche (naturräumliche) <ADJ>
# Umwelt (Umwelt) <NOUN>
# ihrer (sich) <DET>
# jeweiligen (jeweilig) <ADJ>
# Kulturen (Kultur) <NOUN>
# und (und) <CCONJ>
# können (können) <AUX>
# nicht (nicht) <PART>
# als (als) <ADP>
# Verkörperung (Verkörperung) <NOUN>
# einer (einer) <DET>
# bestimmten (bestimmen) <ADJ>
# schamanistischen (schamanistischen) <ADJ>
# Religion (Religion) <NOUN>
# oder (oder) <CCONJ>
# Kosmologie (Kosmologie) <NOUN>
# betrachtet (betrachten) <VERB>
# werden.[29 (werden.[29) <PROPN>
# ] (]) <PROPN>
# So (so) <ADV>
# hängt (hängen) <VERB>
# der (der) <DET>
# Schamanismus (Schamanismus) <NOUN>
# eng (engen) <ADV>
# mit (mit) <ADP>
# der (der) <DET>
# Heilung (Heilung) <NOUN>
# von (von) <ADP>
# Kranken (Kranke) <NOUN>
# , (,) <PUNCT>
# mit (mit) <ADP>
# Bestattungsriten (Bestattungsriten) <NOUN>
# und (und) <CCONJ>
# mit (mit) <ADP>
# Jagdzauber (Jagdzauber) <NOUN>
# zusammen (zusammen) <ADV>
# . (.) <PUNCT>
# Michael (Michael) <PROPN>
# Lütge (Lütge) <PROPN>
# vergleicht (vergleichen) <VERB>
# seine (mein) <DET>
# Rolle (Rolle) <NOUN>
# mit (mit) <ADP>
# der (der) <DET>
# „ („) <PUNCT>
# Anamnese (Anamnese) <NOUN>
# des (der) <DET>
# Gemeindepfarrers (Gemeindepfarrers) <NOUN>
# beim (beim) <ADP>
# Kondolenzbesuch (Kondolenzbesuch) <NOUN>
# “ (“) <PUNCT>
# , (,) <PUNCT>
# der (der) <DET>
# biographische (biographische) <ADJ>
# Bruchstücke (Bruchstück) <NOUN>
# des (der) <DET>
# Toten (Tote) <NOUN>
# aufspürt (aufspüren) <VERB>
# , (,) <PUNCT>
# die (der) <PRON>
# ihn (ich) <PRON>
# vom (vom) <ADP>
# engeren (eng) <ADJ>
# Kreis (Kreis) <NOUN>
# der (der) <DET>
# Angehörigen (Angehörige) <NOUN>
# her (her) <ADP>
# „ („) <PUNCT>
# anwehen (anwehen) <VERB>
# “ (“) <PUNCT>
# . (.) <PUNCT>
# In (In) <ADP>
# anderen (ander) <ADJ>
# Situationen (Situation) <NOUN>
# praktiziert (praktizieren) <VERB>
# er (ich) <PRON>
# „ („) <PUNCT>
# antizipative (antizipative) <ADJ>
# [ ([) <NOUN>
# ... (...) <PUNCT>
# ] (]) <ADJ>
# Jagdpropädeutik (Jagdpropädeutik) <NOUN>
# ähnlich (ähnlich) <ADV>
# der (der) <DET>
# schulischen (schulisch) <ADJ>
# Brandschutzübung“.[30 (Brandschutzübung“.[30) <X>
# ] (]) <PROPN>
#
#  (
# ) <SPACE>
# Wissenschaftsgeschichte (Wissenschaftsgeschichte) <NOUN>
#
#  (
# ) <SPACE>
# Sowjetische (Sowjetische) <ADJ>
# Ethnologen (Ethnologe) <NOUN>
# sahen (sehen) <VERB>
# in (in) <ADP>
# den (der) <DET>
# Schamanen (Schamane) <NOUN>
# Männer (Mann) <NOUN>
# , (,) <PUNCT>
# die (der) <PRON>
# mit (mit) <ADP>
# Hilfe (Hilfe) <NOUN>
# religiöser (religiös) <ADJ>
# Rituale (Ritual) <NOUN>
# politische (politische) <ADJ>
# Macht (Macht) <NOUN>
# gewinnen (gewinnen) <VERB>
# wollten (wollen) <AUX>
# . (.) <PUNCT>
# Tatsächlich (Tatsächlich) <ADV>
# gab (geben) <VERB>
# es (ich) <PRON>
# ebenso (ebenso) <ADV>
# weibliche (weibliche) <ADJ>
# Schamanen (Schamane) <NOUN>
# und (und) <CCONJ>
# soziopolitisch (soziopolitisch) <ADV>
# standen (stehen) <VERB>
# Geisterbeschwörer (Geisterbeschwörer) <NOUN>
# eher (eher) <ADV>
# außerhalb (außerhalb) <ADP>
# der (der) <DET>
# Gesellschaft (Gesellschaft) <NOUN>
#
#  (
# ) <SPACE>
# Mircea (Mircea) <PROPN>
# Eliade (Eliade) <PROPN>
# gilt (gelten) <VERB>
# als (als) <ADP>
# Begründer (Begründer) <NOUN>
# der (der) <DET>
# „ („) <PUNCT>
# Schamanismus-These (Schamanismus-These) <NOUN>
# “ (“) <PUNCT>
# , (,) <PUNCT>
# auf (auf) <ADP>
# die (der) <PRON>
# sich (sich) <PRON>
# heute (heute) <ADV>
# insbesondere (insbesondere) <ADV>
# der (der) <DET>
# esoterische (esoterisch) <ADJ>
# Neoschamanismus (Neoschamanismus) <NOUN>
# beruft (berufen) <VERB>
# . (.) <PUNCT>
# Die (der) <DET>
# Gültigkeit (Gültigkeit) <NOUN>
# seiner (sich) <DET>
# Theorie (Theorie) <NOUN>
# und (und) <CCONJ>
# die (der) <DET>
# Seriosität (Seriosität) <NOUN>
# seiner (sich) <DET>
# Arbeit (Arbeit) <NOUN>
# ist (sein) <AUX>
# in (in) <ADP>
# der (der) <DET>
# Wissenschaft (Wissenschaft) <NOUN>
# stark (stark) <ADV>
# umstritten.[31 (umstritten.[31) <PROPN>
# ] (]) <PROPN>
#
#  (
# ) <SPACE>
# Mexikanischer (Mexikanischer) <ADJ>
# Kahlkopf (Kahlkopf) <NOUN>
# , (,) <PUNCT>
# der (der) <DET>
# erste (erste) <ADJ>
# populäre (populäre) <ADJ>
# „ („) <PUNCT>
# Rauschpilz (Rauschpilz) <NOUN>
# “ (“) <PUNCT>
#
#  (
# ) <SPACE>
# Die (der) <DET>
# Hippiebewegung (Hippiebewegung) <NOUN>
# ebnete (ebnen) <VERB>
# den (der) <DET>
# Weg (Weg) <NOUN>
# für (für) <ADP>
# eine (einen) <DET>
# neue (neue) <ADJ>
# Spiritualität (Spiritualität) <NOUN>
# im (im) <ADP>
# Westen (Westen) <NOUN>
#
#  (
# ) <SPACE>
# Phantasie-Bildnis (Phantasie-Bildnis) <NOUN>
# der (der) <DET>
# literarischen (literarisch) <ADJ>
# Schamanengestalt (Schamanengestalt) <NOUN>
# Don (Don) <PROPN>
# Juan (Juan) <PROPN>
# Matus (Matus) <PROPN>
# ( (() <PUNCT>
# Jacob (Jacob) <PROPN>
# Wayne (Wayne) <PROPN>
# Bryner (Bryner) <PROPN>
# ) ()) <PUNCT>
# , (,) <PUNCT>
# die (der) <PRON>
# den (der) <DET>
# Schriftsteller (Schriftsteller) <NOUN>
# Castañeda (Castañeda) <PROPN>
# weltberühmt (weltberühmt) <VERB>
# machte (machen) <VERB>
#
#  (
# ) <SPACE>
# Tuwinischer (Tuwinischer) <NOUN>
# Schamane (Schamane) <PROPN>
# : (:) <PUNCT>
# Traditionelles (Traditionelles) <ADJ>
# Wissen (Wissen) <NOUN>
# wird (werden) <AUX>
# durch (durch) <ADP>
# neoschamanistische (neoschamanistische) <ADJ>
# Einflüsse (Einfluß) <NOUN>
# verfälscht (verfälschen) <VERB>
#
#  (
# ) <SPACE>
# → (→) <ADJ>
# Hauptartikel (Hauptartikel) <NOUN>
# : (:) <PUNCT>
# Schamanismusforschung (Schamanismusforschung) <NOUN>
#
#
#      (
#
#     ) <SPACE>
# „ („) <PUNCT>
# Schamanismus (Schamanismus) <NOUN>
# ist (sein) <AUX>
# keine (kein) <DET>
# einheitliche (einheitliche) <ADJ>
# Religion (Religion) <NOUN>
# , (,) <PUNCT>
# sondern (sondern) <CCONJ>
# eine (einen) <DET>
# kulturübergreifende (kulturübergreifende) <ADJ>
# Form (Form) <NOUN>
# religiöser (religiös) <ADJ>
# Wahrnehmung (Wahrnehmung) <NOUN>
# und (und) <CCONJ>
# Praxis (Praxis) <NOUN>
# . (.) <PUNCT>
# “ (“) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# – (–) <PUNCT>
# Piers (Pier) <PROPN>
# Vitebsky[7 (Vitebsky[7) <PROPN>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# Seit (seit) <ADP>
# Ende (Ende) <NOUN>
# des (der) <DET>
# 17. (17.) <ADJ>
# Jahrhunderts (Jahrhundert) <NOUN>
# gibt (geben) <VERB>
# es (ich) <PRON>
# detaillierte (detaillierte) <ADJ>
# Berichte (Bericht) <NOUN>
# über (über) <ADP>
# die (der) <DET>
# Schamanen (Schamane) <NOUN>
# Sibiriens (Sibiriens) <PROPN>
# und (und) <CCONJ>
# ihre (mein) <DET>
# Praktiken (Praktik) <NOUN>
# . (.) <PUNCT>
# Die (der) <DET>
# Einstellung (Einstellung) <NOUN>
# der (der) <DET>
# Europäer (Europäer) <NOUN>
# dazu (dazu) <ADV>
# pendelte (pendeln) <VERB>
# mehrmals (mehrmals) <ADV>
# zwischen (zwischen) <ADP>
# Hochachtung (Hochachtung) <NOUN>
# und (und) <CCONJ>
# Verachtung (Verachtung) <NOUN>
# hin (hin) <ADV>
# und (und) <CCONJ>
# her (her) <ADV>
# . (.) <PUNCT>
# Anfangs (Anfang) <ADV>
# riefen (rufen) <VERB>
# diese (dies) <DET>
# Berichte (Bericht) <NOUN>
# nur (nur) <ADV>
# Abneigung (Abneigung) <NOUN>
# und (und) <CCONJ>
# Unverständnis (Unverständnis) <NOUN>
# hervor.[32 (hervor.[32) <X>
# ] (]) <X>
# Im (Im) <ADP>
# Verlauf (Verlauf) <NOUN>
# der (der) <DET>
# deutschen (deutsch) <ADJ>
# Romantik (Romantik) <NOUN>
# schlug (schlagen) <VERB>
# das (der) <DET>
# Pendel (Pendel) <NOUN>
# in (in) <ADP>
# die (der) <DET>
# entgegengesetzte (entgegengesetzt) <ADJ>
# Richtung (Richtung) <NOUN>
# und (und) <CCONJ>
# Schamanen (Schamane) <NOUN>
# wurden (werden) <AUX>
# als (als) <ADP>
# „ („) <PUNCT>
# charismatische (charismatische) <ADJ>
# Genies (Genie) <PROPN>
# “ (“) <PUNCT>
# verklärt (verklären) <VERB>
# . (.) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# Auch (Auch) <ADV>
# die (der) <DET>
# wissenschaftliche (wissenschaftliche) <ADJ>
# Forschung (Forschung) <NOUN>
# im (im) <ADP>
# Rahmen (Rahmen) <NOUN>
# der (der) <DET>
# Völkerkunde (Völkerkunde) <NOUN>
# ist (sein) <AUX>
# von (von) <ADP>
# dieser (dies) <DET>
# großen (groß) <ADJ>
# Diskrepanz (Diskrepanz) <NOUN>
# gekennzeichnet (kennzeichnen) <VERB>
# : (:) <PUNCT>
# Zunächst (Zunächst) <ADV>
# wurden (werden) <AUX>
# Schamanen (Schamane) <NOUN>
# als (als) <ADP>
# krankhaft (krankhaft) <ADV>
# psychotisch (psychotisch) <ADV>
# angesehen (ansehen) <VERB>
# und (und) <CCONJ>
# ihre (mein) <DET>
# Ausdrucksformen (Ausdrucksformen) <NOUN>
# als (als) <ADP>
# „ („) <PUNCT>
# arktische (arktische) <ADJ>
# Hysterie (Hysterie) <NOUN>
# “ (“) <PUNCT>
# bezeichnet.[33 (bezeichnet.[33) <VERB>
# ] (]) <PROPN>
# Später (Später) <ADV>
# wurden (werden) <AUX>
# Epilepsie (Epilepsie) <NOUN>
# oder (oder) <CCONJ>
# Schizophrenie (Schizophrenie) <NOUN>
# in (in) <ADP>
# Beziehung (Beziehung) <NOUN>
# zum (zum) <ADP>
# Schamanentum (Schamanentum) <NOUN>
# gesetzt.[34 (gesetzt.[34) <ADJ>
# ] (]) <NOUN>
#
#
#  (
#
# ) <SPACE>
# Doch (doch) <CCONJ>
# bereits (bereits) <ADV>
# Anfang (Anfang) <NOUN>
# des (der) <DET>
# 20. (20.) <ADJ>
# Jahrhunderts (Jahrhundert) <NOUN>
# wurden (werden) <AUX>
# die (der) <DET>
# besondere (besonder) <ADJ>
# gesellschaftliche (gesellschaftliche) <ADJ>
# Stellung (Stellung) <NOUN>
# des (der) <DET>
# sibirischen (sibirisch) <ADJ>
# „ („) <PUNCT>
# Master (Master) <PROPN>
# of (of) <PROPN>
# Spirits (Spirits) <PROPN>
# “ (“) <PUNCT>
# und (und) <CCONJ>
# die (der) <DET>
# Legitimation (Legitimation) <NOUN>
# seines (mein) <DET>
# Handelns (Handeln) <NOUN>
# im (im) <ADP>
# jeweiligen (jeweilig) <ADJ>
# kulturellen (kulturell) <ADJ>
# und (und) <CCONJ>
# historischen (historisch) <ADJ>
# Kontext (Kontext) <NOUN>
# aus (aus) <ADP>
# soziologischer (soziologisch) <ADJ>
# und (und) <CCONJ>
# psychologischer (psychologisch) <ADJ>
# Sicht (Sicht) <NOUN>
# detailliert (detailliert) <ADV>
# untersucht (untersuchen) <VERB>
# : (:) <PUNCT>
# Er (ich) <PRON>
# sei (sein) <AUX>
# legitimiert (legitimieren) <VERB>
# , (,) <PUNCT>
# Techniken (Technik) <NOUN>
# auszuführen (ausführen) <VERB>
# , (,) <PUNCT>
# die (der) <PRON>
# auch (auch) <ADV>
# andere (ander) <ADJ>
# Gesellschaftsmitglieder (Gesellschaftsmitglieder) <NOUN>
# im (im) <ADP>
# Alltag (Alltag) <NOUN>
# beherrschten (beherrschen) <VERB>
# . (.) <PUNCT>
# Shirokogoroff (Shirokogoroff) <PROPN>
# fand (finden) <VERB>
# bei (bei) <ADP>
# seinen (seinen) <DET>
# Feldforschungen (Feldforschungen) <NOUN>
# unter (unter) <ADP>
# Ewenken (Ewenken) <NOUN>
# und (und) <CCONJ>
# Mandschu (Mandschu) <PROPN>
# , (,) <PUNCT>
# dass (dass) <SCONJ>
# es (ich) <PRON>
# sich (sich) <PRON>
# bei (bei) <ADP>
# den (der) <DET>
# Schamanen (Schamane) <NOUN>
# zwar (zwar) <ADV>
# häufig (häufig) <ADV>
# um (um) <ADP>
# neurotische (neurotische) <ADJ>
# Personen (Person) <NOUN>
# handle (handeln) <VERB>
# ; (;) <PUNCT>
# er (ich) <PRON>
# grenzte (grenzen) <VERB>
# sich (sich) <PRON>
# aber (aber) <ADV>
# von (von) <ADP>
# dem (der) <DET>
# damaligen (damalig) <ADJ>
# verbreiteten (verbreiten) <ADJ>
# Erklärungsmodell (Erklärungsmodell) <NOUN>
# für (für) <ADP>
# das (der) <DET>
# Handeln (Handeln) <NOUN>
# der (der) <DET>
# Schamanen (Schamane) <NOUN>
# ab (ab) <ADP>
# : (:) <PUNCT>
# Die (der) <DET>
# Trancen (Trancen) <NOUN>
# , (,) <PUNCT>
# rituelle (rituelle) <ADJ>
# Ekstasen (Ekstase) <NOUN>
# oder (oder) <CCONJ>
# „ („) <PUNCT>
# Anfälle (Anfall) <NOUN>
# “ (“) <PUNCT>
# der (der) <DET>
# Schamanen (Schamane) <NOUN>
# seien (sein) <AUX>
# nicht (nicht) <PART>
# Ausdruck (Ausdruck) <NOUN>
# von (von) <ADP>
# Hysterie (Hysterie) <NOUN>
# oder (oder) <CCONJ>
# Besessenheit (Besessenheit) <NOUN>
# , (,) <PUNCT>
# sondern (sondern) <CCONJ>
# wohlinszenierte (wohlinszenierte) <ADJ>
# , (,) <PUNCT>
# kulturell (kulturell) <ADV>
# codierte (codieren) <ADJ>
# performative (performative) <ADJ>
# Konfliktlösungen (Konfliktlösungen) <NOUN>
# , (,) <PUNCT>
# die (der) <PRON>
# z. (z.) <ADP>
# B. (B.) <NOUN>
# gegen (gegen) <ADP>
# die (der) <DET>
# russische (russische) <ADJ>
# Fremdherrschaft (Fremdherrschaft) <NOUN>
# eingesetzt (einsetzen) <VERB>
# wurden[35 (wurden[35) <DET>
# ] (]) <NOUN>
# – (–) <PUNCT>
# also (also) <ADV>
# historisch (historisch) <ADV>
# spezifisch (spezifisch) <ADV>
# ausgeprägte (ausgeprägt) <ADJ>
# Phänomene (Phänomen) <NOUN>
# . (.) <PUNCT>
# So (so) <ADV>
# wurden (werden) <AUX>
# in (in) <ADP>
# der (der) <DET>
# Sowjetunion (Sowjetunion) <PROPN>
# Schamanen (Schamane) <NOUN>
# als (als) <ADP>
# Scharlatane (Scharlatan) <NOUN>
# verunglimpft (verunglimpfen) <VERB>
# , (,) <PUNCT>
# die (der) <PRON>
# sich (sich) <PRON>
# angeblich (angeblich) <ADV>
# mit (mit) <ADP>
# Hilfe (Hilfe) <NOUN>
# religiöser (religiös) <ADJ>
# Rituale (Ritual) <NOUN>
# Macht (Macht) <NOUN>
# verschaffen (verschaffen) <VERB>
# wollten.[36 (wollten.[36) <PROPN>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# Auch (Auch) <ADV>
# die (der) <DET>
# „ („) <PUNCT>
# Geistermänner (Geistermänner) <NOUN>
# “ (“) <PUNCT>
# oder (oder) <CCONJ>
# „ („) <PUNCT>
# Zaubermänner (Zaubermänner) <NOUN>
# “ (“) <PUNCT>
# Nordamerikas (Nordamerikas) <PROPN>
# übernahmen (übernahmen) <VERB>
# im (im) <ADP>
# Verlauf (Verlauf) <NOUN>
# der (der) <DET>
# Westwanderung (Westwanderung) <NOUN>
# des (der) <DET>
# weißen (weiß) <ADJ>
# Kolonisten (Kolonist) <NOUN>
# immer (immer) <ADV>
# wieder (wieder) <ADV>
# die (der) <DET>
# Rolle (Rolle) <NOUN>
# politischer (politisch) <ADJ>
# Führer (Führer) <NOUN>
# und (und) <CCONJ>
# setzten (setzen) <VERB>
# sich (sich) <PRON>
# an (an) <ADP>
# die (der) <DET>
# Spitze (spitzen) <NOUN>
# nativistischer (nativistischer) <ADJ>
# Bewegungen (Bewegung) <NOUN>
# . (.) <PUNCT>
# So (so) <ADV>
# wurde (werden) <AUX>
# schon (schon) <ADV>
# 1680 (1680) <NUM>
# ein (einen) <DET>
# zeitweise (zeitweise) <ADV>
# erfolgreicher (erfolgreich) <ADJ>
# Aufstand (Aufstand) <NOUN>
# des (der) <DET>
# Tewa (Tewa) <NOUN>
# in (in) <ADP>
# New (New) <PROPN>
# Mexico (Mexico) <PROPN>
# gegen (gegen) <ADP>
# die (der) <DET>
# spanischen (spanisch) <ADJ>
# Kolonisten (Kolonist) <NOUN>
# vom (vom) <ADP>
# Medizinmann (Medizinmann) <PROPN>
# El (El) <PROPN>
# Popé (Popé) <PROPN>
# organisiert (organisieren) <VERB>
# . (.) <PUNCT>
# In (In) <ADP>
# afrikanischen (afrikanisch) <ADJ>
# Revolten (Revolte) <NOUN>
# gegen (gegen) <ADP>
# die (der) <DET>
# Kolonialherren (Kolonialherren) <NOUN>
# spielten (spielen) <VERB>
# spirituelle (spirituell) <ADJ>
# Vermittler (Vermittler) <NOUN>
# häufig (häufig) <ADV>
# eine (einen) <DET>
# Rolle (Rolle) <NOUN>
# als (als) <ADP>
# Anführer (Anführer) <NOUN>
# , (,) <PUNCT>
# so (so) <ADV>
# der (der) <DET>
# angeblich (angeblich) <ADV>
# vom (vom) <ADP>
# Geist (Geist) <NOUN>
# Hongo (Hongo) <PROPN>
# des (der) <DET>
# Schlangengotts (Schlangengotts) <NOUN>
# besessene (besessen) <ADJ>
# Heiler (Heiler) <ADJ>
# Kinjikitile (Kinjikitile) <NOUN>
# Ngwale (Ngwale) <NOUN>
# im (im) <ADP>
# Maji-Maji-Aufstand (Maji-Maji-Aufstand) <NOUN>
# 1905–1907. (1905–1907.) <NUM>
# Wer (Wer) <PRON>
# zeigte (zeigen) <VERB>
# , (,) <PUNCT>
# dass (dass) <SCONJ>
# er (ich) <PRON>
# von (von) <ADP>
# einem (einer) <DET>
# Hongo (Hongo) <NOUN>
# besessen (besitzen) <VERB>
# war (sein) <AUX>
# , (,) <PUNCT>
# konnte (können) <AUX>
# die (der) <DET>
# Religion (Religion) <NOUN>
# und (und) <CCONJ>
# Politik (Politik) <NOUN>
# seiner (sich) <DET>
# Ethnie (Ethnie) <NOUN>
# in (in) <ADP>
# hohem (hoch) <ADJ>
# Maße (Maß) <NOUN>
# beeinflussen (beeinflussen) <VERB>
# . (.) <PUNCT>
# Auch (Auch) <ADV>
# Lévi-Strauss (Lévi-Strauss) <PROPN>
# berichtet (berichten) <VERB>
# von (von) <ADP>
# Schamanen (Schamane) <NOUN>
# , (,) <PUNCT>
# die (der) <PRON>
# in (in) <ADP>
# Konkurrenz (Konkurrenz) <NOUN>
# zu (zu) <ADP>
# Stammesführern (Stammesführern) <NOUN>
# traten.[37 (traten.[37) <NOUN>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# Mit (Mit) <ADP>
# der (der) <DET>
# Aufgabe (Aufgabe) <NOUN>
# der (der) <DET>
# als (als) <ADP>
# rassistisch (rassistisch) <ADV>
# verpönten (verpönen) <ADJ>
# deutschen (deutsch) <ADJ>
# Kulturkreislehre (Kulturkreislehre) <NOUN>
# und (und) <CCONJ>
# der (der) <DET>
# evolutionistischen (evolutionistischen) <ADJ>
# „ („) <PUNCT>
# Stufen-Ideologie (Stufen-Ideologie) <NOUN>
# “ (“) <PUNCT>
# in (in) <ADP>
# den (der) <DET>
# marxistisch (marxistisch) <ADV>
# beeinflussten (beeinflussten) <ADJ>
# Staaten (Staat) <NOUN>
# setzte (setzen) <VERB>
# sich (sich) <PRON>
# in (in) <ADP>
# der (der) <DET>
# Ethnologie (Ethnologie) <NOUN>
# eine (einen) <DET>
# respektvollere (respektvoll) <ADJ>
# Haltung (Haltung) <NOUN>
# zu (zu) <ADP>
# den (der) <DET>
# Kulturen (Kultur) <NOUN>
# der (der) <DET>
# sogenannten (sogenannt) <ADJ>
# Naturvölker (Naturvölker) <NOUN>
# durch.[38 (durch.[38) <PROPN>
# ] (]) <PROPN>
#
#
#  (
#
# ) <SPACE>
# In (In) <ADP>
# Nordamerika (Nordamerika) <PROPN>
# kam (kommen) <VERB>
# es (ich) <PRON>
# bereits (bereits) <ADV>
# um (um) <ADP>
# die (der) <DET>
# Wende (Wende) <NOUN>
# zum (zum) <ADP>
# 20. (20.) <ADJ>
# Jahrhundert (Jahrhundert) <NOUN>
# zu (zu) <ADP>
# einer (einer) <DET>
# gewissen (gewiß) <ADJ>
# Romantisierung (Romantisierung) <NOUN>
# und (und) <CCONJ>
# Idealisierung (Idealisierung) <NOUN>
# der (der) <DET>
# indianischen (indianisch) <ADJ>
# Kulturen (Kultur) <NOUN>
# Nordamerikas (Nordamerikas) <PROPN>
# und (und) <CCONJ>
# mit (mit) <ADP>
# ihnen (ich) <PRON>
# der (der) <DET>
# spirituell-religiösen (spirituell-religiösen) <ADJ>
# Vorstellungen (Vorstellung) <NOUN>
# , (,) <PUNCT>
# die (der) <PRON>
# bald (bald) <ADV>
# mit (mit) <ADP>
# dem (der) <DET>
# Ekstase-Schamanismus (Ekstase-Schamanismus) <NOUN>
# Sibiriens (Sibiriens) <PROPN>
# und (und) <CCONJ>
# später (spät) <ADV>
# auch (auch) <ADV>
# mit (mit) <ADP>
# den (der) <DET>
# okkulten (okkult) <ADJ>
# Praktiken (Praktik) <NOUN>
# Südamerikas (Südamerika) <PROPN>
# bis (bis) <ADP>
# hin (hin) <ADV>
# zu (zu) <ADP>
# denen (der) <PRON>
# der (der) <DET>
# Selk (Selk) <PROPN>
# ’ (’) <PROPN>
# nam (nam) <PROPN>
# auf (auf) <ADP>
# Feuerland (Feuerland) <PROPN>
# als (als) <ADP>
# shamanistic (shamanistic) <PROPN>
# complex (complex) <PROPN>
# zusammengefasst (zusammengefasst) <VERB>
# wurden (werden) <AUX>
# . (.) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# Der (der) <DET>
# rumänische (rumänische) <ADJ>
# Religionswissenschaftler (Religionswissenschaftler) <NOUN>
# und (und) <CCONJ>
# Roman-Autor (Roman-Autor) <NOUN>
# Mircea (Mircea) <PROPN>
# Eliade (Eliade) <PROPN>
# war (sein) <AUX>
# es (ich) <PRON>
# schließlich (schließlich) <ADV>
# , (,) <PUNCT>
# der (der) <PRON>
# 1951 (1951) <NUM>
# den (der) <DET>
# Begriff (Begriff) <NOUN>
# „ („) <PUNCT>
# Schamanismus (Schamanismus) <NOUN>
# “ (“) <PUNCT>
# entscheidend (entscheiden) <ADV>
# prägte (prägen) <VERB>
# und (und) <CCONJ>
# in (in) <ADP>
# akademischen (akademisch) <ADJ>
# und (und) <CCONJ>
# intellektuellen (intellektuell) <ADJ>
# Kreisen (Kreis) <NOUN>
# weltweit (weltweit) <ADV>
# populär (populär) <ADV>
# machte (machen) <VERB>
# . (.) <PUNCT>
# Eliade (Eliade) <PROPN>
# sah (sehen) <VERB>
# darin (darin) <ADV>
# die (der) <DET>
# älteste (alt) <ADJ>
# Form (Form) <NOUN>
# des (der) <DET>
# Heiligen (Heilige) <NOUN>
# , (,) <PUNCT>
# ja (ja) <ADV>
# die (der) <DET>
# ...
# des (der) <DET>
# chamans (chamans) <NOUN>
# un (un) <X>
# peu (peu) <X>
# partout (partout) <PROPN>
# dans (dans) <PROPN>
# le (le) <PROPN>
# monde (monde) <PROPN>
# … (…) <PUNCT>
# “ (“) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# – (–) <PUNCT>
# Mircea (Mircea) <PROPN>
# Eliade[3 (Eliade[3) <PROPN>
# ] (]) <ADJ>
#
#
#  (
#
# ) <SPACE>
# Dieses (Dieses) <DET>
# Zitat (Zitat) <NOUN>
# des (der) <DET>
# rumänischen (rumänisch) <ADJ>
# Religionswissenschaftlers (Religionswissenschaftlers) <NOUN>
# Mircea (Mircea) <PROPN>
# Eliade (Eliade) <PROPN>
# gibt (geben) <VERB>
# seinen (seinen) <DET>
# zentralen (zentral) <ADJ>
# Gedanken (Gedanke) <NOUN>
# wieder (wieder) <ADV>
# : (:) <PUNCT>
# „ („) <PUNCT>
# Es (ich) <PRON>
# gibt (geben) <VERB>
# keinen (kein) <DET>
# bestimmten (bestimmen) <ADJ>
# geographischen (geographisch) <ADJ>
# Raum (Raum) <NOUN>
# ( (() <PUNCT>
# des (der) <DET>
# Schamanismus (Schamanismus) <NOUN>
# ) ()) <PUNCT>
# , (,) <PUNCT>
# denn (denn) <CCONJ>
# die (der) <DET>
# schamanische (schamanische) <ADJ>
# Trance (Trance) <NOUN>
# ist (sein) <AUX>
# ein (einen) <DET>
# spontanes (spontan) <ADJ>
# und (und) <CCONJ>
# organisches (organisch) <ADJ>
# Phänomen (Phänomen) <NOUN>
# , (,) <PUNCT>
# das (der) <PRON>
# man (man) <PRON>
# bei (bei) <ADP>
# allen (alle) <DET>
# Schamanen (Schamane) <NOUN>
# auf (auf) <ADP>
# der (der) <DET>
# Welt (Welt) <NOUN>
# antrifft (antreffen) <VERB>
# . (.) <PUNCT>
# “ (“) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# Aus (Aus) <ADP>
# seinen (seinen) <DET>
# umfangreichen (umfangreich) <ADJ>
# kulturvergleichenden (kulturvergleichenden) <ADJ>
# Recherchen (Recherche) <NOUN>
# in (in) <ADP>
# russischen (russisch) <ADJ>
# und (und) <CCONJ>
# finnischen (finnisch) <ADJ>
# Ethnographien (Ethnographie) <PROPN>
# schuf (schaffen) <VERB>
# er (ich) <PRON>
# einen (ein) <DET>
# Idealtypus (Idealtypus) <NOUN>
# des (der) <DET>
# Schamanen (Schamane) <NOUN>
# . (.) <PUNCT>
# Er (ich) <PRON>
# konzipierte (konzipieren) <VERB>
# den (der) <DET>
# Schamanismus (Schamanismus) <NOUN>
# als (als) <ADP>
# das (der) <DET>
# weltweit (weltweit) <ADV>
# verbreitete (verbreiten) <ADJ>
# Ur-Phänomen (Ur-Phänomen) <NOUN>
# der (der) <DET>
# menschlichen (menschlich) <ADJ>
# Religiosität (Religiosität) <NOUN>
# und (und) <CCONJ>
# erhob (erheben) <VERB>
# die (der) <DET>
# ( (() <PUNCT>
# passive (passive) <ADJ>
# ) ()) <PUNCT>
# ekstatische (ekstatische) <ADJ>
# Trance (Trance) <PROPN>
# mit (mit) <ADP>
# dem (der) <DET>
# „ („) <PUNCT>
# Seelenflug (Seelenflug) <NOUN>
# in (in) <ADP>
# die (der) <DET>
# Geisterwelt (Geisterwelt) <NOUN>
# “ (“) <PUNCT>
# zum (zum) <ADP>
# zentralen (zentral) <ADJ>
# Merkmal (Merkmal) <NOUN>
# aller (all) <DET>
# schamanischen (schamanischen) <ADJ>
# Phänomene (Phänomen) <NOUN>
# . (.) <PUNCT>
# Darüber (Darüber) <ADV>
# hinaus (hinaus) <ADP>
# hielt (halten) <VERB>
# er (ich) <PRON>
# die (der) <DET>
# klassisch-sibirische (klassisch-sibirische) <ADJ>
# Kosmologie (Kosmologie) <NOUN>
# für (für) <ADP>
# eine (einen) <DET>
# Universalie (Universalie) <NOUN>
# , (,) <PUNCT>
# die (der) <PRON>
# in (in) <ADP>
# vielen (viel) <DET>
# Kulturen (Kultur) <NOUN>
# durch (durch) <ADP>
# Fremdeinflüsse (Fremdeinflüsse) <NOUN>
# überdeckt (überdeckt) <VERB>
# sei (sein) <AUX>
# . (.) <PUNCT>
# Eliade (Eliade) <PROPN>
# hob (heben) <VERB>
# überdies (überdies) <ADV>
# deutlich (deutlich) <ADV>
# hervor (hervor) <ADV>
# , (,) <PUNCT>
# dass (dass) <SCONJ>
# für (für) <ADP>
# den (der) <DET>
# Urmenschen (Urmensch) <NOUN>
# sowie (sowie) <CCONJ>
# heutige (heutige) <ADJ>
# „ („) <PUNCT>
# Naturvölker (Naturvölker) <NOUN>
# “ (“) <PUNCT>
# ein (einen) <DET>
# mystisch-sakraler (mystisch-sakraler) <ADJ>
# Zustand (Zustand) <NOUN>
# kennzeichnend (kennzeichnen) <ADV>
# sei (sein) <AUX>
# , (,) <PUNCT>
# der (der) <PRON>
# einen (ein) <DET>
# direkten (direkt) <ADJ>
# Kontakt (Kontakt) <NOUN>
# zum (zum) <ADP>
# Göttlichen (Göttliche) <NOUN>
# ermöglicht (ermöglichen) <VERB>
# habe (habe) <AUX>
# . (.) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# Mit (Mit) <ADP>
# seinem (mein) <DET>
# Werk (Werk) <NOUN>
# Schamanismus (Schamanismus) <NOUN>
# und (und) <CCONJ>
# archaische (archaische) <ADJ>
# Ekstasetechnik (Ekstasetechnik) <NOUN>
# ( (() <PUNCT>
# Erstausgabe (Erstausgabe) <NOUN>
# auf (auf) <ADP>
# Französisch (Französisch) <NOUN>
# 1957 (1957) <NUM>
# ) ()) <PUNCT>
# löste (lösen) <VERB>
# Eliade (Eliade) <PROPN>
# 1964 (1964) <NUM>
# bei (bei) <ADP>
# der (der) <DET>
# Veröffentlichung (Veröffentlichung) <NOUN>
# in (in) <ADP>
# den (der) <DET>
# USA (USA) <PROPN>
# in (in) <ADP>
# intellektuellen (intellektuell) <ADJ>
# Kreisen (Kreis) <NOUN>
# Begeisterung (Begeisterung) <NOUN>
# für (für) <ADP>
# ein (einen) <DET>
# Thema (Thema) <NOUN>
# aus (aus) <ADP>
# , (,) <PUNCT>
# das (der) <PRON>
# bis (bis) <ADP>
# dahin (dahin) <ADV>
# nur (nur) <ADV>
# Religionswissenschaftler (Religionswissenschaftler) <NOUN>
# am (am) <ADP>
# Rande (Rand) <NOUN>
# interessiert (interessieren) <VERB>
# hatte (haben) <AUX>
# . (.) <PUNCT>
# Dies (Dies) <PRON>
# lag (liegen) <VERB>
# nicht (nicht) <PART>
# nur (nur) <ADV>
# am (am) <ADP>
# Inhalt (Inhalt) <NOUN>
# seiner (sich) <DET>
# Studien (Studie) <NOUN>
# , (,) <PUNCT>
# sondern (sondern) <CCONJ>
# mindestens (mindestens) <ADV>
# ebenso (ebenso) <ADV>
# an (an) <ADP>
# der (der) <DET>
# ungewöhnlichen (ungewöhnlich) <ADJ>
# Herangehensweise (Herangehensweise) <NOUN>
# : (:) <PUNCT>
# Eliade (Eliade) <PROPN>
# führte (führen) <VERB>
# die (der) <DET>
# ethnologischen (ethnologisch) <ADJ>
# , (,) <PUNCT>
# philosophischen (philosophisch) <ADJ>
# , (,) <PUNCT>
# religionswissenschaftlichen (religionswissenschaftlichen) <ADJ>
# und (und) <CCONJ>
# psychologischen (psychologisch) <ADJ>
# Perspektiven (Perspektive) <NOUN>
# in (in) <ADP>
# einer (einer) <DET>
# Synthese (Synthese) <NOUN>
# aus (aus) <ADP>
# empirischer (empirisch) <ADJ>
# Analyse (Analyse) <NOUN>
# und (und) <CCONJ>
# imaginativer (imaginativ) <ADJ>
# Religionsphilosophie (Religionsphilosophie) <NOUN>
# zusammen (zusammen) <ADV>
# . (.) <PUNCT>
# Lange (langen) <ADJ>
# Zeit (Zeit) <NOUN>
# galt (gelten) <VERB>
# seine (mein) <DET>
# These (These) <NOUN>
# als (als) <ADP>
# das (der) <DET>
# Standardwerk (Standardwerk) <NOUN>
# zum (zum) <ADP>
# Schamanismus (Schamanismus) <NOUN>
# . (.) <PUNCT>
# Es (ich) <PRON>
# trug (tragen) <VERB>
# entscheidend (entscheiden) <ADV>
# zur (zur) <ADP>
# Rehabilitation (Rehabilitation) <NOUN>
# spiritueller (spirituell) <ADJ>
# Praktiker (Praktiker) <NOUN>
# bei (bei) <ADP>
# , (,) <PUNCT>
# die (der) <PRON>
# bis (bis) <ADP>
# dato (dato) <X>
# als (als) <ADP>
# Geisteskranke (Geisteskranke) <NOUN>
# oder (oder) <CCONJ>
# Scharlatane (Scharlatan) <NOUN>
# angesehen (ansehen) <VERB>
# wurden (werden) <AUX>
# . (.) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# Seit (seit) <ADP>
# den (der) <DET>
# 1990er (1990er) <ADJ>
# Jahren (Jahr) <NOUN>
# wurde (werden) <AUX>
# es (ich) <PRON>
# in (in) <ADP>
# der (der) <DET>
# Ethnologie (Ethnologie) <NOUN>
# jedoch (jedoch) <ADV>
# mehr (mehr) <ADV>
# und (und) <CCONJ>
# mehr (mehr) <PRON>
# verpönt (verpönen) <VERB>
# . (.) <PUNCT>
# Kunsthistoriker (Kunsthistoriker) <NOUN>
# , (,) <PUNCT>
# Literaturwissenschaftler (Literaturwissenschaftler) <NOUN>
# sowie (sowie) <CCONJ>
# neoschamanistische (neoschamanistische) <ADJ>
# und (und) <CCONJ>
# populärwissenschaftliche (populärwissenschaftliche) <ADJ>
# Autoren (Autor) <NOUN>
# berufen (berufen) <VERB>
# sich (sich) <PRON>
# allerdings (allerdings) <ADV>
# nach (nach) <ADV>
# wie (wie) <CCONJ>
# vor (vor) <ADV>
# auf (auf) <ADP>
# Eliade (Eliade) <PROPN>
# , (,) <PUNCT>
# obwohl (obwohl) <SCONJ>
# die (der) <DET>
# Kritikpunkte (Kritikpunkte) <NOUN>
# seine (mein) <DET>
# These (These) <NOUN>
# weitgehend (weitgehend) <ADV>
# demontieren.[82 (demontieren.[82) <X>
# ] (]) <PROPN>
#
#  (
# ) <SPACE>
# Kritik (Kritik) <NOUN>
#
#  (
# ) <SPACE>
# Kritiker (Kritiker) <NOUN>
# erkennen (erkennen) <VERB>
# christliche (christliche) <ADJ>
# Motive (Motiv) <NOUN>
# ( (() <PUNCT>
# Paradiesischer (Paradiesischer) <ADJ>
# Zustand (Zustand) <NOUN>
# , (,) <PUNCT>
# Sündenfall (Sündenfall) <NOUN>
# ) ()) <PUNCT>
# und (und) <CCONJ>
# romantische (romantische) <ADJ>
# Verklärung (Verklärung) <NOUN>
# in (in) <ADP>
# Eliades (Eliades) <PROPN>
# Werk (Werk) <NOUN>
#
#
#  (
#
# ) <SPACE>
# Da (da) <SCONJ>
# sich (sich) <PRON>
# Eliade (Eliade) <PROPN>
# vollkommen (vollkommen) <ADV>
# auf (auf) <ADP>
# seinen (seinen) <DET>
# ganzheitlich (ganzheitlich) <ADV>
# religionswissenschaftlichen (religionswissenschaftlichen) <ADJ>
# Ansatz (Ansatz) <NOUN>
# konzentrieren (konzentrieren) <VERB>
# wollte (wollen) <AUX>
# , (,) <PUNCT>
# verzichtete (verzichten) <VERB>
# er (ich) <PRON>
# darauf (darauf) <ADV>
# , (,) <PUNCT>
# den (der) <DET>
# historischen (historisch) <ADJ>
# und (und) <CCONJ>
# politischen (politisch) <ADJ>
# Kontext (Kontext) <NOUN>
# der (der) <DET>
# Phänomene (Phänomen) <NOUN>
# genauer (genau) <ADV>
# zu (zu) <PART>
# betrachten (betrachten) <VERB>
# . (.) <PUNCT>
# Stattdessen (Stattdessen) <ADV>
# stellte (stellen) <VERB>
# er (ich) <PRON>
# Vergleichskriterien (Vergleichskriterien) <NOUN>
# auf (auf) <ADP>
# , (,) <PUNCT>
# die (der) <PRON>
# man (man) <PRON>
# als (als) <ADP>
# „ („) <PUNCT>
# ergebnisgeleitet (ergebnisgeleitet) <VERB>
# “ (“) <PUNCT>
# statt (statt) <ADP>
# „ („) <PUNCT>
# ergebnisoffen (ergebnisoffen) <VERB>
# “ (“) <PUNCT>
# bezeichnen (bezeichnen) <VERB>
# kann (können) <AUX>
# . (.) <PUNCT>
# So (so) <ADV>
# entgingen (entgehen) <VERB>
# ihm (ich) <PRON>
# auch (auch) <ADV>
# die (der) <DET>
# bereits (bereits) <ADV>
# erwähnten (erwähnen) <ADJ>
# Fehler (Fehler) <NOUN>
# in (in) <ADP>
# den (der) <DET>
# alten (alt) <ADJ>
# ethnographischen (ethnographisch) <ADJ>
# Aufzeichnungen (Aufzeichnung) <NOUN>
# aus (aus) <ADP>
# Russland.[74 (Russland.[74) <PROPN>
# ] (]) <PROPN>
# Auf (Auf) <ADP>
# der (der) <DET>
# Suche (Suche) <NOUN>
# nach (nach) <ADP>
# dem (der) <DET>
# tieferen (tief) <ADJ>
# Sinn (Sinn) <NOUN>
# vermischte (vermischen) <VERB>
# er (ich) <PRON>
# religiöse (religiös) <VERB>
# mit (mit) <ADP>
# mythisch-literarischen (mythisch-literarischen) <ADJ>
# Phänomenen (Phänomen) <NOUN>
# und (und) <CCONJ>
# stellte (stellen) <VERB>
# das (der) <DET>
# „ („) <PUNCT>
# kreative (kreative) <NOUN>
# vor (vor) <ADP>
# das (der) <DET>
# empirische (empirische) <ADJ>
# Moment (Moment) <NOUN>
# “ (“) <PUNCT>
# . (.) <PUNCT>
# Er (ich) <PRON>
# ging (gehen) <VERB>
# davon (davon) <ADV>
# aus (aus) <ADP>
# , (,) <PUNCT>
# dass (dass) <SCONJ>
# sich (sich) <PRON>
# der (der) <DET>
# „ („) <PUNCT>
# sakrale (sakrale) <ADJ>
# Charakter (Charakter) <NOUN>
# “ (“) <PUNCT>
# nicht (nicht) <PART>
# mit (mit) <ADP>
# Hilfe (Hilfe) <NOUN>
# der (der) <DET>
# reduktionistischen (reduktionistischen) <ADJ>
# Methoden (Methode) <NOUN>
# verschiedener (verschieden) <ADJ>
# Fachbereiche (Fachbereich) <NOUN>
# ( (() <PUNCT>
# Physiologie (Physiologie) <NOUN>
# , (,) <PUNCT>
# Psychologie (Psychologie) <NOUN>
# , (,) <PUNCT>
# Sprachwissenschaft (Sprachwissenschaft) <NOUN>
# , (,) <PUNCT>
# Kunst (Kunst) <NOUN>
# u. (u.) <ADP>
# a. (a.) <X>
# ) ()) <PUNCT>
# offenbare (offenbaren) <VERB>
# , (,) <PUNCT>
# sondern (sondern) <CCONJ>
# nur (nur) <ADV>
# in (in) <ADP>
# seiner (sich) <DET>
# „ („) <PUNCT>
# eigenen (eigen) <ADJ>
# religiösen (religiös) <ADJ>
# Modalität (Modalität) <NOUN>
# “ (“) <PUNCT>
# . (.) <PUNCT>
# Seine (mein) <DET>
# These (These) <NOUN>
# ist (sein) <AUX>
# keine (kein) <DET>
# rein (rein) <ADV>
# akademische (akademische) <ADJ>
# , (,) <PUNCT>
# sondern (sondern) <CCONJ>
# eine (einen) <DET>
# metaphysische (metaphysische) <ADJ>
# Deutung (Deutung) <NOUN>
# von (von) <ADP>
# Geschichte (Geschichte) <NOUN>
# und (und) <CCONJ>
# Welt (Welt) <NOUN>
# . (.) <PUNCT>
# Widersprüche (Widerspruch) <NOUN>
# und (und) <CCONJ>
# Abweichungen (Abweichung) <NOUN>
# erklärte (erklären) <VERB>
# er (ich) <PRON>
# durch (durch) <ADP>
# „ („) <PUNCT>
# Dekadenz (Dekadenz) <NOUN>
# “ (“) <PUNCT>
# und (und) <CCONJ>
# „ („) <PUNCT>
# Kontamination (Kontamination) <NOUN>
# “ (“) <PUNCT>
# durch (durch) <ADP>
# andere (ander) <ADJ>
# Kulturen (Kultur) <NOUN>
# und (und) <CCONJ>
# Religionen (Religion) <NOUN>
# . (.) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# Eliade (Eliade) <PROPN>
# idealisierte (idealisieren) <VERB>
# und (und) <CCONJ>
# romantisierte (romantisierte) <VERB>
# die (der) <DET>
# „ („) <PUNCT>
# archaische (archaische) <ADJ>
# Spiritualität (Spiritualität) <NOUN>
# “ (“) <PUNCT>
# und (und) <CCONJ>
# die (der) <DET>
# „ („) <PUNCT>
# primitiven (primitiv) <ADJ>
# Kulturen (Kultur) <NOUN>
# “ (“) <PUNCT>
# in (in) <ADP>
# der (der) <DET>
# eurozentrischen (eurozentrischen) <ADJ>
# Tradition (Tradition) <NOUN>
# von (von) <ADP>
# Herder (Herder) <PROPN>
# und (und) <CCONJ>
# Boas (Boas) <PROPN>
# . (.) <PUNCT>
# Statt (statt) <SCONJ>
# sich (sich) <PRON>
# den (der) <DET>
# tatsächlichen (tatsächlich) <ADJ>
# ethnischen (ethnisch) <ADJ>
# Mentalitäten (Mentalität) <NOUN>
# zu (zu) <PART>
# nähern (nähern) <VERB>
# , (,) <PUNCT>
# erkennen (erkennen) <VERB>
# einige (einig) <DET>
# Autoren (Autor) <NOUN>
# eher (eher) <ADV>
# christliche (christliche) <ADJ>
# Motive (Motiv) <NOUN>
# bei (bei) <ADP>
# ihm (ich) <PRON>
# : (:) <PUNCT>
# Der (der) <DET>
# mystische (mystische) <ADJ>
# Urzustand (Urzustand) <NOUN>
# entspricht (entsprechen) <VERB>
# dem (der) <DET>
# Paradies (Paradies) <NOUN>
# , (,) <PUNCT>
# der (der) <DET>
# geschichtliche (geschichtlich) <ADJ>
# Zivilisationsprozess (Zivilisationsprozess) <NOUN>
# dem (der) <DET>
# Sündenfall (Sündenfall) <NOUN>
# und (und) <CCONJ>
# die (der) <DET>
# schamanische (schamanische) <ADJ>
# Seelenreise (Seelenreise) <NOUN>
# war (sein) <AUX>
# nach (nach) <ADP>
# Eliade (Eliade) <PROPN>
# angeblich (angeblich) <ADV>
# ursprünglich (ursprünglich) <ADV>
# eine (einen) <DET>
# „ („) <PUNCT>
# Himmelsreise (Himmelsreise) <NOUN>
# “ (“) <PUNCT>
# in (in) <ADP>
# die (der) <DET>
# Oberwelt (Oberwelt) <NOUN>
# . (.) <PUNCT>
#
#
#  (
#
# ) <SPACE>
# Sein (mein) <DET>
# Ansatz (Ansatz) <NOUN>
# hat (haben) <AUX>
# bis (bis) <ADP>
# in (in) <ADP>
# die (der) <DET>
# 1990er (1990er) <ADJ>
# Jahre (Jahr) <NOUN>
# zu (zu) <PART>
# scharfen (scharf) <ADJ>
# Debatten (Debatte) <NOUN>
# um (um) <ADP>
# seine (mein) <DET>
# Methodik (Methodik) <NOUN>
# , (,) <PUNCT>
# aber (aber) <CCONJ>
# demgegenüber (demgegenüber) <ADV>
# auch (auch) <ADV>
# um (um) <ADP>
# den (der) <DET>
# Reduktionismus (Reduktionismus) <NOUN>
# in (in) <ADP>
# den (der) <DET>
# Religionswissenschaften (Religionswissenschaften) <NOUN>
# geführt (führen) <VERB>
# . (.) <PUNCT>
# Aus (Aus) <ADP>
# Sicht (Sicht) <NOUN>
# der (der) <DET>
# Anthropologie (Anthropologie) <NOUN>
# wird (werden) <AUX>
# Eliades (Eliades) <PROPN>
# Methode (Methode) <NOUN>
# vor (vor) <ADP>
# allem (alle) <PRON>
# kritisiert (kritisieren) <VERB>
# , (,) <PUNCT>
# weil (weil) <SCONJ>
# sie (ich) <PRON>
# mehr (mehr) <ADV>
# in (in) <ADP>
# seiner (sich) <DET>
# Rolle (Rolle) <NOUN>
# eines (ein) <DET>
# schamanischen (schamanischen) <ADJ>
# Propheten (Prophet) <NOUN>
# wurzele (wurzeln) <VERB>
# , (,) <PUNCT>
# denn (denn) <CCONJ>
# in (in) <ADP>
# seriöser (seriös) <ADJ>
# wissenschaftlicher (wissenschaftlich) <ADJ>
# Arbeit (Arbeit) <NOUN>
# . (.) <PUNCT>
# Verschiedene (Verschiedene) <ADJ>
# Autoren (Autor) <NOUN>
# bemängeln (bemängeln) <VERB>
# , (,) <PUNCT>
# dass (dass) <SCONJ>
# er (ich) <PRON>
# historische (historische) <VERB>
# , (,) <PUNCT>
# anthropologische (anthropologische) <ADJ>
# , (,) <PUNCT>
# soziologische (soziologische) <ADJ>
# und (und) <CCONJ>
# ökonomische (ökonomisch) <ADJ>
# Perspektiven (Perspektive) <NOUN>
# schlichtweg (schlichtweg) <ADV>
# ignoriert (ignorieren) <VERB>
# habe (habe) <AUX>
# , (,) <PUNCT>
# so (so) <ADV>
# dass (dass) <SCONJ>
# seine (mein) <DET>
# Darstellungen (Darstellung) <NOUN>
# nicht (nicht) <PART>
# verifizierbar (verifizierbar) <ADV>
# seien (sein) <AUX>
# . (.) <PUNCT>
# Darüber (Darüber) <ADV>
# hinaus (hinaus) <ADP>
# wird (werden) <AUX>
# ihm (ich) <PRON>
# angelastet (anlasten) <VERB>
# , (,) <PUNCT>
# dass (dass) <SCONJ>
# er (ich) <PRON>
# über (über) <ADP>
# den (der) <DET>
# reinen (rein) <ADJ>
# Erklärungsversuch (Erklärungsversuch) <NOUN>
# hinausging (hinausging) <VERB>
# und (und) <CCONJ>
# dem (der) <DET>
# unwissenschaftlichen (unwissenschaftlich) <ADJ>
# Neoschamanismus (Neoschamanismus) <NOUN>
# mit (mit) <ADP>
# der (der) <DET>
# Aussage (Aussage) <NOUN>
# „ („) <PUNCT>
# dass (dass) <SCONJ>
# der (der) <DET>
# mystische (mystische) <ADJ>
# Urzustand (Urzustand) <NOUN>
# mit (mit) <ADP>
# Hilfe (Hilfe) <NOUN>
# der (der) <DET>
# schamanischen (schamanischen) <ADJ>
# Ekstase (Ekstase) <NOUN>
# quasi (quasi) <ADV>
# jederzeit (jederzeit) <ADV>
# von (von) <ADP>
# jedermann (jedermann) <PRON>
# vergegenwärtigt (vergegenwärtigen) <VERB>
# werden (werden) <AUX>
# könne (können) <AUX>
# “ (“) <PUNCT>
# eine (einen) <DET>
# Legitimation (Legitimation) <NOUN>
# geliefert (liefern) <VERB>
# hat.[83][82 (hat.[83][82) <PROPN>
# ] (]) <PROPN>
# Klaus (Klaus) <PROPN>
# E. (E.) <PROPN>
# Müller (Müller) <PROPN>
# bezeichnete (bezeichnen) <VERB>
# Eliades (Eliades) <NOUN>
# Thesen (These) <NOUN>
# als (als) <ADP>
# „ („) <PUNCT>
# inhaltlich (inhaltlich) <ADV>
# sehr (sehr) <ADV>
# spekulativ“.[84 (spekulativ“.[84) <NUM>
# ] (]) <PROPN>

# %%
# POS-filter sentences 

ALLOWED_POS = {"NOUN", "ADJ", "PROPN"}
filtered_sentences = []

for sent in doc.sents:
    tmp_sent = []
    for token in sent:
        
        if token.lemma_.lower() in stops:
            continue
            
        if token.pos_ not in ALLOWED_POS:
            continue
        
        tmp_sent.append(token.lemma_)
    
    if len(tmp_sent) > 0:
        filtered_sentences.append(tmp_sent)

# %%
print(filtered_sentences[0])
# Out:
# ['Schamanismus', 'eng', 'Sinn', 'traditionell', 'ethnisch', 'Religion', 'Kulturareales', 'Sibirien', 'Nenzen', 'Jakuten', 'Altaier', 'Burjaten', 'Ewenken', 'europäische', 'Samen', 'Vorhandensein', 'Schamane', 'europäisch', 'Forscher', 'Expansionszeit', 'wesentlich', 'gemeinsam', 'Kennzeichen', 'wurde.[1', ']']

# %%
all_tokens = [token for sent in filtered_sentences for token in sent]
token_count = Counter(all_tokens)
print(token_count.most_common(25))
# Out:
# [(']', 98), ('Schamane', 72), ('Schamanismus', 67), ('Religion', 23), ('sibirisch', 23), ('Volk', 22), ('These', 20), ('Ekstase', 19), ('\ufeff', 19), ('Phänomen', 17), ('Form', 17), ('Jahrhundert', 17), ('traditionell', 16), ('Kultur', 16), ('Müller', 16), ('verschieden', 15), ('Eliade', 15), ('Autor', 14), ('religiös', 14), ('Trance', 14), ('Kritik', 13), ('Konzept', 12), ('Jahr', 12), ('Welt', 12), ('B.', 11)]

# %%
from collections import Counter, defaultdict
from itertools import combinations, product
import time
from nltk.corpus import stopwords
from nltk import ngrams
import numpy as np
import re
import math
import pprint

# %%
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\monox\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
token_min_len = 2
token_max_len = 64

stop_words = stopwords.words("german")

# %%
content = open('Schamanismus.txt', "r").read()
content = " ".join([s.strip() for s in content.split("\n")])
sentences = []

token_count = 0
for sent in content.split("."):  # Thats an awesome sentence segmenter..
    sent = re.sub(r"[^a-zA-Z0-9öäüÖÄÜß\.\?!-]", " ", sent)
    tokens = [t.strip().lower() for t in sent.split(" ")]
    tokens = [t for t in tokens if len(t) > 1]
    # tokens = [t for t in tokens if t.lower() not in stop_words]
    sentences.append(tokens)
    token_count += len(tokens)
    
print(f"Tokens: {token_count}")
print(f"Sents: {len(sentences)}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 content = open('Schamanismus.txt', "r").read()
#       2 content = " ".join([s.strip() for s in content.split("\n")])
#       3 sentences = []
#
# File c:\Users\monox\github\WK_2626_Applied_Natural_Language_Processing\venv_nlp\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Schamanismus.txt'

# %%
bigrams = []
unigrams = []  # just a list of all tokens
for sent in sentences:
    
    if len(sent) < 2:
        continue
    
    sent.insert(0, "<s>")
    sent.append("</s>")
    
    tmp_bigrams = list(ngrams(sent, 2))
    bigrams += tmp_bigrams
    
    unigrams += sent

# %%
bigrams
# Out:
# [('<s>', 'schamanismus'),
#  ('schamanismus', 'bezeichnet'),
#  ('bezeichnet', 'im'),
#  ('im', 'engeren'),
#  ('engeren', 'sinne'),
#  ('sinne', 'die'),
#  ('die', 'traditionellen'),
#  ('traditionellen', 'ethnischen'),
#  ('ethnischen', 'religionen'),
#  ('religionen', 'des'),
#  ('des', 'kulturareales'),
#  ('kulturareales', 'sibirien'),
#  ('sibirien', 'nenzen'),
#  ('nenzen', 'jakuten'),
#  ('jakuten', 'altaier'),
#  ('altaier', 'burjaten'),
#  ('burjaten', 'ewenken'),
#  ('ewenken', 'auch'),
#  ('auch', 'europäische'),
#  ('europäische', 'samen'),
#  ('samen', 'und'),
#  ('und', 'andere'),
#  ('andere', 'bei'),
#  ('bei', 'denen'),
#  ('denen', 'das'),
#  ('das', 'vorhandensein'),
#  ('vorhandensein', 'von'),
#  ('von', 'schamanen'),
#  ('schamanen', 'von'),
#  ('von', 'europäischen'),
#  ('europäischen', 'forschern'),
#  ('forschern', 'der'),
#  ('der', 'expansionszeit'),
#  ('expansionszeit', 'als'),
#  ('als', 'wesentliches'),
#  ('wesentliches', 'gemeinsames'),
#  ('gemeinsames', 'kennzeichen'),
#  ('kennzeichen', 'erachtet'),
#  ('erachtet', 'wurde'),
#  ('wurde', '</s>'),
#  ('<s>', 'zur'),
#  ('zur', 'besseren'),
#  ('besseren', 'abgrenzung'),
#  ('abgrenzung', 'werden'),
#  ('werden', 'diese'),
#  ('diese', 'religionen'),
#  ('religionen', 'häufig'),
#  ('häufig', 'klassischer'),
#  ('klassischer', 'schamanismus'),
#  ('schamanismus', 'oder'),
#  ('oder', 'auch'),
#  ('auch', 'sibirischer'),
#  ('sibirischer', 'animismus'),
#  ('animismus', 'genannt'),
#  ('genannt', '</s>'),
#  ('<s>', 'im'),
#  ('im', 'weiteren'),
#  ('weiteren', 'sinne'),
#  ('sinne', 'meint'),
#  ('meint', 'schamanismus'),
#  ('schamanismus', 'alle'),
#  ('alle', 'wissenschaftlichen'),
#  ('wissenschaftlichen', 'konzepte'),
#  ('konzepte', 'die'),
#  ('die', 'aufgrund'),
#  ('aufgrund', 'von'),
#  ('von', 'ähnlichen'),
#  ('ähnlichen', 'praktiken'),
#  ('praktiken', 'spiritueller'),
#  ('spiritueller', 'spezialisten'),
#  ('spezialisten', 'in'),
#  ('in', 'verschiedenen'),
#  ('verschiedenen', 'traditionellen'),
#  ('traditionellen', 'gesellschaften'),
#  ('gesellschaften', 'die'),
#  ('die', 'kulturübergreifende'),
#  ('kulturübergreifende', 'existenz'),
#  ('existenz', 'des'),
#  ('des', 'schamanismus'),
#  ('schamanismus', 'postulieren'),
#  ('postulieren', '</s>'),
#  ('<s>', 'nach'),
#  ('nach', 'szl'),
#  ('szl', 'vajda'),
#  ('vajda', 'und'),
#  ('und', 'jane'),
#  ('jane', 'monnig'),
#  ('monnig', 'atkinson'),
#  ('atkinson', 'sollte'),
#  ('sollte', 'aufgrund'),
#  ('aufgrund', 'der'),
#  ('der', 'vielzahl'),
#  ('vielzahl', 'unterschiedlicher'),
#  ('unterschiedlicher', 'konzepte'),
#  ('konzepte', 'treffender'),
#  ('treffender', 'von'),
#  ('von', 'schamanismen'),
#  ('schamanismen', 'im'),
#  ('im', 'plural'),
#  ('plural', 'gesprochen'),
#  ('gesprochen', 'werden'),
#  ('werden', '</s>'),
#  ('<s>', 'sibirische'),
#  ('sibirische', 'schamanen'),
#  ('schamanen', 'und'),
#  ('und', 'verschiedene'),
#  ('verschiedene', 'geisterbeschwörer'),
#  ('geisterbeschwörer', 'anderer'),
#  ('anderer', 'ethnien'),
#  ('ethnien', 'die'),
#  ('die', 'ebenfalls'),
#  ('ebenfalls', 'häufig'),
#  ('häufig', 'verallgemeinernd'),
#  ('verallgemeinernd', 'als'),
#  ('als', 'schamanen'),
#  ('schamanen', 'bezeichnet'),
#  ('bezeichnet', 'werden'),
#  ('werden', 'hatten'),
#  ('hatten', 'oder'),
#  ('oder', 'haben'),
#  ('haben', 'in'),
#  ('in', 'vielen'),
#  ('vielen', 'traditionellen'),
#  ('traditionellen', 'weltanschauungen'),
#  ('weltanschauungen', 'angeblich'),
#  ('angeblich', 'einfluss'),
#  ('einfluss', 'auf'),
#  ('auf', 'die'),
#  ('die', 'mächte'),
#  ('mächte', 'des'),
#  ('des', 'jenseits'),
#  ('jenseits', '</s>'),
#  ('<s>', 'sie'),
#  ('sie', 'setzten'),
#  ('setzten', 'ihre'),
#  ('ihre', 'fähigkeiten'),
#  ('fähigkeiten', 'vorwiegend'),
#  ('vorwiegend', 'zum'),
#  ('zum', 'wohle'),
#  ('wohle', 'der'),
#  ('der', 'gemeinschaft'),
#  ('gemeinschaft', 'ein'),
#  ('ein', 'um'),
#  ('um', 'in'),
#  ('in', 'unlösbar'),
#  ('unlösbar', 'erscheinenden'),
#  ('erscheinenden', 'krisensituationen'),
#  ('krisensituationen', 'die'),
#  ('die', 'kosmische'),
#  ('kosmische', 'harmonie'),
#  ('harmonie', 'zwischen'),
#  ('zwischen', 'diesseits'),
#  ('diesseits', 'und'),
#  ('und', 'jenseits'),
#  ('jenseits', 'wiederherzustellen'),
#  ('wiederherzustellen', '</s>'),
#  ('<s>', 'in'),
#  ('in', 'diesem'),
#  ('diesem', 'weiten'),
#  ('weiten', 'sinne'),
#  ('sinne', 'bezeichnet'),
#  ('bezeichnet', 'schamanismus'),
#  ('schamanismus', 'eine'),
#  ('eine', 'reihe'),
#  ('reihe', 'unscharf'),
#  ('unscharf', 'bestimmter'),
#  ('bestimmter', 'phänomene'),
#  ('phänomene', 'zwischen'),
#  ('zwischen', 'religion'),
#  ('religion', 'und'),
#  ('und', 'heilritual'),
#  ('heilritual', '</s>'),
#  ('<s>', 'anmerkung'),
#  ('anmerkung', 'eine'),
#  ('eine', 'nähere'),
#  ('nähere', 'allgemeingültige'),
#  ('allgemeingültige', 'bestimmung'),
#  ('bestimmung', 'ist'),
#  ('ist', 'nicht'),
#  ('nicht', 'möglich'),
#  ('möglich', 'da'),
#  ('da', 'die'),
#  ('die', 'definition'),
#  ('definition', 'verschiedene'),
#  ('verschiedene', 'betrachtungsweisen'),
#  ('betrachtungsweisen', 'aus'),
#  ('aus', 'sicht'),
#  ('sicht', 'der'),
#  ('der', 'ethnologie'),
#  ('ethnologie', 'kulturanthropologie'),
#  ('kulturanthropologie', 'religionswissenschaften'),
#  ('religionswissenschaften', 'archäologie'),
#  ('archäologie', 'soziologie'),
#  ('soziologie', 'und'),
#  ('und', 'psychologie'),
#  ('psychologie', 'enthält'),
#  ('enthält', '</s>'),
#  ('<s>', '10'),
#  ('10', '11'),
#  ('11', 'dies'),
#  ('dies', 'hat'),
#  ('hat', 'unter'),
#  ('unter', 'anderem'),
#  ('anderem', 'zur'),
#  ('zur', 'folge'),
#  ('folge', 'dass'),
#  ('dass', 'angaben'),
#  ('angaben', 'zur'),
#  ('zur', 'räumlichen'),
#  ('räumlichen', 'und'),
#  ('und', 'zeitlichen'),
#  ('zeitlichen', 'verbreitung'),
#  ('verbreitung', 'der'),
#  ('der', 'schamanismen'),
#  ('schamanismen', 'erheblich'),
#  ('erheblich', 'voneinander'),
#  ('voneinander', 'abweichen'),
#  ('abweichen', 'und'),
#  ('und', 'in'),
#  ('in', 'vielen'),
#  ('vielen', 'fällen'),
#  ('fällen', 'umstritten'),
#  ('umstritten', 'sind'),
#  ('sind', '</s>'),
#  ('<s>', '12'),
#  ('12', '13'),
#  ('13', '14'),
#  ('14', 'der'),
#  ('der', 'amerikanische'),
#  ('amerikanische', 'ethnologe'),
#  ('ethnologe', 'clifford'),
#  ('clifford', 'geertz'),
#  ('geertz', 'sprach'),
#  ('sprach', 'daher'),
#  ('daher', 'bereits'),
#  ('bereits', 'in'),
#  ('in', 'den'),
#  ('den', '1960er'),
#  ('1960er', 'jahren'),
#  ('jahren', 'dem'),
#  ('dem', 'westlich'),
#  ('westlich', 'idealistischen'),
#  ('idealistischen', 'konstrukt'),
#  ('konstrukt', 'schamanismus'),
#  ('schamanismus', 'jeglichen'),
#  ('jeglichen', 'erklärungswert'),
#  ('erklärungswert', 'ab'),
#  ('ab', '</s>'),
#  ('<s>', 'einig'),
#  ('einig', 'ist'),
#  ('ist', 'man'),
#  ('man', 'sich'),
#  ('sich', 'lediglich'),
#  ('lediglich', 'bei'),
#  ('bei', 'der'),
#  ('der', 'engen'),
#  ('engen', 'definition'),
#  ('definition', 'des'),
#  ('des', 'klassisch'),
#  ('klassisch', 'sibirischen'),
#  ('sibirischen', 'schamanismus'),
#  ('schamanismus', 'dem'),
#  ('dem', 'ausgangspunkt'),
#  ('ausgangspunkt', 'der'),
#  ('der', 'ersten'),
#  ('ersten', 'schamanismen'),
#  ('schamanismen', '</s>'),
#  ('<s>', 'dazu'),
#  ('dazu', 'gehört'),
#  ('gehört', 'vor'),
#  ('vor', 'allem'),
#  ('allem', 'die'),
#  ('die', 'genaue'),
#  ('genaue', 'beschreibung'),
#  ('beschreibung', 'der'),
#  ('der', 'dort'),
#  ('dort', 'praktizierten'),
#  ('praktizierten', 'rituellen'),
#  ('rituellen', 'ekstase'),
#  ('ekstase', 'eine'),
#  ('eine', 'weitgehend'),
#  ('weitgehend', 'übereinstimmende'),
#  ('übereinstimmende', 'ethnische'),
#  ('ethnische', 'religion'),
#  ('religion', 'sowie'),
#  ('sowie', 'eine'),
#  ('eine', 'ähnliche'),
#  ('ähnliche', 'kosmologie'),
#  ('kosmologie', 'und'),
#  ('und', 'lebensweise'),
#  ('lebensweise', '</s>'),
#  ('<s>', '15'),
#  ('15', '11'),
#  ('11', '16'),
#  ('16', 'nach'),
#  ('nach', 'weiter'),
#  ('weiter', 'gefassten'),
#  ('gefassten', 'definitionen'),
#  ('definitionen', 'wird'),
#  ('wird', 'schamanismus'),
#  ('schamanismus', 'bis'),
#  ('bis', 'in'),
#  ('in', 'die'),
#  ('die', '1980er'),
#  ('1980er', 'jahre'),
#  ('jahre', 'als'),
#  ('als', 'frühe'),
#  ('frühe', 'kulturübergreifende'),
#  ('kulturübergreifende', 'entwicklungsstufe'),
#  ('entwicklungsstufe', 'jeglicher'),
#  ('jeglicher', 'religion'),
#  ('religion', 'betrachtet'),
#  ('betrachtet', '</s>'),
#  ('<s>', '15'),
#  ('15', 'vor'),
#  ('vor', 'allem'),
#  ('allem', 'das'),
#  ('das', 'konzept'),
#  ('konzept', 'des'),
#  ('des', 'core-schamanismus'),
#  ('core-schamanismus', 'von'),
#  ('von', 'michael'),
#  ('michael', 'harner'),
#  ('harner', 'ist'),
#  ('ist', 'hier'),
#  ('hier', 'zu'),
#  ('zu', 'nennen'),
#  ('nennen', '</s>'),
#  ('<s>', 'diese'),
#  ('diese', 'auslegung'),
#  ('auslegung', 'gilt'),
#  ('gilt', 'jedoch'),
#  ('jedoch', 'mittlerweile'),
#  ('mittlerweile', 'als'),
#  ('als', 'nicht'),
#  ('nicht', 'konsensfähig'),
#  ('konsensfähig', '</s>'),
#  ('<s>', '14'),
#  ('14', 'seit'),
#  ('seit', 'den'),
#  ('den', '1990er'),
#  ('1990er', 'jahren'),
#  ('jahren', 'steht'),
#  ('steht', 'häufig'),
#  ('häufig', 'der'),
#  ('der', 'aspekt'),
#  ('aspekt', 'des'),
#  ('des', 'heilens'),
#  ('heilens', 'im'),
#  ('im', 'mittelpunkt'),
#  ('mittelpunkt', 'des'),
#  ('des', 'interesses'),
#  ('interesses', 'und'),
#  ('und', 'der'),
#  ('der', 'jeweiligen'),
#  ('jeweiligen', 'definition'),
#  ('definition', '</s>'),
#  ('<s>', '10'),
#  ('10', 'demgegenüber'),
#  ('demgegenüber', 'geht'),
#  ('geht', 'der'),
#  ('der', 'indologe'),
#  ('indologe', 'michael'),
#  ('michael', 'witzel'),
#  ('witzel', 'davon'),
#  ('davon', 'aus'),
#  ('aus', 'dass'),
#  ('dass', 'es'),
#  ('es', 'angesichts'),
#  ('angesichts', 'der'),
#  ('der', 'ähnlichkeit'),
#  ('ähnlichkeit', 'australischer'),
#  ('australischer', 'andamanischer'),
#  ('andamanischer', 'indischer'),
#  ('indischer', 'und'),
#  ('und', 'afrikanischer'),
#  ('afrikanischer', 'initiationsrituale'),
#  ('initiationsrituale', 'mit'),
#  ('mit', 'den'),
#  ('den', 'entsprechenden'),
#  ('entsprechenden', 'sibirischen'),
#  ('sibirischen', 'ritualen'),
#  ('ritualen', 'die'),
#  ('die', 'die'),
#  ('die', 'phänomene'),
#  ('phänomene', 'der'),
#  ('der', 'aufsteigenden'),
#  ('aufsteigenden', 'hitze'),
#  ('hitze', 'trancen'),
#  ('trancen', 'dreamers'),
#  ('dreamers', 'ekstase'),
#  ('ekstase', 'und'),
#  ('und', 'kollaps'),
#  ('kollaps', 'symbolischen'),
#  ('symbolischen', 'tod'),
#  ('tod', 'und'),
#  ('und', 'wiedergeburt'),
#  ('wiedergeburt', 'verwendung'),
#  ('verwendung', 'psychoaktiver'),
#  ('psychoaktiver', 'drogen'),
#  ('drogen', 'tabubewahrung'),
#  ('tabubewahrung', 'zauberei'),
#  ('zauberei', 'und'),
#  ('und', 'heilung'),
#  ('heilung', 'umfassen'),
#  ('umfassen', 'einen'),
#  ('einen', 'älteren'),
#  ('älteren', 'prototyp'),
#  ('prototyp', 'des'),
#  ('des', 'schamanismus'),
#  ('schamanismus', 'gegeben'),
#  ('gegeben', 'habe'),
#  ('habe', '</s>'),
#  ('<s>', 'dieser'),
#  ('dieser', 'habe'),
#  ('habe', 'sich'),
#  ('sich', 'mit'),
#  ('mit', 'der'),
#  ('der', 'out-of-africa-wanderung'),
#  ('out-of-africa-wanderung', 'des'),
#  ('des', 'modernen'),
#  ('modernen', 'menschen'),
#  ('menschen', 'entlang'),
#  ('entlang', 'der'),
#  ('der', 'küsten'),
#  ('küsten', 'des'),
#  ('des', 'indischen'),
#  ('indischen', 'ozeans'),
#  ('ozeans', 'und'),
#  ('und', 'früh'),
#  ('früh', 'auch'),
#  ('auch', 'nach'),
#  ('nach', 'eurasien'),
#  ('eurasien', 'und'),
#  ('und', 'nordamerika'),
#  ('nordamerika', 'verbreitet'),
#  ('verbreitet', '</s>'),
#  ('<s>', 'dafür'),
#  ('dafür', 'sprächen'),
#  ('sprächen', 'spätpaläolithische'),
#  ('spätpaläolithische', 'bärenkulte'),
#  ('bärenkulte', 'und'),
#  ('und', 'felszeichnungen'),
#  ('felszeichnungen', 'wie'),
#  ('wie', 'in'),
#  ('in', 'les'),
#  ('les', 'trois'),
#  ('trois', 'fr'),
#  ('fr', 'res'),
#  ('res', 'abb'),
#  ('abb', '</s>'),
#  ('<s>', 'siehe'),
#  ('siehe', 'unten'),
#  ('unten', '</s>'),
#  ('<s>', 'der'),
#  ('der', 'sibirische'),
#  ('sibirische', 'schamanismus'),
#  ('schamanismus', 'stelle'),
#  ('stelle', 'eine'),
#  ('eine', 'jüngere'),
#  ('jüngere', 'evolutionsstufe'),
#  ('evolutionsstufe', 'dieses'),
#  ('dieses', 'prototyps'),
#  ('prototyps', 'dar'),
#  ('dar', 'mit'),
#  ('mit', 'fellkleidung'),
#  ('fellkleidung', 'trommel'),
#  ('trommel', 'usw'),
#  ('usw', '</s>'),
#  ('<s>', 'er'),
#  ('er', 'habe'),
#  ('habe', 'über'),
#  ('über', 'weitere'),
#  ('weitere', 'wanderungswellen'),
#  ('wanderungswellen', 'die'),
#  ('die', 'nordamerikanischen'),
#  ('nordamerikanischen', 'jägerkulturen'),
#  ('jägerkulturen', 'sekundär'),
#  ('sekundär', 'beeinflusst'),
#  ('beeinflusst', '</s>'),
#  ('<s>', 'an'),
#  ('an', 'die'),
#  ('die', 'stelle'),
#  ('stelle', 'des'),
#  ('des', 'opfers'),
#  ('opfers', 'wilder'),
#  ('wilder', 'tiere'),
#  ('tiere', 'die'),
#  ('die', 'der'),
#  ('der', 'schamane'),
#  ('schamane', 'vorher'),
#  ('vorher', 'um'),
#  ('um', 'erlaubnis'),
#  ('erlaubnis', 'für'),
#  ('für', 'die'),
#  ('die', 'tötung'),
#  ('tötung', 'fragt'),
#  ('fragt', 'oder'),
#  ('oder', 'bei'),
#  ('bei', 'denen'),
#  ('denen', 'er'),
#  ('er', 'sich'),
#  ('sich', 'für'),
#  ('für', 'die'),
#  ('die', 'tat'),
#  ('tat', 'entschuldigt'),
#  ('entschuldigt', 'so'),
#  ('so', 'bei'),
#  ('bei', 'den'),
#  ('den', 'bärenkulten'),
#  ('bärenkulten', 'der'),
#  ('der', 'schamanen'),
#  ('schamanen', 'der'),
#  ('der', 'ainu'),
#  ('ainu', 'aleuten'),
#  ('aleuten', 'und'),
#  ('und', 'der'),
#  ('der', 'transbaikalischen'),
#  ('transbaikalischen', 'völker'),
#  ('völker', 'seien'),
#  ('seien', 'später'),
#  ('später', 'domestizierte'),
#  ('domestizierte', 'tiere'),
#  ('tiere', 'wie'),
#  ('wie', 'das'),
#  ('das', 'rentier'),
#  ('rentier', 'in'),
#  ('in', 'sibirien'),
#  ('sibirien', 'oder'),
#  ('oder', 'hunde'),
#  ('hunde', 'wie'),
#  ('wie', 'in'),
#  ('in', 'russland'),
#  ('russland', 'oder'),
#  ('oder', 'indien'),
#  ('indien', 'getreten'),
#  ('getreten', '</s>'),
#  ('<s>', '17'),
#  ('17', 'insofern'),
#  ('insofern', 'folgt'),
#  ('folgt', 'witzel'),
#  ('witzel', 'der'),
#  ('der', 'weiten'),
#  ('weiten', 'phänomenologischen'),
#  ('phänomenologischen', 'schamanismus-definition'),
#  ('schamanismus-definition', 'von'),
#  ('von', 'walter'),
#  ('walter', 'und'),
#  ('und', 'fridman'),
#  ('fridman', '</s>'),
#  ('<s>', '18'),
#  ('18', 'da'),
#  ('da', 'bereits'),
#  ('bereits', 'der'),
#  ('der', 'klassische'),
#  ('klassische', 'schamanismus'),
#  ('schamanismus', 'sibiriens'),
#  ('sibiriens', 'etliche'),
#  ('etliche', 'varianten'),
#  ('varianten', 'aufweist'),
#  ('aufweist', 'werden'),
#  ('werden', 'weiter'),
#  ('weiter', 'reichende'),
#  ('reichende', 'geographische'),
#  ('geographische', 'oder'),
#  ('oder', 'historische'),
#  ('historische', 'auslegungen'),
#  ('auslegungen', 'die'),
#  ('die', 'solche'),
#  ('solche', 'phänomene'),
#  ('phänomene', 'aus'),
#  ('aus', 'ihrem'),
#  ('ihrem', 'kulturellen'),
#  ('kulturellen', 'kontext'),
#  ('kontext', 'gelöst'),
#  ('gelöst', 'betrachten'),
#  ('betrachten', 'und'),
#  ('und', 'verallgemeinern'),
#  ('verallgemeinern', 'von'),
#  ('von', 'vielen'),
#  ('vielen', 'autoren'),
#  ('autoren', 'als'),
#  ('als', 'spekulativ'),
#  ('spekulativ', 'kritisiert'),
#  ('kritisiert', '</s>'),
#  ('<s>', '19'),
#  ('19', '13'),
#  ('13', 'in'),
#  ('in', 'der'),
#  ('der', 'zeitgenössischen'),
#  ('zeitgenössischen', 'literatur'),
#  ('literatur', 'populärwissenschaftlichen'),
#  ('populärwissenschaftlichen', 'insbesondere'),
#  ('insbesondere', 'esoterischen'),
#  ('esoterischen', 'büchern'),
#  ('büchern', 'aber'),
#  ('aber', 'auch'),
#  ('auch', 'wissenschaftlichen'),
#  ('wissenschaftlichen', 'schriften'),
#  ('schriften', 'wird'),
#  ('wird', 'in'),
#  ('in', 'diesem'),
#  ('diesem', 'zusammenhang'),
#  ('zusammenhang', 'oftmals'),
#  ('oftmals', 'nicht'),
#  ('nicht', 'deutlich'),
#  ('deutlich', 'gemacht'),
#  ('gemacht', 'auf'),
#  ('auf', 'welche'),
#  ('welche', 'ethnien'),
#  ('ethnien', 'sich'),
#  ('sich', 'darstellungen'),
#  ('darstellungen', 'zu'),
#  ('zu', 'bestimmten'),
#  ('bestimmten', 'schamanischen'),
#  ('schamanischen', 'praktiken'),
#  ('praktiken', 'konkret'),
#  ('konkret', 'beziehen'),
#  ('beziehen', 'so'),
#  ('so', 'dass'),
#  ('dass', 'regionale'),
#  ('regionale', 'oft'),
#  ('oft', 'sibirische'),
#  ('sibirische', 'phänomene'),
#  ('phänomene', 'auch'),
#  ('auch', 'in'),
#  ('in', 'anderen'),
#  ('anderen', 'kulturen'),
#  ('kulturen', 'verortet'),
#  ('verortet', 'werden'),
#  ('werden', 'in'),
#  ('in', 'deren'),
#  ('deren', 'traditionen'),
#  ('traditionen', 'sie'),
#  ('sie', 'tatsächlich'),
#  ('tatsächlich', 'jedoch'),
#  ('jedoch', 'fremd'),
#  ('fremd', 'sind'),
#  ('sind', '</s>'),
#  ('<s>', 'beispiele'),
#  ('beispiele', 'dafür'),
#  ('dafür', 'sind'),
#  ('sind', 'der'),
#  ('der', 'weltenbaum'),
#  ('weltenbaum', 'und'),
#  ('und', 'die'),
#  ('die', 'gesamte'),
#  ('gesamte', 'schamanische'),
#  ('schamanische', 'kosmologie'),
#  ('kosmologie', 'in'),
#  ('in', 'eurasien'),
#  ('eurasien', 'verankerte'),
#  ('verankerte', 'mythologische'),
#  ('mythologische', 'konzepte'),
#  ('konzepte', 'die'),
#  ('die', 'hier'),
#  ('hier', 'mit'),
#  ('mit', 'ähnlichen'),
#  ('ähnlichen', 'archetypen'),
#  ('archetypen', 'anderer'),
#  ('anderer', 'weltgegenden'),
#  ('weltgegenden', 'gleichgesetzt'),
#  ('gleichgesetzt', 'werden'),
#  ('werden', 'und'),
#  ('und', 'so'),
#  ('so', 'das'),
#  ('das', 'irreführende'),
#  ('irreführende', 'bild'),
#  ('bild', 'eines'),
#  ('eines', 'einheitlichen'),
#  ('einheitlichen', 'schamanismus'),
#  ('schamanismus', 'erzeugen'),
#  ('erzeugen', '</s>'),
#  ('<s>', '13'),
#  ('13', 'witzel'),
#  ('witzel', 'sieht'),
#  ('sieht', 'jedoch'),
#  ('jedoch', 'in'),
#  ('in', 'der'),
#  ('der', 'eurasischen'),
#  ('eurasischen', 'germanischen'),
#  ('germanischen', 'indischen'),
#  ('indischen', 'japanischen'),
#  ('japanischen', 'usw'),
#  ('usw', '</s>'),
#  ('<s>', 'vorstellung'),
#  ('vorstellung', 'vom'),
#  ('vom', 'baum'),
#  ('baum', 'des'),
#  ('des', 'lebens'),
#  ('lebens', 'der'),
#  ('der', 'erstiegen'),
#  ('erstiegen', 'werden'),
#  ('werden', 'muss'),
#  ('muss', 'beziehungsweise'),
#  ('beziehungsweise', 'im'),
#  ('im', 'weltenbaum'),
#  ('weltenbaum', 'nur'),
#  ('nur', 'eine'),
#  ('eine', 'analogie'),
#  ('analogie', 'zur'),
#  ('zur', 'älteren'),
#  ('älteren', 'vorstellung'),
#  ('vorstellung', 'des'),
#  ('des', 'schamanenflugs'),
#  ('schamanenflugs', 'die'),
#  ('die', 'nichts'),
#  ('nichts', 'mit'),
#  ('mit', 'anderen'),
#  ('anderen', 'baummythen'),
#  ('baummythen', 'zu'),
#  ('zu', 'tun'),
#  ('tun', 'habe'),
#  ('habe', '</s>'),
#  ('<s>', '20'),
#  ('20', 'insbesondere'),
#  ('insbesondere', 'die'),
#  ('die', 'äußerst'),
#  ('äußerst', 'erfolgreichen'),
#  ('erfolgreichen', 'bücher'),
#  ('bücher', 'von'),
#  ('von', 'mircea'),
#  ('mircea', 'eliade'),
#  ('eliade', 'carlos'),
#  ('carlos', 'castaneda'),
#  ('castaneda', 'und'),
#  ('und', 'harner'),
#  ('harner', 'haben'),
#  ('haben', 'den'),
#  ('den', 'modernen'),
#  ('modernen', 'mythos'),
#  ('mythos', 'schamanismus'),
#  ('schamanismus', 'erzeugt'),
#  ('erzeugt', 'der'),
#  ('der', 'suggeriert'),
#  ('suggeriert', 'dass'),
#  ('dass', 'es'),
#  ('es', 'sich'),
#  ('sich', 'dabei'),
#  ('dabei', 'um'),
#  ('um', 'ein'),
#  ('ein', 'universelles'),
#  ('universelles', 'und'),
#  ('und', 'homolog'),
#  ('homolog', 'entstandenes'),
#  ('entstandenes', 'religiös-spirituelles'),
#  ('religiös-spirituelles', 'phänomen'),
#  ('phänomen', 'handeln'),
#  ('handeln', 'würde'),
#  ('würde', '</s>'),
#  ('<s>', 'im'),
#  ('im', 'hinblick'),
#  ('hinblick', 'auf'),
#  ('auf', 'das'),
#  ('das', 'große'),
#  ('große', 'interesse'),
#  ('interesse', 'in'),
#  ('in', 'der'),
#  ('der', 'bevölkerung'),
#  ('bevölkerung', '21'),
#  ('21', 'weisen'),
#  ('weisen', 'einige'),
#  ('einige', 'autoren'),
#  ('autoren', 'darauf'),
#  ('darauf', 'hin'),
#  ('hin', 'dass'),
#  ('dass', 'schamanismus'),
#  ('schamanismus', 'keine'),
#  ('keine', 'einheitliche'),
#  ('einheitliche', 'ideologie'),
#  ('ideologie', 'oder'),
#  ('oder', 'religion'),
#  ('religion', 'bestimmter'),
#  ('bestimmter', 'kulturen'),
#  ('kulturen', 'ist'),
#  ('ist', '</s>'),
#  ('<s>', 'es'),
#  ('es', 'handle'),
#  ('handle', 'sich'),
#  ('sich', 'vielmehr'),
#  ('vielmehr', 'um'),
#  ('um', 'ein'),
#  ('ein', 'wissenschaftliches'),
#  ('wissenschaftliches', 'konstrukt'),
#  ('konstrukt', 'aus'),
#  ('aus', 'eurozentrischer'),
#  ('eurozentrischer', 'perspektive'),
#  ('perspektive', 'um'),
#  ('um', 'ähnliche'),
#  ('ähnliche', 'phänomene'),
#  ('phänomene', 'rund'),
#  ('rund', 'um'),
#  ('um', 'die'),
#  ('die', 'geisterbeschwörer'),
#  ('geisterbeschwörer', 'unterschiedlichster'),
#  ('unterschiedlichster', 'herkunft'),
#  ('herkunft', 'zu'),
#  ('zu', 'vergleichen'),
#  ('vergleichen', 'und'),
#  ('und', 'zu'),
#  ('zu', 'klassifizieren'),
#  ('klassifizieren', '</s>'),
#  ('<s>', '14'),
#  ('14', '22'),
#  ('22', '23'),
#  ('23', 'inhaltsverzeichnis'),
#  ('inhaltsverzeichnis', 'etymologie'),
#  ('etymologie', 'schamanen'),
#  ('schamanen', 'und'),
#  ('und', 'schamanismus'),
#  ('schamanismus', 'wissenschaftsgeschichte'),
#  ('wissenschaftsgeschichte', 'spirituelle'),
#  ('spirituelle', 'schamanismus-konzepte'),
#  ('schamanismus-konzepte', 'entstehung'),
#  ('entstehung', 'popularität'),
#  ('popularität', 'und'),
#  ('und', 'kritik'),
#  ('kritik', 'weitgehend'),
#  ('weitgehend', 'anerkannte'),
#  ('anerkannte', 'thesen'),
#  ('thesen', '</s>'),
#  ('<s>', 'der'),
#  ('der', 'klassisch'),
#  ('klassisch', 'sibirische'),
#  ('sibirische', 'schamanismus'),
#  ('schamanismus', 'oder'),
#  ('oder', 'animismus'),
#  ('animismus', '</s>'),
#  ('<s>', '</s>'),
#  ('<s>', 'historische'),
#  ('historische', 'entwicklung'),
#  ('entwicklung', '</s>'),
#  ('<s>', '</s>'),
#  ('<s>', 'kosmologie'),
#  ('kosmologie', '</s>'),
#  ('<s>', '</s>'),
#  ('<s>', 'die'),
#  ('die', 'rituelle'),
#  ('rituelle', 'ekstase'),
#  ('ekstase', '</s>'),
#  ('<s>', 'müller'),
#  ('müller', 'elementar-'),
#  ('elementar-', 'komplex-'),
#  ('komplex-', 'und'),
#  ('und', 'besessenheitsschamanismus'),
#  ('besessenheitsschamanismus', '</s>'),
#  ('<s>', '</s>'),
#  ('<s>', 'elementarschamanismus'),
#  ('elementarschamanismus', '</s>'),
#  ('<s>', '</s>'),
#  ('<s>', 'komplexschamanismus'),
#  ('komplexschamanismus', '</s>'),
#  ('<s>', '</s>'),
#  ('<s>', 'besessenheitsschamanismus'),
#  ('besessenheitsschamanismus', '</s>'),
#  ('<s>', '</s>'),
#  ('<s>', 'kritik'),
#  ('kritik', '</s>'),
#  ('<s>', 'ganzheitliche'),
#  ('ganzheitliche', 'heilkunde'),
#  ('heilkunde', 'generelle'),
#  ('generelle', 'kritik'),
#  ('kritik', 'umstrittene'),
#  ('umstrittene', 'und'),
#  ('und', 'spekulative'),
#  ('spekulative', 'thesen'),
#  ('thesen', '</s>'),
#  ('<s>', 'umstrittene'),
#  ('umstrittene', 'thesen'),
#  ('thesen', '</s>'),
#  ('<s>', '</s>'),
#  ('<s>', 'prähistorischer'),
#  ('prähistorischer', 'schamanismus'),
#  ('schamanismus', '</s>'),
#  ('<s>', '</s>'),
#  ('<s>', 'beziehung'),
#  ('beziehung', 'zum'),
#  ('zum', 'sufismus'),
#  ('sufismus', '</s>'),
#  ('<s>', 'spekulative'),
#  ('spekulative', 'thesen'),
#  ('thesen', '</s>'),
#  ('<s>', '</s>'),
#  ('<s>', 'schamanismus'),
#  ('schamanismus', 'als'),
#  ('als', 'archaische'),
#  ('archaische', 'ekstasetechnik'),
#  ('ekstasetechnik', '</s>'),
#  ('<s>', '</s>'),
#  ('<s>', 'kritik'),
#  ('kritik', 'siehe'),
#  ('siehe', 'auch'),
#  ('auch', 'literatur'),
#  ('literatur', 'weblinks'),
#  ('weblinks', '10'),
#  ('10', 'anmerkungen'),
#  ('anmerkungen', '11'),
#  ('11', 'einzelnachweise'),
#  ('einzelnachweise', 'etymologie'),
#  ('etymologie', 'die'),
#  ('die', 'bezeichnung'),
#  ('bezeichnung', 'schamanismus'),
#  ('schamanismus', 'leitet'),
#  ('leitet', 'sich'),
#  ('sich', 'den'),
#  ('den', 'meisten'),
#  ('meisten', 'autoren'),
#  ('autoren', 'zufolge'),
#  ('zufolge', 'von'),
#  ('von', 'dem'),
#  ('dem', 'aus'),
#  ('aus', 'sibirien'),
#  ('sibirien', 'entlehnten'),
#  ('entlehnten', 'wort'),
#  ('wort', 'schamane'),
#  ('schamane', 'ab'),
#  ('ab', 'mit'),
#  ('mit', 'dem'),
#  ('dem', 'die'),
#  ('die', 'tungusischen'),
#  ('tungusischen', 'völker'),
#  ('völker', 'ihre'),
#  ('ihre', 'geisterbeschwörer'),
#  ('geisterbeschwörer', 'bezeichnen'),
#  ('bezeichnen', '</s>'),
#  ('<s>', '24'),
#  ('24', 'das'),
#  ('das', 'wort'),
#  ('wort', 'entstammt'),
#  ('entstammt', 'vermutlich'),
#  ('vermutlich', 'dem'),
#  ('dem', 'evenkischen'),
#  ('evenkischen', '</s>'),
#  ('<s>', '</s>'),
#  ('<s>', 'tungusischen'),
#  ('tungusischen', 'aman'),
#  ('aman', 'dessen'),
#  ('dessen', 'weitere'),
#  ('weitere', 'etymologie'),
#  ('etymologie', 'umstritten'),
#  ('umstritten', 'ist'),
#  ('ist', '</s>'),
#  ('<s>', 'möglicherweise'),
#  ('möglicherweise', 'liegt'),
#  ('liegt', 'das'),
#  ('das', 'manjurische'),
#  ('manjurische', 'verb'),
#  ('verb', 'sambi'),
#  ('sambi', 'wissen'),
#  ('wissen', 'kennen'),
#  ('kennen', 'durchschauen'),
#  ('durchschauen', 'zugrunde'),
#  ('zugrunde', '</s>'),
#  ('<s>', 'die'),
#  ('die', 'ältere'),
#  ('ältere', 'bezeichnung'),
#  ('bezeichnung', 'schamanentum'),
#  ('schamanentum', 'bezieht'),
#  ('bezieht', 'sich'),
#  ('sich', 'nicht'),
#  ('nicht', 'auf'),
#  ('auf', 'die'),
#  ('die', 'wissenschaftlichen'),
#  ('wissenschaftlichen', 'konzepte'),
#  ('konzepte', 'sondern'),
#  ('sondern', 'nur'),
#  ('nur', 'auf'),
#  ('auf', 'die'),
#  ('die', 'existenz'),
#  ('existenz', 'von'),
#  ('von', 'geisterbeschwörern'),
#  ('geisterbeschwörern', 'in'),
#  ('in', 'verschiedenen'),
#  ('verschiedenen', 'kulturen'),
#  ('kulturen', 'ohne'),
#  ('ohne', 'dabei'),
#  ('dabei', 'bestimmte'),
#  ('bestimmte', 'zusammenhänge'),
#  ('zusammenhänge', 'herzustellen'),
#  ('herzustellen', '</s>'),
#  ('<s>', '25'),
#  ('25', 'weitere'),
#  ('weitere', 'informationen'),
#  ('informationen', 'siehe'),
#  ('siehe', 'etymologie'),
#  ('etymologie', 'im'),
#  ('im', 'artikel'),
#  ('artikel', 'schamane'),
#  ('schamane', 'schamanen'),
#  ('schamanen', 'und'),
#  ('und', 'schamanismus'),
#  ('schamanismus', 'george'),
#  ('george', 'catlins'),
#  ('catlins', 'darstellung'),
#  ('darstellung', 'eines'),
#  ('eines', 'schamanen'),
#  ('schamanen', 'medicine'),
#  ('medicine', 'man'),
#  ('man', 'der'),
#  ('der', 'schwarzfuß-indianer'),
#  ...]

# %%
unigram_counter = Counter(unigrams)
unigram_counter.most_common(25)
# Out:
# [('<s>', 358),
#  ('</s>', 358),
#  ('der', 285),
#  ('und', 283),
#  ('die', 274),
#  ('in', 146),
#  ('den', 96),
#  ('des', 87),
#  ('oder', 76),
#  ('schamanismus', 67),
#  ('als', 67),
#  ('von', 63),
#  ('sich', 62),
#  ('mit', 60),
#  ('eine', 58),
#  ('das', 57),
#  ('auf', 53),
#  ('schamanen', 51),
#  ('zu', 51),
#  ('bei', 50),
#  ('im', 49),
#  ('es', 38),
#  ('für', 38),
#  ('auch', 37),
#  ('ist', 37)]

# %%
bigram_counter = Counter(bigrams)
bigram_counter.most_common(25)
# Out:
# [(('in', 'der'), 29),
#  (('<s>', 'die'), 24),
#  (('in', 'den'), 20),
#  (('vor', 'allem'), 16),
#  (('und', 'die'), 14),
#  (('auf', 'die'), 12),
#  (('für', 'die'), 11),
#  (('bei', 'den'), 11),
#  (('<s>', 'in'), 10),
#  (('in', 'die'), 10),
#  (('und', 'der'), 9),
#  (('der', 'schamanen'), 9),
#  (('<s>', 'es'), 9),
#  (('<s>', 'jahrhunderts'), 9),
#  (('mit', 'der'), 8),
#  (('<s>', 'der'), 8),
#  (('schamanismus', 'als'), 8),
#  (('mit', 'dem'), 8),
#  (('des', 'schamanismus'), 7),
#  (('bei', 'der'), 7),
#  (('<s>', 'müller'), 7),
#  (('<s>', 'dies'), 7),
#  (('darüber', 'hinaus'), 7),
#  (('bei', 'denen'), 6),
#  (('<s>', 'im'), 6)]

# %%
bigram_model = defaultdict(dict)

for bigram, count in bigram_counter.items():
    w_1, w, = bigram
    w_1_frequ = unigram_counter[w_1]
    
    prob = count / w_1_frequ
    bigram_model[w_1][w] = prob

# %%
pprint.pprint(bigram_model["bezeichnet"])
# Out:
# {'</s>': 0.14285714285714285,
#  'im': 0.14285714285714285,
#  'schamanismus': 0.14285714285714285,
#  'werden': 0.2857142857142857,
#  'wird': 0.2857142857142857}

# %%
def eval_model(model, sentence):
    tokens = sentence.split()
    bigrams = ngrams(tokens, 2)
    
    log_prob = 0
    for bigram in bigrams:
        t_1, t = bigram
        
        try:
            probability = model[t_1][t]
        except:
            print("Prob not found for", bigram)
            probability = 0.00001
        
        log_prob += math.log(probability)
    
    log_prob = math.exp(log_prob)
    print(f"Probability for '{sentence}' is: {log_prob}")
    print("\n\n")


eval_model(bigram_model, "sibirischer schamanismus ist entscheidend")
eval_model(bigram_model, "Schamanismus bezeichnet auch".lower())
eval_model(bigram_model, "im engeren Sinne".lower())
# Out:
# Prob not found for ('sibirischer', 'schamanismus')
# Prob not found for ('ist', 'entscheidend')
# Probability for 'sibirischer schamanismus ist entscheidend' is: 4.477611940298505e-08
#
#
#
# Probability for 'schamanismus bezeichnet schamanismus' is: 0.0021321961620469087
#
#
#
# Probability for 'im engeren sinne' is: 0.010204081632653057
